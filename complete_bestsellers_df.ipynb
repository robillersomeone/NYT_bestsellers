# %%
import pandas as pd

# %%
df0 = pd.read_csv('csv_files/books3_df.csv')
df1 = pd.read_csv('csv_files/monthly_book.csv')
df2 = pd.read_csv('csv_files/nytbooks1.csv')
df3 = pd.read_csv('csv_files/paperback_nonfiction_df.csv')

# %%
df = pd.concat([df0, df1])
# Out:
#                                                Author  \
# 0                                       Joanna Gaines
# 1                                       Rachel Hollis
# 2                      Joanna Gaines with Marah Stets
# 3     The Staff of the Late Show With Stephen Colbert
# 4                                         Mark Manson
# 5                                         Jen Sincero
# 6                                  Lin-Manuel Miranda
# 7                                          Ina Garten
# 8                   Chrissy Teigen and Adeena Sussman
# 9                                   Reese Witherspoon
# 10                                         RJ Palacio
# 11                                  Rachel Ignotofsky
# 12                    Dylan Thuras and Rosemary Mosco
# 13                                     Kelly Barnhill
# 14                 James Patterson with Steven Butler
# 15                             America's Test Kitchen
# ...

# %%
df.to_csv('csv_files/complete_bestsellers_df.csv', encoding='utf-8', index=False)
