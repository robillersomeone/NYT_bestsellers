# %% [markdown]
# # Merging data

# %% [markdown]
# notebook for merging data

# %%
# import modules
import re
import pandas as pd
import numpy as np
import string

# %% [markdown]
# ## Read in dataframes

# %%
# these are the NYT best seller list
nyt_2016_df = pd.read_csv('../data/nyt_2016_df.csv')
nyt_2017_df = pd.read_csv('../data/nyt_2017_df.csv')
nyt_2018_df = pd.read_csv('../data/nyt_2018_df')

# these are all of our books
gr_2016_df = pd.read_csv('../data/goodreads_2016_df.csv')
gr_2017_df = pd.read_csv('../data/goodreads_2017_df.csv')
gr_2018_df = pd.read_csv('../data/goodreads_2018_df.csv')

# %% [markdown]
# ## Merge thte NYT Bestseller dataframes

# %%
nyt_2018_df.shape
# Out:
# (100, 10)

# %%
nyt_2016_df.head()
# Out:
#              author                                        description  \
# 0         Yaa Gyasi  A novel of breathtaking sweep and emotional po...
# 1  Colson Whitehead  Cora is a slave on a cotton plantation in Geor...
# 2    Paul Kalanithi  For readers of Atul Gawande, Andrew Solomon, a...
# 3   Matthew Desmond  <b><i>New York Times </i>Bestseller<br/><br/>F...
# 4       Ian McGuire           LONGLISTED FOR THE MAN BOOKER PRIZE 2016
#
#            format       genre    month  pages  \
# 0       Hardcover  Historical     June    320
# 1       Hardcover  Historical   August    306
# 2  Kindle Edition  Nonfiction  January    208
# 3       Hardcover  Nonfiction    March    418
# 4       Hardcover  Historical    March    272
#
#                                            publisher  rating  \
# 0                                    Alfred A. Knopf    4.42
# 1                                    Doubleday Books    4.03
# 2  Random House                          (first p...    4.34
# 3                                              Crown    4.49
# 4  Henry Holt and Co.                          (f...    4.00
#
#                                               title  year
# 0                                         Homegoing  2016
# 1                          The Underground Railroad  2016
# 2                           When Breath Becomes Air  2016
# 3  Evicted: Poverty and Profit in the American City  2016
# 4                                   The North Water  2016

# %%
nyt_2017_df.head()
# Out:
#             author                                        description  \
# 0      David Grann  In the 1920s, the richest people per capita in...
# 1  George Saunders  In his long-awaited first novel, American mast...
# 2      Min Jin Lee                                    <i>Pachinko</i>
# 3     Mohsin Hamid  In a country teetering on the brink of civil w...
# 4        Ali Smith  Autumn. Season of mists and mellow fruitfulnes...
#
#       format       genre     month  pages  \
# 0      ebook  Nonfiction     April    359
# 1  Hardcover     Fiction  February    343
# 2  Hardcover  Historical  February    489
# 3  Hardcover     Fiction     March    231
# 4  Hardcover     Fiction  February    263
#
#                                            publisher  rating  \
# 0                                          Doubleday    4.11
# 1                                       Random House    3.79
# 2                           Grand Central Publishing    4.26
# 3  Riverhead                          (first publ...    3.81
# 4  Pantheon Books                          (first...    3.72
#
#                                                title    year
# 0  Killers of the Flower Moon: The Osage Murders ...  2017.0
# 1                               Lincoln in the Bardo  2017.0
# 2                                           Pachinko  2017.0
# 3                                          Exit West  2017.0
# 4                                             Autumn  2016.0

# %%
nyt_2018_df.head()
# Out:
#              author                                        description  \
# 0  Michael Ondaatje  In a narrative as mysterious as memory itself ...
# 1      Tayari Jones  Newlyweds Celestial and Roy are the embodiment...
# 2      Tommy Orange  Fierce, angry, funny, heartbreaking—Tommy Oran...
# 3     Lisa Halliday  A singularly inventive and unforgettable debut...
# 4    Richard Powers  An Air Force loadmaster in the Vietnam War is ...
#
#       format       genre     month  pages  \
# 0  Paperback  Historical      June    304
# 1  Hardcover     Fiction  February    308
# 2  Hardcover     Fiction      June    294
# 3  Hardcover     Fiction  February    277
# 4  Hardcover     Fiction     April    502
#
#                                            publisher  rating  \
# 0  Jonathan Cape                          (first ...    3.73
# 1  Algonquin Books                          (firs...    4.01
# 2                                              Knopf    4.07
# 3                                   Simon & Schuster    3.60
# 4                             W. W. Norton & Company    4.25
#
#                   title    year
# 0              Warlight  2018.0
# 1  An American Marriage  2018.0
# 2           There There  2018.0
# 3             Asymmetry  2018.0
# 4         The Overstory  2018.0

# %%
# put it together
nyt_df = pd.concat([nyt_2016_df, nyt_2017_df, nyt_2018_df])

# %%
nyt_df.shape
# Out:
# (300, 10)

# %%
nyt_df .head()
# Out:
#              author                                        description  \
# 0         Yaa Gyasi  A novel of breathtaking sweep and emotional po...
# 1  Colson Whitehead  Cora is a slave on a cotton plantation in Geor...
# 2    Paul Kalanithi  For readers of Atul Gawande, Andrew Solomon, a...
# 3   Matthew Desmond  <b><i>New York Times </i>Bestseller<br/><br/>F...
# 4       Ian McGuire           LONGLISTED FOR THE MAN BOOKER PRIZE 2016
#
#            format       genre    month  pages  \
# 0       Hardcover  Historical     June    320
# 1       Hardcover  Historical   August    306
# 2  Kindle Edition  Nonfiction  January    208
# 3       Hardcover  Nonfiction    March    418
# 4       Hardcover  Historical    March    272
#
#                                            publisher  rating  \
# 0                                    Alfred A. Knopf    4.42
# 1                                    Doubleday Books    4.03
# 2  Random House                          (first p...    4.34
# 3                                              Crown    4.49
# 4  Henry Holt and Co.                          (f...    4.00
#
#                                               title    year
# 0                                         Homegoing  2016.0
# 1                          The Underground Railroad  2016.0
# 2                           When Breath Becomes Air  2016.0
# 3  Evicted: Poverty and Profit in the American City  2016.0
# 4                                   The North Water  2016.0

# %%
#df[df.duplicated(['ID'], keep=False)]

# this is to test
title_df = nyt_df[nyt_df.duplicated(['title'], keep=False)]

# %%
nyt_df.head()
# Out:
#              author                                        description  \
# 0         Yaa Gyasi  A novel of breathtaking sweep and emotional po...
# 1  Colson Whitehead  Cora is a slave on a cotton plantation in Geor...
# 2    Paul Kalanithi  For readers of Atul Gawande, Andrew Solomon, a...
# 3   Matthew Desmond  <b><i>New York Times </i>Bestseller<br/><br/>F...
# 4       Ian McGuire           LONGLISTED FOR THE MAN BOOKER PRIZE 2016
#
#            format       genre    month  pages  \
# 0       Hardcover  Historical     June    320
# 1       Hardcover  Historical   August    306
# 2  Kindle Edition  Nonfiction  January    208
# 3       Hardcover  Nonfiction    March    418
# 4       Hardcover  Historical    March    272
#
#                                            publisher  rating  \
# 0                                    Alfred A. Knopf    4.42
# 1                                    Doubleday Books    4.03
# 2  Random House                          (first p...    4.34
# 3                                              Crown    4.49
# 4  Henry Holt and Co.                          (f...    4.00
#
#                                               title    year
# 0                                         Homegoing  2016.0
# 1                          The Underground Railroad  2016.0
# 2                           When Breath Becomes Air  2016.0
# 3  Evicted: Poverty and Profit in the American City  2016.0
# 4                                   The North Water  2016.0

# %%
title_df.shape
# Out:
# (22, 10)

# %%
nyt_df = nyt_df.drop_duplicates(subset='title')#, keep="last")

# %%
nyt_df.shape[0]
# Out:
# 289

# %% [markdown]
# ### Merge best seller dataframe with all books dataframe

# %%
nyt_df.head()
# Out:
#              author                                        description  \
# 0         Yaa Gyasi  A novel of breathtaking sweep and emotional po...
# 1  Colson Whitehead  Cora is a slave on a cotton plantation in Geor...
# 2    Paul Kalanithi  For readers of Atul Gawande, Andrew Solomon, a...
# 3   Matthew Desmond  <b><i>New York Times </i>Bestseller<br/><br/>F...
# 4       Ian McGuire           LONGLISTED FOR THE MAN BOOKER PRIZE 2016
#
#            format       genre    month  pages  \
# 0       Hardcover  Historical     June    320
# 1       Hardcover  Historical   August    306
# 2  Kindle Edition  Nonfiction  January    208
# 3       Hardcover  Nonfiction    March    418
# 4       Hardcover  Historical    March    272
#
#                                            publisher  rating  \
# 0                                    Alfred A. Knopf    4.42
# 1                                    Doubleday Books    4.03
# 2  Random House                          (first p...    4.34
# 3                                              Crown    4.49
# 4  Henry Holt and Co.                          (f...    4.00
#
#                                               title    year
# 0                                         Homegoing  2016.0
# 1                          The Underground Railroad  2016.0
# 2                           When Breath Becomes Air  2016.0
# 3  Evicted: Poverty and Profit in the American City  2016.0
# 4                                   The North Water  2016.0

# %%
# add column for Bestseller
nyt_df.shape
# Out:
# (289, 10)

# %%
# add in target feature
nyt_df['best_seller'] = 1

# %%
nyt_df.head()
# Out:
#              author                                        description  \
# 0         Yaa Gyasi  A novel of breathtaking sweep and emotional po...
# 1  Colson Whitehead  Cora is a slave on a cotton plantation in Geor...
# 2    Paul Kalanithi  For readers of Atul Gawande, Andrew Solomon, a...
# 3   Matthew Desmond  <b><i>New York Times </i>Bestseller<br/><br/>F...
# 4       Ian McGuire           LONGLISTED FOR THE MAN BOOKER PRIZE 2016
#
#            format       genre    month  pages  \
# 0       Hardcover  Historical     June    320
# 1       Hardcover  Historical   August    306
# 2  Kindle Edition  Nonfiction  January    208
# 3       Hardcover  Nonfiction    March    418
# 4       Hardcover  Historical    March    272
#
#                                            publisher  rating  \
# 0                                    Alfred A. Knopf    4.42
# 1                                    Doubleday Books    4.03
# 2  Random House                          (first p...    4.34
# 3                                              Crown    4.49
# 4  Henry Holt and Co.                          (f...    4.00
#
#                                               title    year  best_seller
# 0                                         Homegoing  2016.0            1
# 1                          The Underground Railroad  2016.0            1
# 2                           When Breath Becomes Air  2016.0            1
# 3  Evicted: Poverty and Profit in the American City  2016.0            1
# 4                                   The North Water  2016.0            1

# %%
# this is making the dataframe with all the books

choiceawards_df = pd.concat([gr_2016_df, gr_2017_df, gr_2018_df])

# %%
choiceawards_df.shape
# Out:
# (1220, 10)

# %%
doubled_books_df = choiceawards_df[choiceawards_df.duplicated(['title'], keep=False)]

# %%
doubled_books_df.shape
# Out:
# (96, 10)

# %%
choiceawards_df = choiceawards_df.drop_duplicates(subset='title')#, keep="last")

# %%
choiceawards_df.shape
# Out:
# (1171, 10)

# %%
# set best seller feature to false
choiceawards_df['best_seller'] = 0

# %%
choiceawards_df.head()
# Out:
#                     author                                        description  \
# 0           Liane Moriarty  Six responsible adults. Three cute kids. One s...
# 1           Bryn Greenwood  As the daughter of a meth dealer, Wavy knows n...
# 2               Emma Cline  Northern California, during the violent end of...
# 3  Cynthia D'Aprix Sweeney  <i>A warm, funny and acutely perceptive debut ...
# 4             Jodi Picoult  Ruth Jefferson is a labor and delivery nurse a...
#
#       format    genre    month  pages           publisher  rating  \
# 0  Hardcover  Fiction     July    415      Flatiron Books    3.56
# 1  Hardcover  Fiction   August    346  Thomas Dunne Books    4.07
# 2  Hardcover  Fiction     June    355        Random House    3.47
# 3  Hardcover  Fiction    March    368                Ecco    3.42
# 4  Hardcover  Fiction  October    480    Ballantine Books    4.35
#
#                                title    year  best_seller
# 0                 Truly Madly Guilty  2016.0            0
# 1  All the Ugly and Wonderful Things  2016.0            0
# 2                          The Girls  2016.0            0
# 3                           The Nest  2016.0            0
# 4                 Small Great Things  2016.0            0

# %%
all_books = pd.concat([choiceawards_df, nyt_df])
all_books.shape
# all_books nyt best sellers and all the books from good reads so there are duplicates
# Out:
# (1460, 11)

# %%
all_books.head()
# Out:
#                     author                                        description  \
# 0           Liane Moriarty  Six responsible adults. Three cute kids. One s...
# 1           Bryn Greenwood  As the daughter of a meth dealer, Wavy knows n...
# 2               Emma Cline  Northern California, during the violent end of...
# 3  Cynthia D'Aprix Sweeney  <i>A warm, funny and acutely perceptive debut ...
# 4             Jodi Picoult  Ruth Jefferson is a labor and delivery nurse a...
#
#       format    genre    month  pages           publisher  rating  \
# 0  Hardcover  Fiction     July    415      Flatiron Books    3.56
# 1  Hardcover  Fiction   August    346  Thomas Dunne Books    4.07
# 2  Hardcover  Fiction     June    355        Random House    3.47
# 3  Hardcover  Fiction    March    368                Ecco    3.42
# 4  Hardcover  Fiction  October    480    Ballantine Books    4.35
#
#                                title    year  best_seller
# 0                 Truly Madly Guilty  2016.0            0
# 1  All the Ugly and Wonderful Things  2016.0            0
# 2                          The Girls  2016.0            0
# 3                           The Nest  2016.0            0
# 4                 Small Great Things  2016.0            0

# %% [markdown]
# ## fix for publishers with messy names

# %%
# some publishers have extra info after their names 
all_books.loc[:,['publisher']].head()
# Out:
#             publisher
# 0      Flatiron Books
# 1  Thomas Dunne Books
# 2        Random House
# 3                Ecco
# 4    Ballantine Books

# %%
publishers = all_books['publisher']
len(publishers)
# Out:
# 1460

# %%
publishers.iloc[8]
# Out:
# 'Random House                          (first published January 6th 2016'

# %%
clean_publishers = []
for i in publishers:
    clean_publishers.append(i.split('   ')[0])

# %%
len(clean_publishers)
# Out:
# 1460

# %%
type(clean_publishers)
# Out:
# list

# %%
all_books['publisher'] = clean_publishers

# %%
len(all_books['publisher'].unique())
# Out:
# 398

# %% [markdown]
# ## more_than_one_df checks to see where the duplicate books are

# %%
more_than_one_df = all_books[all_books.duplicated(['title'], keep=False)]

# %%
more_than_one_df.shape
# Out:
# (174, 11)

# %%
more_than_one_df.head()
# Out:
#                   author                                        description  \
# 6           Ann Patchett  <strong>#1 <em>New York Times </em>Bestseller<...
# 8       Elizabeth Strout  The profound mother-daughter bond is explored ...
# 10    Jacqueline Woodson  Running into a long-ago friend sets memories f...
# 11  Jonathan Safran Foer  <b>A monumental new novel from the bestselling...
# 12         Richard Russo  Richard Russo, at the very top of his game, no...
#
#        format    genre      month  pages                  publisher  rating  \
# 6   Hardcover  Fiction  September    336                     Harper    3.81
# 8   Hardcover  Fiction    January    193               Random House    3.51
# 10  Hardcover  Fiction     August    177                    Amistad    3.86
# 11  Hardcover  Fiction  September    592  Farrar, Straus and Giroux    3.64
# 12  Hardcover  Fiction        May    477                      Knopf    4.08
#
#                      title    year  best_seller
# 6             Commonwealth  2016.0            0
# 8   My Name Is Lucy Barton  2016.0            0
# 10        Another Brooklyn  2016.0            0
# 11               Here I Am  2016.0            0
# 12        Everybody's Fool  2016.0            0

# %%
more_than_one_df[more_than_one_df['title'].str.contains("Small Fry")==True]
# Out:
#                 author                                        description  \
# 194  Lisa Brennan-Jobs  Born on a farm and named in a field by her par...
# 96   Lisa Brennan-Jobs  Born on a farm and named in a field by her par...
#
#         format       genre      month  pages    publisher  rating      title  \
# 194  Hardcover  Nonfiction  September    383  Grove Press    3.94  Small Fry
# 96   Hardcover  Nonfiction  September    383  Grove Press    3.94  Small Fry
#
#        year  best_seller
# 194  2018.0            0
# 96   2018.0            1

# %%
all_books = all_books.drop_duplicates(subset='title', keep='last')

# %%
# this is to cheack that the Small Fry that was not on the bestseller list was dropped
all_books[all_books['title'].str.contains("Small Fry")==True]
# Out:
#                author                                        description  \
# 96  Lisa Brennan-Jobs  Born on a farm and named in a field by her par...
#
#        format       genre      month  pages    publisher  rating      title  \
# 96  Hardcover  Nonfiction  September    383  Grove Press    3.94  Small Fry
#
#       year  best_seller
# 96  2018.0            1

# %%
check_double = all_books[all_books.duplicated(['title'], keep=False)]

# %%
check_double.shape
# Out:
# (0, 11)

# %%
# all_books as the nyt best sellers and non best seller labeled with 1 and 0

# %%
all_books.shape
# Out:
# (1373, 11)

# %%
all_books.head(15)
# Out:
#                      author  \
# 0            Liane Moriarty
# 1            Bryn Greenwood
# 2                Emma Cline
# 3   Cynthia D'Aprix Sweeney
# 4              Jodi Picoult
# 5         Curtis Sittenfeld
# 7            Steven  Rowley
# 9             Helen Oyeyemi
# 14                 Jung Yun
# 17         Bette Lee Crosby
# 18         Tiffany McDaniel
# 21             Louise Penny
# 22                Ruth Ware
# 23                J.D. Robb
# 24               B.A. Paris
#
#                                           description          format  \
# 0   Six responsible adults. Three cute kids. One s...       Hardcover
# 1   As the daughter of a meth dealer, Wavy knows n...       Hardcover
# 2   Northern California, during the violent end of...       Hardcover
# 3   <i>A warm, funny and acutely perceptive debut ...       Hardcover
# 4   Ruth Jefferson is a labor and delivery nurse a...       Hardcover
# 5   This version of the Bennet family and Mr. Darc...       Hardcover
# 7                   Combining the emotional depth of        Hardcover
# 9   The key to a house, the key to a heart, the ke...       Hardcover
# 14  <b>Why should a man care for his parents when ...       Hardcover
# 17  On the day Jennifer Green was born a pile of s...  Kindle Edition
# 18  <b>Fielding Bliss has never forgotten the summ...       Hardcover
# 21  Bestselling author Louise Penny pulls back the...       Hardcover
# 22  Lo Blacklock, a journalist who writes for a tr...       Hardcover
# 23  Dennis Mira just had two unpleasant surprises....       Hardcover
# 24  Everyone knows a couple like Jack and Grace: h...       Hardcover
#
#             genre      month  pages             publisher  rating  \
# 0         Fiction       July    415        Flatiron Books    3.56
# 1         Fiction     August    346    Thomas Dunne Books    4.07
# 2         Fiction       June    355          Random House    3.47
# 3         Fiction      March    368                  Ecco    3.42
# 4         Fiction    October    480      Ballantine Books    4.35
# 5         Fiction      April    492          Random House    3.61
# 7         Fiction       June    307       Simon  Schuster    3.72
# 9   Short Stories      March    325       Riverhead Books    3.63
# 14        Fiction      March    326               Picador    3.73
# 17        Fiction  September    248  Bent Pine Publishing    4.23
# 18        Fiction       July    310    St. Martin's Press    3.93
# 21        Mystery     August    389        Minotaur Books    4.42
# 22        Mystery       July    340   Gallery/Scout Press    3.68
# 23        Mystery   February    388               Berkley    4.36
# 24       Thriller     August    293    St. Martin's Press    3.94
#
#                                 title    year  best_seller
# 0                  Truly Madly Guilty  2016.0            0
# 1   All the Ugly and Wonderful Things  2016.0            0
# 2                           The Girls  2016.0            0
# 3                            The Nest  2016.0            0
# 4                  Small Great Things  2016.0            0
# 5                            Eligible  2016.0            0
# 7                Lily and the Octopus  2016.0            0
# 9      What is Not Yours is Not Yours  2016.0            0
# 14                            Shelter  2016.0            0
# 17                     Silver Threads  2016.0            0
# 18  The Summer that Melted Everything  2016.0            0
# 21                  A Great Reckoning  2016.0            0
# 22              The Woman in Cabin 10  2016.0            0
# 23               Brotherhood in Death  2016.0            0
# 24                Behind Closed Doors  2016.0            0

# %%
all_books.columns

all_books.head()
# Out:
#                     author                                        description  \
# 0           Liane Moriarty  Six responsible adults. Three cute kids. One s...
# 1           Bryn Greenwood  As the daughter of a meth dealer, Wavy knows n...
# 2               Emma Cline  Northern California, during the violent end of...
# 3  Cynthia D'Aprix Sweeney  <i>A warm, funny and acutely perceptive debut ...
# 4             Jodi Picoult  Ruth Jefferson is a labor and delivery nurse a...
#
#       format    genre    month  pages           publisher  rating  \
# 0  Hardcover  Fiction     July    415      Flatiron Books    3.56
# 1  Hardcover  Fiction   August    346  Thomas Dunne Books    4.07
# 2  Hardcover  Fiction     June    355        Random House    3.47
# 3  Hardcover  Fiction    March    368                Ecco    3.42
# 4  Hardcover  Fiction  October    480    Ballantine Books    4.35
#
#                                title    year  best_seller
# 0                 Truly Madly Guilty  2016.0            0
# 1  All the Ugly and Wonderful Things  2016.0            0
# 2                          The Girls  2016.0            0
# 3                           The Nest  2016.0            0
# 4                 Small Great Things  2016.0            0

# %%
# export dataframe
#all_books.to_csv('csv_files/9_1_all_books_df.csv', encoding='utf-8', index=False)
