# %% [markdown]
# # Good Reads Books Dataframe

# %%
from bs4 import BeautifulSoup as bs
import urllib.request
import requests
import re
import time
import pandas as pd

# %%
url_2018 = 'https://www.goodreads.com/list/show/129936.NYT_100_Notable_Books_of_2018'
r = urllib.request.urlopen(url_2018)

soup = bs(r, 'html.parser')

# %%
url_2017 = 'https://www.goodreads.com/list/show/117971.100_Notable_Books_of_2017_The_New_York_Times_'
r2017 = urllib.request.urlopen(url_2017)

soup2017 = bs(r2017, 'html.parser')

# %%
url_2016 = 'https://www.goodreads.com/list/show/105933.New_York_Times_100_Notable_Books_of_2016'
r2016 = urllib.request.urlopen(url_2016)

soup2016 = bs(r2016, 'html.parser')

# %%
s2017 = soup2017.find_all('div', {"data-resource-type":"Book"})

# %%
s2017[0].a['href']
# Out:
# '/book/show/29496076-killers-of-the-flower-moon'

# %%
#data-resource-type="Book"
s = soup.find_all('div', {"data-resource-type":"Book"})
s[0].a['href']
# Out:
# '/book/show/35657511-warlight'

# %%
len(s)
# Out:
# 100

# %%
s2016 = soup2016.find_all('div', {"data-resource-type":"Book"})

# %%
s2016[0].a['href']
# Out:
# '/book/show/27071490-homegoing'

# %%
nyt_2018 = []
s = soup.find_all('div', {"data-resource-type":"Book"})
for i in range(len(s)):
    nyt_2018.append('https://www.goodreads.com' +s[i].a['href'])

# %%
nyt_2017 = []
s = soup2017.find_all('div', {"data-resource-type":"Book"})
for i in range(len(s2017)):
    nyt_2017.append('https://www.goodreads.com' +s[i].a['href'])

# %%
nyt_2016 = []
s = soup2016.find_all('div', {"data-resource-type":"Book"})
for i in range(len(s2016)):
    nyt_2016.append('https://www.goodreads.com' +s[i].a['href'])

# %%
nyt_2017[0]
# Out:
# 'https://www.goodreads.com/book/show/29496076-killers-of-the-flower-moon'

# %%
nyt_2018[0]
# Out:
# 'https://www.goodreads.com/book/show/35657511-warlight'

# %%
nyt_2016[0]
# Out:
# 'https://www.goodreads.com/book/show/27071490-homegoing'

# %%
def get_rating(soup):    
    get_rating = soup.find('span',{"itemprop":"ratingValue"})
    get_rating = get_rating.get_text().replace('\n', '').replace(' ', '')
    return get_rating

# %%
def get_title(soup):
    get_title = soup.find('h1',{"id":"bookTitle"})
    get_title = get_title.get_text().replace('\n', '').replace('  ', '')
    return get_title

# %%
def get_author(soup):
    get_author = soup.find('span', {'itemprop':"name"})
    get_author = get_author.get_text()
    return get_author

# %%
def get_publisher(soup):
    get_publisher = soup.find('div', {'id':"details"})
    get_publisher = get_publisher.contents[3].get_text()
    get_publisher = get_publisher.replace('\n', '')
    get_publisher = re.findall(r'(?<=by ).+\b', get_publisher)[0]
    return get_publisher

# %%
def get_date(soup):
    get_date = soup.find('div', {'id':"details"})
    get_date = get_date.contents[3].get_text()
    get_date = get_date.replace('\n', '')
    get_date = re.findall(r'((?<=Published        ).+\b)(\d{4})', get_date)[0]
    return get_date
def get_month_day(soup):
    get_month_day = get_date(soup)[0]
    return get_month_day
def get_month(soup):
    get_month = get_date(soup)[0].split(' ')[0]
    return get_month
def get_year(soup):
    get_year = get_date(soup)[1]
    return get_year

# %%
def get_pages(soup):
    get_pages = soup.find('span', {'itemprop':"numberOfPages"})
    get_pages = get_pages.get_text().split(' ')[0]
    return get_pages

# %%
def get_genre(soup):
    get_genre = soup.find('a', {'class':"actionLinkLite bookPageGenreLink"})
    get_genre = get_genre.get_text()
    return get_genre

# %%
def get_descrip(soup):
    get_descrip = soup.find('div', {'id':"description"})
    get_descrip = get_descrip.find('span').contents[0]
    return get_descrip

# %%
def get_format(soup):
    get_format = soup.find('span', {'itemprop':"bookFormat"})
    get_format = get_format.get_text()
    return get_format

# %%
# take a list and return a list of dictionaries

def book_info(url):
    all_the_books = []
    for x in url:
        link = x
        #link = 'https://www.goodreads.com/book/show/6148028-catching-fire?from_choice=true'
        #probably add timer here
        time.sleep(1)
        page = urllib.request.urlopen(link)
        soup = bs(page, 'html.parser')
        try:
            dictionary = {'rating': get_rating(soup), 'author': get_author(soup), 'publisher' : get_publisher(soup),'title':get_title(soup), 'pages': get_pages(soup),
             'description': get_descrip(soup), 'format': get_format(soup), 'genre': get_genre(soup), 'year': get_year(soup), 'month': get_month(soup)}
        except:
            try:
                dictionary = {'rating': get_rating(soup), 'author': get_author(soup),'publisher' : get_publisher(soup), 'title':get_title(soup), 'pages': get_pages(soup),
                 'description': get_descrip(soup), 'format': get_format(soup), 'genre': get_genre(soup)}
            except:
                pass
        all_the_books.append(dictionary)
    #print(all_the_books)
    return all_the_books

# %%
all_books = book_info(nyt_2018)

# %%
all_books
# Out:
# [{'rating': '3.73',
#   'author': 'Michael Ondaatje',
#   'publisher': 'Jonathan Cape                          (first published May 8th 2018',
#   'title': 'Warlight',
#   'pages': '304',
#   'description': 'In a narrative as mysterious as memory itself – at once both shadowed and luminous – ',
#   'format': 'Paperback',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.01',
#   'author': 'Tayari Jones',
#   'publisher': 'Algonquin Books                          (first published January 29th 2018',
#   'title': 'An American Marriage',
#   'pages': '308',
#   'description': 'Newlyweds Celestial and Roy are the embodiment of both the American Dream and the New South. He is a young executive, and she is an artist on the brink of an exciting career. But as they settle into the routine of their life together, they are ripped apart by circumstances neither could have imagined. In this deft exploration of love, loyalty, race, justice, and both Black',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.07',
#   'author': 'Tommy Orange',
#   'publisher': 'Knopf',
#   'title': 'There There',
#   'pages': '294',
#   'description': 'Fierce, angry, funny, heartbreaking—Tommy Orange’s first novel is a wondrous and shattering portrait of an America few of us have ever seen, and it introduces a brilliant new author at the start of a major career. ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.60',
#   'author': 'Lisa Halliday',
#   'publisher': 'Simon & Schuster',
#   'title': 'Asymmetry',
#   'pages': '277',
#   'description': 'A singularly inventive and unforgettable debut novel about love, luck, and the inextricability of life and art, from 2017 Whiting Award winner Lisa Halliday.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.25',
#   'author': 'Richard Powers',
#   'publisher': 'W. W. Norton & Company',
#   'title': 'The Overstory',
#   'pages': '502',
#   'description': 'An Air Force loadmaster in the Vietnam War is shot out of the sky, then saved by falling into a banyan. An artist inherits a hundred years of photographic portraits, all of the same doomed American chestnut. A hard-partying undergraduate in the late 1980s electrocutes herself, dies, and is sent back into life by creatures of air and light. A hearing- and speech-impaired sc',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.34',
#   'author': 'Michael Pollan',
#   'publisher': 'Allen Lane                          (first published May 15th 2018',
#   'title': 'How to Change Your Mind: What the New Science of Psychedelics Teaches Us About Consciousness, Dying, Addiction, Depression, and Transcendence',
#   'pages': '480',
#   'description': <b>Could psychedelic drugs change our worldview? One of America's most admired writers takes us on a mind-altering journey to the frontiers of human consciousness</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.53',
#   'author': 'Rachel Kushner',
#   'publisher': 'Scribner',
#   'title': 'The Mars Room',
#   'pages': '338',
#   'description': 'It’s 2003 and Romy Hall is at the start of two consecutive life sentences at Stanville Women’s Correctional Facility, deep in California’s Central Valley. Outside is the world from which she has been severed: the San Francisco of her youth and her young son, Jackson. Inside is a new reality: thousands of women hustling for the bare essentials needed to survive; the bluffin',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.02',
#   'author': 'Denis Johnson',
#   'publisher': 'Random House',
#   'title': 'The Largesse of the Sea Maiden',
#   'pages': '207',
#   'description': <i>The Largesse of the Sea Maiden </i>,
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.02',
#   'author': 'Denis Johnson',
#   'publisher': 'Random House',
#   'title': 'The Largesse of the Sea Maiden',
#   'pages': '207',
#   'description': <i>The Largesse of the Sea Maiden </i>,
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.16',
#   'author': 'Beth Macy',
#   'publisher': 'Little, Brown and Company',
#   'title': 'Dopesick: Dealers, Doctors, and the Drug Company that Addicted America',
#   'pages': '384',
#   'description': "Beth Macy takes us into the epicenter of America's twenty-plus year struggle with opioid addiction. From distressed small communities in Central Appalachia to wealthy suburbs; from disparate cities to once-idyllic farm towns; it's a heartbreaking trajectory that illustrates how this national crisis has persisted for so long and become so firmly entrenched. ",
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.44',
#   'author': 'Jill Lepore',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'These Truths: A History of the United States',
#   'pages': '933',
#   'description': <strong>In the most ambitious one-volume American history in decades, award-winning historian and <em>New Yorker</em> writer Jill Lepore offers a magisterial account of the origins and rise of a divided nation, an urgently needed reckoning with the beauty and tragedy of American history.</strong>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.00',
#   'author': 'Akwaeke Emezi',
#   'publisher': 'Grove Press',
#   'title': 'Freshwater',
#   'pages': '229',
#   'description': 'An extraordinary debut novel, ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.48',
#   'author': 'Tara Westover',
#   'publisher': 'Random House',
#   'title': 'Educated',
#   'pages': '334',
#   'description': <strong>An unforgettable memoir in the tradition of <em>The Glass Castle</em> about a young girl who, kept out of school, leaves her survivalist family and goes on to earn a PhD from Cambridge University</strong>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '3.76',
#   'author': 'Ottessa Moshfegh',
#   'publisher': 'Jonathan Cape                          (first published July 10th 2018',
#   'title': 'My Year of Rest and Relaxation',
#   'pages': '304',
#   'description': 'A shocking, hilarious and strangely tender novel about a young woman’s experiment in narcotic hibernation, aided and abetted by one of the worst psychiatrists in the annals of literature. Our narrator has many of the advantages of life, on the surface. Young, thin, pretty, a recent Columbia graduate, she lives in an apartment on the Upper East Side of Manhattan paid for, l',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.84',
#   'author': 'Sigrid Nunez',
#   'publisher': 'Riverhead Books',
#   'title': 'The Friend',
#   'pages': '213',
#   'description': <b>A moving story of love, friendship, grief, healing, and the magical bond between a woman and her dog.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.01',
#   'author': 'Luis Alberto Urrea',
#   'publisher': 'Little, Brown and Company',
#   'title': 'The House of Broken Angels',
#   'pages': '336',
#   'description': <b>The definitive Mexican-American immigrant story, a sprawling and deeply felt portrait of a Mexican-American family occasioned by the impending loss of its patriarch, from one of the country's most beloved authors.</b>,
#   'format': 'Kindle Edition',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.26',
#   'author': 'Anand Giridharadas',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'Winners Take All: The Elite Charade of Changing the World',
#   'pages': '288',
#   'description': <b>An insider's groundbreaking investigation of how the global elite's efforts to "change the world" preserve the status quo and obscure their role in causing the problems they later seek to solve.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.26',
#   'author': 'Anand Giridharadas',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'Winners Take All: The Elite Charade of Changing the World',
#   'pages': '288',
#   'description': <b>An insider's groundbreaking investigation of how the global elite's efforts to "change the world" preserve the status quo and obscure their role in causing the problems they later seek to solve.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.47',
#   'author': 'John Carreyrou',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'Bad Blood: Secrets and Lies in a Silicon Valley Startup',
#   'pages': '299',
#   'description': 'The full inside story of the breathtaking rise and shocking collapse of Theranos, the multibillion-dollar biotech startup, by the prize-winning journalist who first broke the story and pursued it to the end, despite pressure from its charismatic CEO and threats by her lawyers. ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.06',
#   'author': 'Michael   Lewis',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'The Fifth Risk',
#   'pages': '219',
#   'description': 'What are the consequences if the people given control over our government have no idea how it works?',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '4.07',
#   'author': 'Lawrence Wright',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'God Save Texas: A Journey Into the Soul of the Lone Star State',
#   'pages': '352',
#   'description': <b>With humor and the biting insight of a native, the Pulitzer Prize-winning author of <i>The Looming Tower</i> explores the history, culture, and politics of Texas, while holding the stereotypes up for rigorous scrutiny.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.42',
#   'author': 'Kiese Laymon',
#   'publisher': 'Scribner',
#   'title': 'Heavy: An American Memoir',
#   'pages': '256',
#   'description': <b>In this powerful and provocative memoir, genre-bending essayist and novelist Kiese Laymon explores what the weight of a lifetime of secrets, lies, and deception does to a black body, a black family, and a nation teetering on the brink of moral collapse.</b>,
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.71',
#   'author': 'Daisy Johnson',
#   'publisher': 'Jonathan Cape',
#   'title': 'Everything Under',
#   'pages': '264',
#   'description': 'Words are important to Gretel, always have been. As a child, she lived on a canal boat with her mother, and together they invented a language that was just their own. She hasn’t seen her mother since the age of sixteen, though – almost a lifetime ago – and those memories have faded. Now Gretel works as a lexicographer, updating dictionary entries, which suits her solitary',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.12',
#   'author': 'Rebecca Makkai',
#   'publisher': 'Viking',
#   'title': 'The Great Believers',
#   'pages': '421',
#   'description': 'A dazzling new novel of friendship and redemption in the face of tragedy and loss set in 1980s Chicago and contemporary Paris, by the acclaimed and award-winning author Rebecca Makkai.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.64',
#   'author': 'Meg Wolitzer',
#   'publisher': 'Riverhead Books',
#   'title': 'The Female Persuasion',
#   'pages': '454',
#   'description': "Greer Kadetsky is a shy college freshman when she meets the woman she hopes will change her life. Faith Frank, dazzlingly persuasive and elegant at sixty-three, has been a central pillar of the women's movement for decades, a figure who inspires others to influence the world. Upon hearing Faith speak for the first time, Greer--madly in love with her boyfriend, Cory, but st",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.61',
#   'author': 'Andrew     Martin',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Early Work',
#   'pages': '240',
#   'description': 'A wry, supersmart, seriocomic first novel from a prodigious talent—a ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.18',
#   'author': 'Nana Kwame Adjei-Brenyah',
#   'publisher': 'Mariner Books',
#   'title': 'Friday Black',
#   'pages': '208',
#   'description': 'In the stories of Adjei-Brenyah’s debut, an amusement park lets players enter augmented reality to hunt terrorists or shoot intruders played by minority actors, a school shooting results in both the victim and gunman stuck in a shared purgatory, and an author sells his soul to a many-tongued god.',
#   'format': 'Paperback',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '4.06',
#   'author': 'Esi Edugyan',
#   'publisher': 'Knopf Publishing Group                          (first published August 2nd 2018',
#   'title': 'Washington Black',
#   'pages': '339',
#   'description': 'Washington Black is an eleven-year-old field slave who knows no other life than the Barbados sugar plantation where he was born. ',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.59',
#   'author': 'Alan Hollinghurst',
#   'publisher': 'Picador',
#   'title': 'The Sparsholt Affair',
#   'pages': '454',
#   'description': 'In 1940, Evert Dax and David Sparsholt, two young men from very different backgrounds, meet at Oxford University. Dax is a second year student reading English, coming from a rackety upper middle class background; Sparsholt is from a humbler Midlands community and is reading engineering, a young man whose good looks and fine figure have proved highly attractive to his peers',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.43',
#   'author': 'Leïla Slimani',
#   'publisher': 'Penguin Books                          (first published August 18th 2016',
#   'title': 'The Perfect Nanny',
#   'pages': '228',
#   'description': <b>*One of the 10 BEST BOOKS OF THE YEAR of The New York Times Book Review*<br/><br/>*National Bestseller*<br/><br/>“A great novel . . . Incredibly engaging and disturbing . . . You read the entire novel knowing something terrible is coming. In that, Slimani has us in her thrall.” —Roxane Gay, <i>New York Times</i> bestselling author of <i>Bad Feminist</i> and <i>Hunger</i><br/><br/>“A book . . . that I’ve thought about prett</b>,
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'January'},
#  {'rating': '4.10',
#   'author': 'Karl Ove Knausgård',
#   'publisher': 'Archipelago                          (first published 2011',
#   'title': 'The End',
#   'pages': '1160',
#   'description': 'In the critically acclaimed autobiographical novel work, My Struggle, explores Karl Ove Knaus Farm mercilessly and even releasing his own life, his ambitions and weaknesses, its uncertainty and doubt, his relationships with friends and lovers, wife and children, mother and father.',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2011',
#   'month': 'September'},
#  {'rating': '4.38',
#   'author': 'Adam Tooze',
#   'publisher': 'Viking',
#   'title': 'Crashed: How a Decade of Financial Crises Changed the World',
#   'pages': '720',
#   'description': <b> <b>"An intelligent explanation of the mechanisms that produced the crisis and the response to it...One of the great strengths of Tooze's book is to demonstrate the deeply intertwined nature of the European and American financial systems."</b> <b> <i>--The New York Times Book Review</i> </b> <b></b> <br/><b></b> <br/><b>From a prizewinning economic historian, an eye-opening reinterpretation of the 2008 economic crisis (</b></b>,
#   'format': 'Hardcover',
#   'genre': 'Economics',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.42',
#   'author': 'Ronen Bergman',
#   'publisher': 'John Murray                          (first published January 30th 2018',
#   'title': "Rise and Kill First: The Secret History of Israel's Targeted Assassinations",
#   'pages': '760',
#   'description': 'The page-turning, news-breaking, inside account of Israel’s state-sponsored assassination programs, from the man hailed by David Remnick as “arguably [Israel’s] best investigative reporter.”',
#   'format': 'Paperback',
#   'genre': 'History',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.62',
#   'author': 'Nico Walker',
#   'publisher': 'Jonathan Cape                          (first published August 14th 2018',
#   'title': 'Cherry',
#   'pages': '336',
#   'description': 'Cleveland, Ohio, 2003. A young man is just a college freshman when he meets Emily. They share a passion for Edward Albee and ecstasy and fall hard and fast in love. But soon Emily has to move home to Elba, New York, and he flunks out of school and joins the army. Desperate to keep their relationship alive, they marry before he ships out to Iraq. But as an army medic, he is',
#   'format': 'Hardcover',
#   'genre': 'Fiction'},
#  {'rating': '4.07',
#   'author': 'Jenny Erpenbeck',
#   'publisher': 'Portobello Books                          (first published August 31st 2015',
#   'title': 'Go, Went, Gone',
#   'pages': '304',
#   'description': "One of the great contemporary European writers takes on Europe's biggest issue.",
#   'format': 'Kindle Edition',
#   'genre': 'Fiction',
#   'year': '2015',
#   'month': 'September'},
#  {'rating': '4.20',
#   'author': 'Susan Orlean',
#   'publisher': 'Simon  Schuster',
#   'title': 'The Library Book',
#   'pages': '318',
#   'description': 'On the morning of April 28, 1986, a fire alarm sounded in the Los Angeles Public Library. As the moments passed, the patrons and staff who had been cleared out of the building realized this was not the usual fire alarm. As one fireman recounted, “Once that first stack got going, it was ‘Goodbye, Charlie.’” The fire was disastrous: it reached 2000 degrees and burned for mor',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.27',
#   'author': 'Dorthe Nors',
#   'publisher': 'Pushkin Press                          (first published February 2nd 2016',
#   'title': 'Mirror, Shoulder, Signal',
#   'pages': '139',
#   'description': <p> <strong>A spikily funny, startlingly perceptive and beautifully written novel about modern life by the brightest light in Danish fiction</strong> </p>,
#   'format': 'Kindle Edition',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'February'},
#  {'rating': '4.03',
#   'author': 'William Trevor',
#   'publisher': 'Viking',
#   'title': 'Last Stories',
#   'pages': '224',
#   'description': 'With a career that spanned more than half a century, William Trevor was regarded as one of the greatest writers of short stories in the English language. Now, in ',
#   'format': 'Kindle Edition',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.74',
#   'author': 'Homer',
#   'publisher': 'W. W. Norton  Company                          (first published -720',
#   'title': 'The Odyssey',
#   'pages': '582',
#   'description': 'The first great adventure story in the Western canon, ',
#   'format': 'Hardcover',
#   'genre': 'Classics',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '3.66',
#   'author': 'Gary Shteyngart',
#   'publisher': 'Random House',
#   'title': 'Lake Success',
#   'pages': '339',
#   'description': "Myopic, narcissistic, hilariously self-deluded and divorced from the real world as most of us know it, hedge fund manager Barry Cohen oversees $2.4 billion in assets. Deeply stressed by an SEC investigation and by his 3 year-old-son's diagnosis of autism, he flees New York on a Greyhound bus in search of a simpler, more romantic life with his old college sweetheart, whom h",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.44',
#   'author': 'Jo Nesbø',
#   'publisher': 'Hogarth',
#   'title': 'Macbeth',
#   'pages': '512',
#   'description': <b>He’s the best cop they’ve got. </b>,
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.31',
#   'author': 'Naomi Novik',
#   'publisher': 'Del Rey',
#   'title': 'Spinning Silver',
#   'pages': '480',
#   'description': "Miryem is the daughter and granddaughter of moneylenders... but her father isn't a very good one. Free to lend and reluctant to collect, he has loaned out most of his wife's dowry and left the family on the edge of poverty--until Miryem steps in. Hardening her heart against her fellow villagers' pleas, she sets out to collect what is owed--and finds herself more than up to",
#   'format': 'Kindle Edition',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.85',
#   'author': 'Patrick Chamoiseau',
#   'publisher': 'The New Press                          (first published April 1st 1999',
#   'title': 'Slave Old Man',
#   'pages': '176',
#   'description': <p>From one of the most innovative and subversive novelists writing in French, a "writer of exceptional and original gifts" (<em>The New York Times</em>), whose <em>Texaco</em> won the Prix Goncourt and has been translated into fourteen languages, Patrick Chamoiseau's <em>The Old Slave</em> is a gripping, profoundly unsettling story of an elderly slave's daring escape into the wild from a plantation in</p>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '1999',
#   'month': 'May'},
#  {'rating': '3.84',
#   'author': 'Nick Drnaso',
#   'publisher': 'Drawn and Quarterly',
#   'title': 'Sabrina',
#   'pages': '204',
#   'description': <b>Video games, conspiracy theories, breakdown, murder: Everything’s gonna be all right—until it isn’t...</b>,
#   'format': 'Hardcover',
#   'genre': 'Sequential Art',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.12',
#   'author': 'Tracy K. Smith',
#   'publisher': 'Graywolf Press',
#   'title': 'Wade in the Water: Poems',
#   'pages': '96',
#   'description': <p> <b>The extraordinary new poetry collection by Tracy K. Smith, the Poet Laureate of the United States</b> </p>,
#   'format': 'Kindle Edition',
#   'genre': 'Poetry',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.63',
#   'author': 'Tana French',
#   'publisher': 'Viking',
#   'title': 'The Witch Elm',
#   'pages': '464',
#   'description': "Toby is a happy-go-lucky charmer who's dodged a scrape at work and is celebrating with friends when the night takes a turn that will change his life: he surprises two burglars who beat him and leave him for dead. Struggling to recover from his injuries, beginning to understand that he might never be the same man again, he takes refuge at his family's ancestral home to care",
#   'format': 'ebook',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.19',
#   'author': 'Nafkote Tamirat',
#   'publisher': 'Henry Holt and Co',
#   'title': 'The Parking Lot Attendant',
#   'pages': '240',
#   'description': <b>A mesmerizing, indelible coming-of-age story about a girl in Boston's tightly-knit Ethiopian community who falls under the spell of a charismatic hustler out to change the world</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '3.87',
#   'author': 'Alyssa Cole',
#   'publisher': 'Avon',
#   'title': 'A Princess in Theory',
#   'pages': '360',
#   'description': <strong> <em>From acclaimed author Alyssa Cole comes the tale of a city Cinderella </em> </strong>,
#   'format': 'Mass Market Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '2.95',
#   'author': 'Christine Schutt',
#   'publisher': 'Grove Atlantic',
#   'title': 'Pure Hollywood: And Other Stories',
#   'pages': '144',
#   'description': 'In 11 captivating tales, ',
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.40',
#   'author': 'Sam Anderson',
#   'publisher': 'Crown',
#   'title': 'Boom Town: The Fantastical Saga of Oklahoma City, Its Chaotic Founding, Its Apocalyptic Weather, Its Purloined Basketball Team, and the Dream of Becoming a World-class Metropolis',
#   'pages': '448',
#   'description': <b>Award-winning journalist Sam Anderson’s long-awaited debut is a brilliant, kaleidoscopic narrative of Oklahoma City--a great American story of civics, basketball, and destiny.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '3.91',
#   'author': 'Ling  Ma',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Severance',
#   'pages': '304',
#   'description': 'An offbeat office novel turns apocalyptic satire as a young woman transforms from orphan to worker bee to survivor',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.25',
#   'author': 'Deborah Levy',
#   'publisher': 'Bloomsbury Publishing',
#   'title': 'The Cost of Living: A Working Autobiography',
#   'pages': '144',
#   'description': <b>A searching examination of all the dimensions of love, marriage, mourning, and kinship from two-time Booker Prize finalist Deborah Levy.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.22',
#   'author': 'Greg Lukianoff',
#   'publisher': 'Penguin Press                          (first published July 17th 2018',
#   'title': 'The Coddling of the American Mind: How Good Intentions and Bad Ideas Are Setting Up a Generation for Failure',
#   'pages': '352',
#   'description': <b>A timely investigation into the campus assault on free speech and what it means for students, education, and our democracy.</b>,
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.12',
#   'author': 'Caryl Phillips',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'A View of the Empire at Sunset',
#   'pages': '324',
#   'description': 'A gripping novelization of the life of Jean Rhys, the author of Wide Sargasso Sea',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.24',
#   'author': 'Steven Pinker',
#   'publisher': 'Viking',
#   'title': 'Enlightenment Now: The Case for Reason, Science, Humanism, and Progress',
#   'pages': '576',
#   'description': "The follow-up to Pinker's groundbreaking ",
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.02',
#   'author': "Keith  O'Brien",
#   'publisher': 'Eamon Dolan/Houghton Mifflin Harcourt',
#   'title': 'Fly Girls: How Five Daring Women Defied All Odds and Made Aviation History',
#   'pages': '352',
#   'description': <br/>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.28',
#   'author': 'Eliza Griswold',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Amity and Prosperity: One Family and the Fracturing of America',
#   'pages': '336',
#   'description': <b>Prize-winning poet and journalist Eliza Griswold's <i>Amity and Prosperity</i> is an expose on how fracking shattered a rural Pennsylvania town, and how one lifelong resident brought the story into the national spotlight. This is an incredible true account of investigative journalism and a devastating indictment of energy politics in America.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.86',
#   'author': 'Ramachandra Guha',
#   'publisher': 'Random House Canada',
#   'title': 'Gandhi: The Years That Changed the World, 1914-1948',
#   'pages': '1102',
#   'description': <b> <b>An epic and revelatory biography of one of the most abidingly influential--and controversial--men in modern history.</b> </b>,
#   'format': 'Kindle Edition',
#   'genre': 'Biography',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.86',
#   'author': 'Ramachandra Guha',
#   'publisher': 'Random House Canada',
#   'title': 'Gandhi: The Years That Changed the World, 1914-1948',
#   'pages': '1102',
#   'description': <b> <b>An epic and revelatory biography of one of the most abidingly influential--and controversial--men in modern history.</b> </b>,
#   'format': 'Kindle Edition',
#   'genre': 'Biography',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.92',
#   'author': 'Sally Field',
#   'publisher': 'Hachette Audio',
#   'title': 'In Pieces',
#   'pages': '399',
#   'description': 'One of the most celebrated, beloved, and enduring actors of our time, Sally Field has an infectious charm that has captivated the nation for more than five decades, beginning with her first TV role at the age of seventeen.',
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.16',
#   'author': 'Alice Bolin',
#   'publisher': 'William Morrow Paperbacks',
#   'title': 'Dead Girls: Essays on Surviving an American Obsession',
#   'pages': '288',
#   'description': 'A collection of poignant, perceptive essays that expertly blends the personal and political in an exploration of American culture through the lens of our obsession with dead women.',
#   'format': 'ebook',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.90',
#   'author': 'Lauren Hilgers',
#   'publisher': 'Crown Publishing Group (NY',
#   'title': 'Patriot Number One: American Dreams in Chinatown',
#   'pages': '336',
#   'description': <b>A deeply reported look at the Chinese immigrant community in the United States, casting a new light on what it means to seek the American dream</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '3.90',
#   'author': 'Lauren Hilgers',
#   'publisher': 'Crown Publishing Group (NY',
#   'title': 'Patriot Number One: American Dreams in Chinatown',
#   'pages': '336',
#   'description': <b>A deeply reported look at the Chinese immigrant community in the United States, casting a new light on what it means to seek the American dream</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.17',
#   'author': 'Emily X.R. Pan',
#   'publisher': 'Little, Brown Books for Young Readers',
#   'title': 'The Astonishing Color of After',
#   'pages': '462',
#   'description': 'Leigh Chen Sanders is absolutely certain about one thing: When her mother died by suicide, she turned into a bird.',
#   'format': 'Hardcover',
#   'genre': 'Young Adult',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.12',
#   'author': 'Kevin Young',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'Brown: Poems',
#   'pages': '161',
#   'description': <b>James Brown. John Brown's raid. Brown v. the Topeka Board of Ed. The prize-winning author of <i>Blue Laws</i> meditates on all things "brown" in this powerful new collection.</b>,
#   'format': 'Hardcover',
#   'genre': 'Poetry',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.15',
#   'author': 'Joanne B. Freeman',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'The Field of Blood: Violence in Congress and the Road to Civil War',
#   'pages': '480',
#   'description': <b>The previously untold story of the violence in Congress that helped spark the Civil War</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.45',
#   'author': 'Olivia Laing',
#   'publisher': 'W. W. Norton  Company                          (first published June 28th 2018',
#   'title': 'Crudo',
#   'pages': '143',
#   'description': 'A brilliant, funny, and emphatically raw novel of love on the brink of the apocalypse, from the acclaimed author of ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.82',
#   'author': 'Dara Horn',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'Eternal Life',
#   'pages': '256',
#   'description': 'Rachel is a woman with a problem: she can’t die. Her recent troubles—widowhood, a failing business, an unemployed middle-aged son—are only the latest in a litany spanning dozens of countries, scores of marriages, and hundreds of children. In the 2,000 years since she made a spiritual bargain to save the life of her first son back in Roman-occupied Jerusalem, she’s tried ev',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.37',
#   'author': 'David W. Blight',
#   'publisher': 'Simon & Schuster',
#   'title': 'Frederick Douglass: Prophet of Freedom',
#   'pages': '912',
#   'description': <b>A <i>NEW YORK TIMES</i>, <i>WALL STREET JOURNAL</i>, and <i>TIME</i> TOP 10 BOOK OF THE YEAR</b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '4.26',
#   'author': 'Adam Winkler',
#   'publisher': 'Liveright',
#   'title': 'We the Corporations: How American Businesses Won Their Civil Rights',
#   'pages': '496',
#   'description': <em>We the Corporations</em>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.26',
#   'author': 'Adam Winkler',
#   'publisher': 'Liveright',
#   'title': 'We the Corporations: How American Businesses Won Their Civil Rights',
#   'pages': '496',
#   'description': <em>We the Corporations</em>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '3.58',
#   'author': 'Joan Silber',
#   'publisher': 'Counterpoint                          (first published November 14th 2017',
#   'title': 'Improvement',
#   'pages': '256',
#   'description': 'One of our most gifted writers of fiction returns with a bold and piercing novel about a young single mother living in New York, her eccentric aunt, and the decisions they make that have unexpected implications for the world around them. ',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.58',
#   'author': 'Joan Silber',
#   'publisher': 'Counterpoint                          (first published November 14th 2017',
#   'title': 'Improvement',
#   'pages': '256',
#   'description': 'One of our most gifted writers of fiction returns with a bold and piercing novel about a young single mother living in New York, her eccentric aunt, and the decisions they make that have unexpected implications for the world around them. ',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '4.25',
#   'author': 'Romain Gary',
#   'publisher': 'New Directions                          (first published April 16th 1980',
#   'title': 'The Kites',
#   'pages': '384',
#   'description': 'On a small farm in Normandy, as Hitler rises to power in Germany, young Ludo comes of age in the care of his Uncle Ambrose, an eccentric mailman, kite-maker, and pacifist. Ludo’s quiet existence changes the day he meets Lila, a girl from the aristocratic Polish family who own the estate next door. In a single glance, Ludo instantly falls in love forever; Lila, on the other',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '1980',
#   'month': 'October'},
#  {'rating': '3.41',
#   'author': 'Craig  Brown',
#   'publisher': 'Farrar, Straus and Giroux                          (first published September 21st 2017',
#   'title': 'Ninety-Nine Glimpses of Princess Margaret',
#   'pages': '423',
#   'description': <b>A witty and profound portrait of the most talked-about English royal</b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.36',
#   'author': 'Mario Vargas Llosa',
#   'publisher': 'Farrar, Straus and Giroux                          (first published March 3rd 2016',
#   'title': 'The Neighborhood',
#   'pages': '256',
#   'description': <b>A thrilling tale of desire and Peruvian corruption swirls around a scandalous expose that leads to murder</b>,
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'February'},
#  {'rating': '3.63',
#   'author': 'Lawrence Osborne',
#   'publisher': 'Hogarth Press',
#   'title': 'Only to Sleep: A Philip Marlowe Novel',
#   'pages': '259',
#   'description': <b>The new Philip Marlowe novel, from Lawrence Osborne, a master of the psychological thriller</b>,
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.92',
#   'author': 'Lionel Shriver',
#   'publisher': 'Harper',
#   'title': 'Property: Stories Between Two Novellas',
#   'pages': '336',
#   'description': 'A striking new collection of ten short stories and two novellas that explores the idea of property in every meaning of the word, from the acclaimed ',
#   'format': 'ebook',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.59',
#   'author': 'Neel Mukherjee',
#   'publisher': 'W. W. Norton  Company                          (first published July 6th 2017',
#   'title': 'A State of Freedom',
#   'pages': '278',
#   'description': <b>A devastating and powerful vision of a people defined by that most unquenchable human urge, the striving for a different life.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'January'},
#  {'rating': '4.50',
#   'author': 'Jonathan Eig',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'title': 'Ali: A Life',
#   'pages': '640',
#   'description': 'The definitive biography of an American icon, from a\xa0',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.50',
#   'author': 'Jonathan Eig',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'title': 'Ali: A Life',
#   'pages': '640',
#   'description': 'The definitive biography of an American icon, from a\xa0',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.01',
#   'author': 'Victoria  Johnson',
#   'publisher': 'Liveright',
#   'title': 'American Eden: David Hosack, Botany, and Medicine in the Garden of the Early Republic',
#   'pages': '480',
#   'description': 'On a clear morning in July 1804, Alexander Hamilton stepped onto a boat at the edge of the Hudson River. He was bound for a New Jersey dueling ground to settle his bitter dispute with Aaron Burr. Hamilton took just two men with him: his “second” for the duel, and Dr. David Hosack.',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.29',
#   'author': 'Shane Bauer',
#   'publisher': 'Penguin Press',
#   'title': "American Prison: A Reporter's Undercover Journey into the Business of Punishment",
#   'pages': '318',
#   'description': <b>A groundbreaking and brave inside reckoning with the nexus of prison and profit in America in one Louisiana prison and over the course of our country's history. </b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.19',
#   'author': 'Raymond Arsenault',
#   'publisher': 'Simon  Schuster',
#   'title': 'Arthur Ashe: A Life',
#   'pages': '784',
#   'description': <b>A <i>NEW YORK TIMES </i>NOTABLE BOOK</b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.24',
#   'author': 'Marwan Hisham',
#   'publisher': 'One World',
#   'title': 'Brothers of the Gun: A Memoir of the Syrian War',
#   'pages': '320',
#   'description': <b>A bracingly immediate memoir by a young man coming of age during the Syrian war, <i>Brothers of the Gun</i> is an intimate lens on the century's bloodiest conflict and a profound meditation on kinship, home, and freedom.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.50',
#   'author': 'Andrew Roberts',
#   'publisher': 'Allen Lane                          (first published October 4th 2018',
#   'title': 'Churchill: Walking with Destiny',
#   'pages': '1105',
#   'description': 'A landmark reconsideration of the iconoclastic war leader, based on extensive new material--from private letters to war cabinet meetings-- by the bestselling, award-winning author of ',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2018',
#   'month': 'November'},
#  {'rating': '4.04',
#   'author': 'Catherine Nixey',
#   'publisher': 'Macmillan',
#   'title': 'The Darkening Age: The Christian Destruction of the Classical World',
#   'pages': '352',
#   'description': <i>The Darkening Age</i>,
#   'format': 'Kindle Edition',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.68',
#   'author': 'Paige  Williams',
#   'publisher': 'Hachette Books',
#   'title': "The Dinosaur Artist: Obsession, Betrayal, and the Quest for Earth's Ultimate Trophy",
#   'pages': '432',
#   'description': 'In 2012, a New York auction catalogue boasted an unusual offering: "a superb Tyrannosaurus skeleton." In fact, Lot 49135 consisted of a nearly complete ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.39',
#   'author': 'Michael Massing',
#   'publisher': 'Harper/HarperCollins Publishers L.L.C.                          (first published February 2018',
#   'title': 'Fatal Discord: Erasmus, Luther, and the Fight for the Western Mind',
#   'pages': '1008',
#   'description': <strong>An engrossing dual biography and fascinating intellectual history that examines two of the greatest minds of European history—Erasmus of Rotterdam and Martin Luther—whose heated rivalry gave rise to two enduring, fundamental, and often colliding traditions of philosophical and religious thought.</strong>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '3.81',
#   'author': 'Zadie Smith',
#   'publisher': 'Penguin Press',
#   'title': 'Feel Free: Essays',
#   'pages': '448',
#   'description': "Since she burst spectacularly into view with her debut novel almost two decades ago, Zadie Smith has established herself not just as one of the world's preeminent fiction writers, but also a brilliant and singular essayist. She contributes regularly to ",
#   'format': 'Kindle Edition',
#   'genre': 'Writing',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.22',
#   'author': 'Rachel Slade',
#   'publisher': 'Ecco',
#   'title': 'Into the Raging Sea: Thirty-Three Mariners, One Megastorm, and the Sinking of El Faro',
#   'pages': '416',
#   'description': 'On October 1, 2015, Hurricane Joaquin barreled into the Bermuda Triangle and swallowed the container ship ',
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.22',
#   'author': 'Rachel Slade',
#   'publisher': 'Ecco',
#   'title': 'Into the Raging Sea: Thirty-Three Mariners, One Megastorm, and the Sinking of El Faro',
#   'pages': '416',
#   'description': 'On October 1, 2015, Hurricane Joaquin barreled into the Bermuda Triangle and swallowed the container ship ',
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.17',
#   'author': 'Darnell L. Moore',
#   'publisher': 'Bold Type Books',
#   'title': 'No Ashes in the Fire: Coming of Age Black and Free in America',
#   'pages': '243',
#   'description': <b>From a leading journalist and activist comes a brave, beautifully wrought survival story of navigating childhood during the height of the AIDS and crack epidemics, searching for intimacy and love as a young gay man, and ultimately finding a calling fighting for justice and liberation in the Black Lives Matter and LGBTQ movements.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.33',
#   'author': 'Rania Abouzeid',
#   'publisher': 'W. W. Norton  Company                          (first published 2018',
#   'title': 'No Turning Back: Life, Loss, and Hope in Wartime Syria',
#   'pages': '378',
#   'description': 'Extending back to the first demonstrations of 2011, ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '3.96',
#   'author': 'Deborah Blum',
#   'publisher': 'Penguin Press',
#   'title': "The Poison Squad: One Chemist's Single-Minded Crusade for Food Safety at the Turn of the Twentieth Century",
#   'pages': '352',
#   'description': <b> <b>A <i>New York Times</i> Notable Book </b> </b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.18',
#   'author': 'Carl Zimmer',
#   'publisher': 'Dutton',
#   'title': "She Has Her Mother's Laugh: The Powers, Perversions, and Potential of Heredity",
#   'pages': '544',
#   'description': 'Carl Zimmer presents a history of our understanding of heredity in this sweeping, resonating overview of a force that shaped human society--a force set to shape our future even more radically.',
#   'format': 'Hardcover',
#   'genre': 'Science',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.94',
#   'author': 'Lisa Brennan-Jobs',
#   'publisher': 'Grove Press',
#   'title': 'Small Fry',
#   'pages': '383',
#   'description': "Born on a farm and named in a field by her parents--artist Chrisann Brennan and Steve Jobs--Lisa Brennan-Jobs's childhood unfolded in a rapidly changing Silicon Valley. When she was young, Lisa's father was a mythical figure who was rarely present in her life. As she grew older, her father took an interest in her, ushering her into a new world of mansions, vacations, and p",
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.45',
#   'author': 'Wesley Yang',
#   'publisher': 'W. W. Norton & Company',
#   'title': 'The Souls of Yellow Folk: Essays',
#   'pages': '256',
#   'description': <p>The National Magazine Award–winning writer’s debut collection of incisive, stylish essays on race and gender.</p>,
#   'format': 'Kindle Edition',
#   'genre': 'Writing',
#   'year': '2018',
#   'month': 'November'},
#  {'rating': '4.05',
#   'author': 'David Quammen',
#   'publisher': 'Simon  Schuster',
#   'title': 'The Tangled Tree: A Radical New History of Life',
#   'pages': '480',
#   'description': <b>Nonpareil science writer David Quammen explains how recent discoveries in molecular biology can change our understanding of evolution and life’s history, with powerful implications for human health and even our own human nature. </b>,
#   'format': 'Hardcover',
#   'genre': 'Science',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '3.82',
#   'author': 'Casey Gerald',
#   'publisher': 'Riverhead Books',
#   'title': 'There Will Be No Miracles Here: A Memoir',
#   'pages': '400',
#   'description': <b>NAMED A BEST BOOK OF 2018 BY <i>THE NEW YORK TIMES</i><br/><br/>"Somehow Casey Gerald has pulled off the most urgently political, most deeply personal, and most engagingly spiritual statement of our time by just looking outside his window and inside himself. Extraordinary." - Marlon James<br/><br/>"Staccato prose and peripatetic storytelling combine the cadences of the Bible with an urgency reminisc</b>,
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2018',
#   'month': 'October'}]

# %%
len(all_books)
# Out:
# 100

# %%
all_books_2017 = book_info(nyt_2017)

# %%
all_books_2017
# Out:
# [{'rating': '4.11',
#   'author': 'David Grann',
#   'publisher': 'Doubleday',
#   'title': 'Killers of the Flower Moon: The Osage Murders and the Birth of the FBI',
#   'pages': '359',
#   'description': 'In the 1920s, the richest people per capita in the world were members of the Osage Indian Nation in Oklahoma. After oil was discovered beneath their land, the Osage rode in chauffeured automobiles, built mansions, and sent their children to study in Europe.',
#   'format': 'ebook',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '3.79',
#   'author': 'George Saunders',
#   'publisher': 'Random House',
#   'title': 'Lincoln in the Bardo',
#   'pages': '343',
#   'description': 'In his long-awaited first novel, American master George Saunders delivers his most original, transcendent, and moving work yet. Unfolding in a graveyard over the course of a single night, narrated by a dazzling chorus of voices, Lincoln in the Bardo is a literary experience unlike any other—for no one but Saunders could conceive it.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '4.26',
#   'author': 'Min Jin Lee',
#   'publisher': 'Grand Central Publishing',
#   'title': 'Pachinko',
#   'pages': '489',
#   'description': <i>Pachinko</i>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '3.81',
#   'author': 'Mohsin Hamid',
#   'publisher': 'Riverhead                          (first published March 2nd 2017',
#   'title': 'Exit West',
#   'pages': '231',
#   'description': 'In a country teetering on the brink of civil war, two young people meet—sensual, fiercely independent Nadia and gentle, restrained Saeed. They embark on a furtive love affair and are soon cloistered in a premature intimacy by the unrest roiling their city. When it explodes, turning familiar streets into a patchwork of checkpoints and bomb blasts, they begin to hear whisper',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '3.72',
#   'author': 'Ali Smith',
#   'publisher': 'Pantheon Books                          (first published October 20th 2016',
#   'title': 'Autumn',
#   'pages': '263',
#   'description': "Autumn. Season of mists and mellow fruitfulness. That's what it felt like for Keats in 1819. How about Autumn 2016? Daniel is a century old. Elisabeth, born in 1984, has her eye on the future. The United Kingdom is in pieces, divided by a historic, once-in-a-generation summer.Love is won, love is lost. Hope is hand-in-hand with hopelessness. The seasons roll round, as ever",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'February'},
#  {'rating': '4.44',
#   'author': 'Ta-Nehisi Coates',
#   'publisher': 'One World',
#   'title': 'We Were Eight Years in Power: An American Tragedy',
#   'pages': '367',
#   'description': '"We were eight years in power" was the lament of Reconstruction-era black politicians as the American experiment in multiracial democracy ended with the return of white supremacist rule in the South. Now Ta-Nehisi Coates explores the tragic echoes of that history in our own time: the unprecedented election of a black president followed by a vicious backlash that fueled the',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.04',
#   'author': 'Jesmyn Ward',
#   'publisher': 'Scribner',
#   'title': 'Sing, Unburied, Sing',
#   'pages': '285',
#   'description': 'Jesmyn Ward’s first novel since her National Book Award–winning ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.88',
#   'author': 'Naomi Alderman',
#   'publisher': 'Viking                          (first published October 27th 2016',
#   'title': 'The Power',
#   'pages': '341',
#   'description': 'In ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.44',
#   'author': 'Trevor Noah',
#   'publisher': 'Doubleday Canada',
#   'title': 'Born a Crime: Stories From a South African Childhood',
#   'pages': '304',
#   'description': 'The compelling, inspiring, and comically sublime New York Times bestseller about one man’s coming-of-age, set during the twilight of apartheid and the tumultuous days of freedom that followed.',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'November'},
#  {'rating': '3.63',
#   'author': 'Sarah Perry',
#   'publisher': 'Custom House                          (first published May 27th 2016',
#   'title': 'The Essex Serpent',
#   'pages': '422',
#   'description': "Set in Victorian London and an Essex village in the 1890's, and enlivened by the debates on scientific and medical discovery which defined the era, ",
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '4.03',
#   'author': 'Ayọ̀bámi Adébáyọ̀',
#   'publisher': 'Knopf Publishing Group                          (first published March 2nd 2017',
#   'title': 'Stay with Me',
#   'pages': '260',
#   'description': 'Yejide and Akin have been married since they met and fell in love at university. Though many expected Akin to take several wives, he and Yejide have always agreed: polygamy is not for them. But four years into their marriage--after consulting fertility doctors and healers, trying strange teas and unlikely cures--Yejide is still not pregnant. She assumes she still has time-',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '4.09',
#   'author': 'Kamila Shamsie',
#   'publisher': 'Riverhead Books',
#   'title': 'Home Fire',
#   'pages': '276',
#   'description': 'The suspenseful and heartbreaking story of an immigrant family driven to pit love against loyalty, with devastating consequences ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.55',
#   'author': 'David Grossman',
#   'publisher': 'Alfred A. Knopf                          (first published August 2014',
#   'title': 'A Horse Walks into a Bar',
#   'pages': '208',
#   'description': <b>The award-winning and internationally acclaimed author of the <i>To the End of the Land </i>now gives us a searing short novel about the life of a stand-up comic, as revealed in the course of one evening's performance. In the dance between comic and audience, with barbs flying back and forth, a deeper story begins to take shape--one that will alter the lives of many of those in a</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2014',
#   'month': 'February'},
#  {'rating': '3.77',
#   'author': 'Elizabeth Strout',
#   'publisher': 'Random House',
#   'title': 'Anything Is Possible',
#   'pages': '254',
#   'description': 'Short story collection ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '4.33',
#   'author': 'Gail Honeyman',
#   'publisher': 'Viking - Pamela Dorman Books',
#   'title': 'Eleanor Oliphant Is Completely Fine',
#   'pages': '327',
#   'description': 'No one’s ever told Eleanor that life should be better than fine. ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '3.64',
#   'author': 'Jennifer Egan',
#   'publisher': 'Scribner',
#   'title': 'Manhattan Beach',
#   'pages': '438',
#   'description': <b>The daring and magnificent novel from the Pulitzer Prize–winning author of A Visit from the Goon Squad.</b>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '3.83',
#   'author': 'Patricia Lockwood',
#   'publisher': 'Riverhead Books',
#   'title': 'Priestdaddy: A Memoir',
#   'pages': '336',
#   'description': 'The childhood of Patricia Lockwood, the poet dubbed "The Smutty-Metaphor Queen of Lawrence, Kansas" by ',
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '3.80',
#   'author': 'Andrew Sean Greer',
#   'publisher': 'Lee Boudreaux Books',
#   'title': 'Less',
#   'pages': '272',
#   'description': '8 hours, 20 minutes',
#   'format': 'ebook',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'July'},
#  {'rating': '4.14',
#   'author': 'Amy Goldstein',
#   'publisher': 'Simon & Schuster',
#   'title': 'Janesville: An American Story',
#   'pages': '368',
#   'description': <b>* <i>Financial Times</i> and McKinsey Business Book of the Year * </b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '3.54',
#   'author': 'Dava Sobel',
#   'publisher': 'Viking',
#   'title': 'The Glass Universe: How the Ladies of the Harvard Observatory Took the Measure of the Stars',
#   'pages': '336',
#   'description': <b>Author Dava Sobel returns with the little-known true story of a group of women whose contributions to the burgeoning field of astronomy forever changed our understanding of the stars and our place in the universe</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'December'},
#  {'rating': '3.89',
#   'author': 'Paul Auster',
#   'publisher': 'Henry Holt and Co.                          (first published January 2017',
#   'title': '4 3 2 1',
#   'pages': '866',
#   'description': <b>Astonishing, a masterpiece, Paul Auster’s greatest, most satisfying, most vivid and heartbreaking novel -- a sweeping and surprising story of inheritance, family, love and life itself.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'January'},
#  {'rating': '3.89',
#   'author': 'Viet Thanh Nguyen',
#   'publisher': 'Grove Press',
#   'title': 'The Refugees',
#   'pages': '209',
#   'description': 'From a young Vietnamese refugee who suffers profound culture shock when he comes to live with two gay men in San Francisco, to a woman whose husband is suffering from dementia and starts to confuse her for a former lover, to a girl living in Ho Chi Minh City whose older half-sister comes back from America having seemingly accomplished everything she never will, the stories',
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '4.34',
#   'author': 'Dan Egan',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'The Death and Life of the Great Lakes',
#   'pages': '364',
#   'description': <strong>A master reporter’s landmark work of contemporary ecology.</strong>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '3.91',
#   'author': 'Douglas Preston',
#   'publisher': 'Grand Central Publishing',
#   'title': 'The Lost City of the Monkey God: A True Story',
#   'pages': '328',
#   'description': <b>A five-hundred-year-old legend. An ancient curse. A stunning medical mystery. And a pioneering journey into the unknown heart of the world's densest jungle.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'January'},
#  {'rating': '3.54',
#   'author': 'Louise Erdrich',
#   'publisher': 'Harper',
#   'title': 'Future Home of the Living God',
#   'pages': '263',
#   'description': 'Louise Erdrich, the ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '3.69',
#   'author': 'Hari Kunzru',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'White Tears',
#   'pages': '271',
#   'description': 'From one of the most talented fiction writers at work today: two ambitious young musicians are drawn into the dark underworld of blues record collecting, haunted by the ghosts of a repressive past.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '3.79',
#   'author': 'Margaret Wilkerson Sexton',
#   'publisher': 'Counterpoint LLC',
#   'title': 'A Kind of Freedom',
#   'pages': '256',
#   'description': 'Evelyn is a Creole woman who comes of age in New Orleans at the height of World War Two. Her family inhabits the upper echelon of Black society and when she falls for no-name Renard, she is forced to choose between her life of privilege and the man she loves.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.64',
#   'author': 'Pankaj Mishra',
#   'publisher': 'Farrar, Straus and Giroux                          (first published January 26th 2017',
#   'title': 'Age of Anger: A History of the Present',
#   'pages': '416',
#   'description': <b>One of our most important public intellectuals reveals the hidden history of our current global crisis</b>,
#   'format': 'ebook',
#   'genre': 'Politics',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '3.81',
#   'author': 'Joshua  Green',
#   'publisher': 'Penguin Press',
#   'title': "Devil's Bargain: Steve Bannon, Donald Trump, and the Storming of the Presidency",
#   'pages': '286',
#   'description': <b>From the reporter who was there at the very beginning comes the revealing inside story of the partnership between Steve Bannon and Donald Trump—the key to understanding the rise of the alt-right, the fall of Hillary Clinton, and the hidden forces that drove the greatest upset in American political history. </b>,
#   'format': 'Kindle Edition',
#   'genre': 'Politics',
#   'year': '2017',
#   'month': 'July'},
#  {'rating': '3.87',
#   'author': 'Rachel Cusk',
#   'publisher': 'Farrar, Straus and Giroux                          (first published September 29th 2016',
#   'title': 'Transit',
#   'pages': '272',
#   'description': <b>The stunning second novel of a trilogy that began with <i>Outline</i>, one of <i>The New York Times Book Review</i>’s ten best books of 2015</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'January'},
#  {'rating': '4.14',
#   'author': 'Yuri Slezkine',
#   'publisher': 'Princeton University Press                          (first published August 15th 2017',
#   'title': 'The House of Government: A Saga of the Russian Revolution',
#   'pages': '1096',
#   'description': <i>The House of Government</i>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.81',
#   'author': 'Omar El Akkad',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'American War',
#   'pages': '333',
#   'description': 'Sarat Chestnut, born in Louisiana, is only six when the Second American Civil War breaks out in 2074. But even she knows that oil is outlawed, that Louisiana is half underwater, that unmanned drones fill the sky. And when her father is killed and her family is forced into Camp Patience for displaced persons, she quickly begins to be shaped by her particular time and place',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '3.64',
#   'author': 'Elif Batuman',
#   'publisher': 'Penguin Press',
#   'title': 'The Idiot',
#   'pages': '423',
#   'description': <b>A portrait of the artist as a young woman. A novel about not just discovering but inventing oneself.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '4.39',
#   'author': 'Julia Wertz',
#   'publisher': 'Black Dog & Leventhal',
#   'title': 'Tenements, Towers & Trash: An Unconventional Illustrated History of New York City',
#   'pages': '284',
#   'description': <b>A <i>New York Times</i> Notable Book of 2017!<br/><br/>Here is New York, </b>,
#   'format': 'Hardcover',
#   'genre': 'Sequential Art',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '3.65',
#   'author': 'Gabriel Tallent',
#   'publisher': 'Riverhead Books                          (first published April 29th 2017',
#   'title': 'My Absolute Darling',
#   'pages': '417',
#   'description': 'Turtle Alveston is a survivor. At fourteen, she roams the woods along the northern California coast. The creeks, tide pools, and rocky islands are her haunts and her hiding grounds, and she is known to wander for miles. But while her physical world is expansive, her personal one is small and treacherous: Turtle has grown up isolated since the death of her mother, in the th',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '4.00',
#   'author': 'Jessica Bruder',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'Nomadland: Surviving America in the Twenty-First Century',
#   'pages': '273',
#   'description': "From the beet fields of North Dakota to the wilderness campgrounds of California to an Amazon warehouse in Texas, people who once might have kicked back to enjoy their sunset years are hard at work. Underwater on mortgages or finding that Social Security comes up short, they're hitting the road in astonishing numbers, forming a new community of nomads: RV and van-dwelling",
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '4.12',
#   'author': 'Ganesh Sitaraman',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'The Crisis of the Middle-Class Constitution: Why Economic Inequality Threatens Our Republic',
#   'pages': '432',
#   'description': <b>In this original, provocative contribution to the debate over economic inequality, Ganesh Sitaraman argues that a strong and sizable middle class is a prerequisite for America's constitutional system. </b>,
#   'format': 'Hardcover',
#   'genre': 'Politics',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '4.22',
#   'author': 'Chris Hayes',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'A Colony in a Nation',
#   'pages': '256',
#   'description': 'America likes to tell itself that it inhabits a post-racial world, but nearly every empirical measure—wealth, unemployment, incarceration, school segregation—reveals that racial inequality hasn’t improved since 1968. With the clarity and originality that distinguished his prescient bestseller ',
#   'format': 'Hardcover',
#   'genre': 'Politics',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '4.26',
#   'author': 'Jack E. Davis',
#   'publisher': 'Liveright',
#   'title': 'The Gulf: The Making of An American Sea',
#   'pages': '608',
#   'description': 'When painter Winslow Homer first sailed into the Gulf of Mexico, he was struck by its "special kind of providence." Indeed, the Gulf presented itself as America’s sea—bound by geography, culture, and tradition to the national experience—and yet, there has never been a comprehensive history of the Gulf until now. And so, in this rich and original work that explores the Gulf',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '3.98',
#   'author': 'Rachel Aspden',
#   'publisher': 'Harvill Secker                          (first published February 4th 2016',
#   'title': 'Generation Revolution: On the Front Line Between Tradition and Change in the Middle East',
#   'pages': '272',
#   'description': "In 2003, Rachel Aspden arrived in Egypt as a 23-year-old trainee journalist. She found a country on the brink of change. Of Egypt's 80 million citizens, two-thirds were under 30. The new generation were stifled, broken and frustrated – caught between a dictatorship with nothing to offer them and autocratic parents still clinging to tradition and obedience after a lifetime",
#   'format': 'Paperback',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '4.18',
#   'author': 'David M.  Barnett',
#   'publisher': 'Trapeze                          (first published January 19th 2017',
#   'title': 'Calling Major Tom',
#   'pages': '304',
#   'description': <p> <b><i>Calling Major Tom</i> is a heartwarming, quirky and ultimately life-affirming story of friendship, family and forgiveness - and the world's most unlikely astronaut. </b> </p>,
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'June'},
#  {'rating': '4.12',
#   'author': 'Maya Jasanoff',
#   'publisher': 'Penguin Press                          (first published 2017',
#   'title': 'The Dawn Watch: Joseph Conrad in a Global World',
#   'pages': '375',
#   'description': <b>From one of America's most exciting historians, the astonishing life and times of Joseph Conrad, a visionary guide to the turbulent age of globalization</b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '4.01',
#   'author': 'Alice Kaplan',
#   'publisher': 'University of Chicago Press',
#   'title': 'Looking for The Stranger: Albert Camus and the Life of a Literary Classic',
#   'pages': '288',
#   'description': <i>The Stranger</i>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '4.25',
#   'author': 'Edmund Gordon',
#   'publisher': 'Chatto & Windus',
#   'title': 'The Invention of Angela Carter: A Biography',
#   'pages': '544',
#   'description': 'Angela Carter is widely acknowledged as one of the most important and beguiling writers of the last century. Her work stands out for its bawdiness and linguistic zest, its hospitality to the fantastic and the absurd, and its extraordinary inventiveness and range. Her life was as modern and as unconventional as anything in her fiction.',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.69',
#   'author': 'Ottessa Moshfegh',
#   'publisher': 'Penguin Press',
#   'title': 'Homesick for Another World',
#   'pages': '294',
#   'description': <b>An electrifying first collection from one of the most exciting short story writers of our time.</b>,
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2017',
#   'month': 'January'},
#  {'rating': '3.60',
#   'author': 'Margaret Drabble',
#   'publisher': 'Farrar, Straus and Giroux                          (first published November 3rd 2016',
#   'title': 'The Dark Flood Rises',
#   'pages': '325',
#   'description': <b>A magnificently mordant reckoning with mortality by the great British novelist</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'February'},
#  {'rating': '4.03',
#   'author': 'Edward Stourton',
#   'publisher': 'Doubleday',
#   'title': "Auntie's War: The BBC during the Second World War",
#   'pages': '432',
#   'description': 'The British Broadcasting Corporation is a British institution unlike any other, and its story during the Second World War is also our story. This was Britain’s first total war, engaging the whole nation, and the wireless played a crucial role in it. For the first time, news of the conflict reached every living room – sometimes almost as it happened; and at key moments – Ch',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '3.60',
#   'author': 'Lauren Elkin',
#   'publisher': ' Farrar, Straus and Giroux',
#   'title': 'Flâneuse: Women Walk the City in Paris, New York, Tokyo, Venice and London',
#   'pages': '336',
#   'description': <i>'Flâneuse [flanne-euhze], noun, from the French. Feminine form of flâneur [flanne-euhr], an idler, a dawdling observer, usually found in cities.<br/><br/>That is an imaginary definition.'</i>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction'},
#  {'rating': '4.00',
#   'author': 'Anthony DeCurtis',
#   'publisher': 'Little, Brown and Company',
#   'title': 'Lou Reed: A Life',
#   'pages': '528',
#   'description': <strong>The essential biography of one of music's most influential icons: Lou Reed</strong>,
#   'format': 'Hardcover',
#   'genre': 'Music',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.21',
#   'author': 'Masha Gessen',
#   'publisher': 'Riverhead Books',
#   'title': 'The Future Is History: How Totalitarianism Reclaimed Russia',
#   'pages': '515',
#   'description': 'The essential journalist and bestselling biographer of Vladimir Putin reveals how, in the space of a generation, Russia surrendered to a more virulent and invincible new strain of autocracy. ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '3.24',
#   'author': 'Richard Flanagan',
#   'publisher': 'Chatto  Windus                          (first published October 2nd 2017',
#   'title': 'First Person',
#   'pages': '400',
#   'description': <b>Six weeks to write for your life... In this blistering story of a ghostwriter haunted by his demonic subject, the Man Booker Prize winner turns to lies, crime and literature with devastating effect</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '3.59',
#   'author': 'John Banville',
#   'publisher': 'Hamish Hamilton',
#   'title': 'Mrs Osmond',
#   'pages': '368',
#   'description': <b>A rich historical novel about the aftermath of betrayal, from the Booker prize-winning author.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '3.88',
#   'author': 'Matt Haig',
#   'publisher': 'Viking                          (first published July 6th 2017',
#   'title': 'How to Stop Time',
#   'pages': '325',
#   'description': <b> <b><b>"The first rule is that you don't fall in love, ' he said... 'There are other rules too, but that is the main one. No falling in love. No staying in love. No daydreaming of love. If you stick to this you will just about be okay.'"</b> </b> </b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '4.16',
#   'author': 'Naomi Klein',
#   'publisher': 'Allen Lane                          (first published June 7th 2017',
#   'title': 'No Is Not Enough: Defeating the New Shock Politics',
#   'pages': '273',
#   'description': <b>Naomi Klein - award-winning journalist, bestselling author of <i>No Logo</i>, <i>The Shock Doctrine</i> and <i>This Changes Everything</i>, scourge of brand bullies and corporate liars - gives us the toolkit we need to survive our surreal, shocking age.</b>,
#   'format': 'Paperback',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'June'},
#  {'rating': '3.63',
#   'author': 'Rachel Seiffert',
#   'publisher': 'Pantheon Books                          (first published May 30th 2017',
#   'title': 'A Boy in Winter',
#   'pages': '256',
#   'description': <b>From the award-winning author of the Booker Prize short-listed <i>The Dark Room</i> a startling portrait of the Nazis' arrival in Ukraine as they move to implement the final solution.</b>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.99',
#   'author': 'Hillary Rodham Clinton',
#   'publisher': 'Simon & Schuster',
#   'title': 'What Happened',
#   'pages': '512',
#   'description': <b>“In the past, for reasons I try to explain, I’ve often felt I had to be careful in public, like I was up on a wire without a net. Now I’m letting my guard down.”</b>,
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.45',
#   'author': 'Hideo Yokoyama',
#   'publisher': 'Farrar, Straus and Giroux                          (first published October 2012',
#   'title': 'Six Four',
#   'pages': '576',
#   'description': <i>Six Four</i>,
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2012',
#   'month': 'February'},
#  {'rating': '3.08',
#   'author': 'Judith Newman',
#   'publisher': 'Quercus',
#   'title': 'To Siri With Love: A Mother, Her Autistic Son, and the Kindness of a Machine',
#   'pages': '240',
#   'description': "Writer Judith Newman never had any illusions that her family was 'normal'. She and her husband keep separate apartments-his filled with twin grand pianos as befits a former opera singer; hers filled with the clutter and chaos of twin adolescent boys conceived late in life. And one of those boys is Gus, her sweet, complicated, autistic 13-year-old.",
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '3.98',
#   'author': 'Michael   Lewis',
#   'publisher': 'W. W. Norton  Company                          (first published December 6th 2016',
#   'title': 'The Undoing Project: A Friendship That Changed Our Minds',
#   'pages': '368',
#   'description': 'Forty years ago, Israeli psychologists Daniel Kahneman and Amos Tversky wrote a series of breathtakingly original papers that invented the field of behavioral economics. One of the greatest partnerships in the history of science, Kahneman and Tversky’s extraordinary friendship incited a revolution in Big Data studies, advanced evidence-based medicine, led to a new approach',
#   'format': 'Paperback',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.62',
#   'author': 'Franklin Foer',
#   'publisher': 'Penguin Press',
#   'title': 'World Without Mind: The Existential Threat of Big Tech',
#   'pages': '272',
#   'description': 'Franklin Foer reveals the existential threat posed by big tech, and in his brilliant polemic gives us the toolkit to fight their pervasive influence. ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.62',
#   'author': 'Franklin Foer',
#   'publisher': 'Penguin Press',
#   'title': 'World Without Mind: The Existential Threat of Big Tech',
#   'pages': '272',
#   'description': 'Franklin Foer reveals the existential threat posed by big tech, and in his brilliant polemic gives us the toolkit to fight their pervasive influence. ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '2.90',
#   'author': 'Katie Kitamura',
#   'publisher': 'Riverhead Books',
#   'title': 'A Separation',
#   'pages': '231',
#   'description': "A mesmerizing, psychologically taut novel about a marriage's end and the secrets we all carry. ",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '3.92',
#   'author': 'Domenico Starnone',
#   'publisher': 'Europa                          (first published October 14th 2014',
#   'title': 'Ties',
#   'pages': '150',
#   'description': <i>Ties</i>,
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2014',
#   'month': '2015'},
#  {'rating': '4.05',
#   'author': 'Thomas E. Ricks',
#   'publisher': 'Penguin Press',
#   'title': 'Churchill and Orwell: The Fight for Freedom',
#   'pages': '352',
#   'description': <b>From #1 <i>New York Times</i> bestselling author Thomas E. Ricks, a dual biography of Winston Churchill and George Orwell, whose farsighted vision and inspired action preserved democracy from the threats of authoritarianism, from the left and right alike.</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '4.04',
#   'author': 'Richard O. Prum',
#   'publisher': 'Doubleday Books',
#   'title': "The Evolution of Beauty: How Darwin's Forgotten Theory of Mate Choice Shapes the Animal World—And Us",
#   'pages': '448',
#   'description': <b>A major reimagining of how evolutionary forces work, revealing how mating preferences--what Darwin termed "the taste for the beautiful"--create the extraordinary range of ornament in the animal world. </b>,
#   'format': 'Hardcover',
#   'genre': 'Science',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '4.08',
#   'author': 'Gordon S. Wood',
#   'publisher': 'Penguin Press',
#   'title': 'Friends Divided: John Adams and Thomas Jefferson',
#   'pages': '512',
#   'description': <b>From the great historian of the American Revolution, New York Times-bestselling and Pulitzer-winning Gordon Wood, comes a majestic dual biography of two of America's most enduringly fascinating figures, whose partnership helped birth a nation, and whose subsequent falling out did much to fix its course.</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.07',
#   'author': 'Caroline Fraser',
#   'publisher': 'Metropolitan Books                          (first published November 14th 2017',
#   'title': 'Prairie Fires: The American Dreams of Laura Ingalls Wilder',
#   'pages': '640',
#   'description': <b>The first comprehensive historical biography of Laura Ingalls Wilder, the beloved author of the <i>Little House on the Prairie</i> books</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '3.95',
#   'author': 'James McBride',
#   'publisher': 'Riverhead Books',
#   'title': 'Five-Carat Soul',
#   'pages': '320',
#   'description': 'The stories in ',
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.80',
#   'author': 'Victor LaValle',
#   'publisher': 'Spiegel & Grau',
#   'title': 'The Changeling',
#   'pages': '431',
#   'description': <b>One man’s thrilling journey through an enchanted world to find his wife, who has disappeared after seemingly committing an unforgiveable act of violence, from the award-winning author of the <i>The Devil in Silver</i> and <i>Big Machine</i>.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2017',
#   'month': 'June'},
#  {'rating': '3.63',
#   'author': 'Jeffrey Eugenides',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Fresh Complaint',
#   'pages': '285',
#   'description': <b>The first collection of short fiction from the Pulitzer Prize-winning author Jeffrey Eugenides</b>,
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '3.62',
#   'author': 'Alice McDermott',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'The Ninth Hour',
#   'pages': '247',
#   'description': <b>A magnificent new novel from one of America’s finest writers—a powerfully affecting story spanning the twentieth century of a widow and her daughter and the nuns who serve their Irish-American community in Brooklyn.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '4.56',
#   'author': 'Ron Chernow',
#   'publisher': 'Penguin Press',
#   'title': 'Grant',
#   'pages': '1074',
#   'description': <b>Pulitzer Prize-winner and biographer of Alexander Hamilton, George Washington, and John D. Rockefeller, Ron Chernow returns with a sweeping and dramatic portrait of one of America's most complicated generals and presidents, Ulysses S. Grant.</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '3.63',
#   'author': 'Dylan Krieger',
#   'publisher': 'Delete Press',
#   'title': 'Giving Godhead',
#   'pages': '82',
#   'description': 'As its suggestively punning title implies, Giving Godhead is a volume of poetry that challenges the boundary between the sacred and the obscene by conflating biblical images of “holy” acquiescence with sexually deviant forms of submission characteristic of BDSM roleplaying. This conflation of saintly and sinful acts of submission naturally centers around a meditation on Ch',
#   'format': 'Paperback',
#   'genre': 'Poetry',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '3.23',
#   'author': 'Danzy Senna',
#   'publisher': 'Riverhead Books',
#   'title': 'New People',
#   'pages': '240',
#   'description': 'From the bestselling author of ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '4.40',
#   'author': 'Layli Long Soldier',
#   'publisher': 'Graywolf Press',
#   'title': 'Whereas',
#   'pages': '110',
#   'description': <b>The astonishing, powerful debut by the winner of a 2016 Whiting Writers' Award</b>,
#   'format': 'Paperback',
#   'genre': 'Poetry',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '3.09',
#   'author': 'Nicole Krauss',
#   'publisher': 'Harper                          (first published 2017',
#   'title': 'Forest Dark',
#   'pages': '304',
#   'description': 'Jules Epstein, a man whose drive, avidity, and outsized personality have, for sixty-eight years, been a force to be reckoned with, is undergoing a metamorphosis. In the wake of his parents’ deaths, his divorce from his wife of more than thirty years, and his retirement from the New York legal firm where he was a partner, he’s felt an irresistible need to give away his poss',
#   'format': 'ebook',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.90',
#   'author': 'Elena Passarello',
#   'publisher': 'Sarabande Books',
#   'title': 'Animals Strike Curious Poses',
#   'pages': '200',
#   'description': 'Beginning with Yuka, a 39,000 year old mummified woolly mammoth recently found in the Siberian permafrost, each of the 16 essays in ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '4.16',
#   'author': 'Frances FitzGerald',
#   'publisher': 'Simon  Schuster',
#   'title': 'The Evangelicals: The Struggle to Shape America',
#   'pages': '752',
#   'description': <b>“A page turner…We have long needed a fair-minded overview of this vitally important religious sensibility, and FitzGerald has now provided it.” —<i>The New York Times Book Review</i></b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '4.38',
#   'author': 'N.K. Jemisin',
#   'publisher': 'Orbit',
#   'title': 'The Stone Sky',
#   'pages': '416',
#   'description': 'THIS IS THE WAY THE WORLD ENDS... FOR THE LAST TIME.',
#   'format': 'Paperback',
#   'genre': 'Fantasy',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '4.24',
#   'author': 'Timothy B. Tyson',
#   'publisher': 'Simon & Schuster',
#   'title': 'The Blood of Emmett Till',
#   'pages': '291',
#   'description': 'This extraordinary ',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'January'},
#  {'rating': '4.20',
#   'author': 'Graham Allison',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'title': 'Destined for War: Can America and China Escape Thucydides’s Trap?',
#   'pages': '384',
#   'description': <b>CHINA AND THE UNITED STATES ARE HEADING TOWARD A WAR NEITHER WANTS. </b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '4.26',
#   'author': 'Elizabeth Hardwick',
#   'publisher': 'New York Review of Books                          (first published 2017',
#   'title': 'The Collected Essays of Elizabeth Hardwick',
#   'pages': '610',
#   'description': 'An NYRB Classics Original',
#   'format': 'Paperback',
#   'genre': 'Writing',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.43',
#   'author': 'Richard Rothstein',
#   'publisher': 'Liveright',
#   'title': 'The Color of Law: A Forgotten History of How Our Government Segregated America',
#   'pages': '368',
#   'description': 'In this groundbreaking history of the modern American metropolis, Richard Rothstein, a leading authority on housing policy, explodes the myth that America’s cities came to be racially divided through ',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '3.81',
#   'author': 'Adam Federman',
#   'publisher': 'Chelsea Green Publishing Company                          (first published June 2nd 2017',
#   'title': 'Fasting and Feasting: The Life of Visionary Food Writer Patience Gray',
#   'pages': '400',
#   'description': 'For more than thirty years, Patience Gray--author of the celebrated cookbook ',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '3.81',
#   'author': 'Ayelet Gundar-Goshen',
#   'publisher': 'Puskin Press                          (first published 2014',
#   'title': 'Waking Lions',
#   'pages': '409',
#   'description': 'Dr. Eitan Green is a good man. He saves lives. Then, speeding along a deserted moonlit road in his SUV, he hits someone. Seeing that the man, an African migrant, is beyond help, he flees the scene. It is a decision that changes everything. Because the dead man’s wife knows what happened. When she knocks at Eitan’s door the next day, tall and beautiful, he discovers that he',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2014',
#   'month': 'March'},
#  {'rating': '4.25',
#   'author': 'Mike  Wallace',
#   'publisher': 'Oxford University Press                          (first published October 2017',
#   'title': 'Greater Gotham: A History of New York City from 1898 to 1919',
#   'pages': '1200',
#   'description': "In this utterly immersive volume, Mike Wallace captures the swings of prosperity and downturn, from the 1898 skyscraper-driven boom to the Bankers' Panic of 1907, the labor upheaval, and violent repression during and after the First World War. Here is New York on a whole new scale, moving from national to global prominence -- an urban dynamo driven by restless ambition, bo",
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.37',
#   'author': 'James Forman Jr.',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Locking Up Our Own: Crime and Punishment in Black America',
#   'pages': '320',
#   'description': 'In recent years, America’s criminal justice system has become the subject of an increasingly urgent debate. Critics have assailed the rise of mass incarceration, emphasizing its disproportionate impact on people of color. As James Forman, Jr., points out, however, the war on crime that began in the 1970s was supported by many African American leaders in the nation’s urban',
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '3.72',
#   'author': 'Dominic Dromgoole',
#   'publisher': 'Grove Press',
#   'title': 'Hamlet Globe to Globe',
#   'pages': '320',
#   'description': 'Two years. 193,000 miles. 190 countries. One play. For the 450th anniversary of Shakespeare’s birth the Globe Theatre undertook an unparalleled journey, to take ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '4.05',
#   'author': 'Suzy Hansen',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Notes on a Foreign Country: An American Abroad in a Post-American World',
#   'pages': '288',
#   'description': 'Suzy Hansen left her country and moved to Istanbul and discovered America',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'August'},
#  {'rating': '4.49',
#   'author': 'Laura Dassow Walls',
#   'publisher': 'University of Chicago Press',
#   'title': 'Henry David Thoreau: A Life',
#   'pages': '640',
#   'description': '“Walden. Yesterday I came here to live.” That entry from the journal of Henry David Thoreau, and the intellectual journey it began, would by themselves be enough to place Thoreau in the American pantheon. His attempt to “live deliberately” in a small woods at the edge of his hometown of Concord has been a touchstone for individualists and seekers since the publication of ',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'July'},
#  {'rating': '4.30',
#   'author': 'Michael Tisserand',
#   'publisher': 'Harper                          (first published December 2016',
#   'title': 'Krazy: The Black and White World of George Herriman',
#   'pages': '384',
#   'description': 'In the tradition of Schulz and Peanuts, an epic and revelatory biography of Krazy Kat creator George Herriman that explores the turbulent time and place from which he emerged—and the deep secret he explored through his art.',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2016',
#   'month': 'December'},
#  {'rating': '3.89',
#   'author': 'Alan F. Taylor',
#   'publisher': 'Polygon',
#   'title': 'Appointment in Arezzo: A Friendship With Muriel Spark',
#   'pages': '162',
#   'description': <p>This book is an intimate, fond and funny memoir of one of the greatest novelists of the last century. This colourful, personal, anecdotal, indiscrete and admiring memoir charts the course of Muriel Spark's life revealing her as she really was. Once, she commented sitting over a glass of chianti at the kitchen table, that she was upset that the academic whom she had appoint</p>,
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '4.26',
#   'author': 'Victor Sebestyen',
#   'publisher': 'Weidenfeld & Nicolson',
#   'title': 'Lenin the Dictator',
#   'pages': '593',
#   'description': <p> <b>Shortlisted for the Elizabeth Longford Prize for Historical Biography</b> </p>,
#   'format': 'Kindle Edition',
#   'genre': 'History',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '3.35',
#   'author': 'Dan Chaon',
#   'publisher': 'Ballantine Books',
#   'title': 'Ill Will',
#   'pages': '496',
#   'description': <b>Two sensational unsolved crimes—one in the past, another in the present—are linked by one man’s memory and self-deception in this chilling novel of literary suspense from National Book Award finalist Dan Chaon.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'March'},
#  {'rating': '3.70',
#   'author': 'Jason Zinoman',
#   'publisher': 'Harper',
#   'title': 'Letterman: The Last Giant of Late Night',
#   'pages': '368',
#   'description': <em>New York Times</em>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'April'},
#  {'rating': '4.31',
#   'author': 'Charlie Veron',
#   'publisher': 'Penguin Books',
#   'title': 'A Life Underwater',
#   'pages': '320',
#   'description': "Hailed by David Attenborough and proclaimed a second Charles Darwin, Charlie Veron has lived up to his namesake. Even as a toddler, he had a deep affinity with the natural world, and by school age he knew more about some sciences than his teachers did. This didn't prevent him failing in a system that smothered creativity, and it was only by chance that he went to universit",
#   'format': 'Paperback',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'July'},
#  {'rating': '3.41',
#   'author': 'Emily Fridlund',
#   'publisher': 'Grove Atlantic',
#   'title': 'History of Wolves',
#   'pages': '288',
#   'description': 'Fourteen-year-old Madeline lives with her parents in the beautiful, austere woods of northern Minnesota, where their nearly abandoned commune stands as a last vestige of a lost counter-culture world. Isolated at home and an outlander at school, Madeline is drawn to the enigmatic, attractive Lily and new history teacher Mr. Grierson. When Mr. Grierson is charged with posses',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'January'},
#  {'rating': '3.58',
#   'author': 'Peter Kimani',
#   'publisher': 'Akashic Books',
#   'title': 'Dance of the Jakaranda',
#   'pages': '342',
#   'description': '"This funny, perceptive and ambitious work of historical fiction by a Kenyan poet and novelist explores his country’s colonial past and its legacy through the stories of three men involved with the building of a railroad linking Lake Victoria and the Indian Ocean--what the Kikuyu called the \'Iron Snake\' and the British called the \'Lunatic Express.\'"',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '4.28',
#   'author': 'Karin Roffman',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': "The Songs We Know Best: John Ashbery's Early Life",
#   'pages': '336',
#   'description': <b>The first biography of an American master</b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2017',
#   'month': 'June'},
#  {'rating': '3.79',
#   'author': 'Monica Hesse',
#   'publisher': 'Liveright',
#   'title': 'American Fire: Love, Arson, and Life in a Vanishing Land',
#   'pages': '255',
#   'description': 'A breathtaking feat of reportage, ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2017',
#   'month': 'July'}]

# %%
all_books_2016 = book_info(nyt_2016)

# %%
all_books_2016
# Out:
# [{'rating': '4.42',
#   'author': 'Yaa Gyasi',
#   'publisher': 'Alfred A. Knopf',
#   'title': 'Homegoing',
#   'pages': '320',
#   'description': 'A novel of breathtaking sweep and emotional power that traces three hundred years in Ghana and along the way also becomes a truly great American novel. Extraordinary for its exquisite language, its implacable sorrow, its soaring beauty, and for its monumental portrait of the forces that shape families and nations, ',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '4.03',
#   'author': 'Colson Whitehead',
#   'publisher': 'Doubleday Books',
#   'title': 'The Underground Railroad',
#   'pages': '306',
#   'description': 'Cora is a slave on a cotton plantation in Georgia. Life is hellish for all the slaves but especially bad for Cora; an outcast even among her fellow Africans, she is coming into womanhood - where even greater pain awaits. When Caesar, a recent arrival from Virginia, tells her about the Underground Railroad, they decide to take a terrifying risk and escape. Matters do not go',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '4.34',
#   'author': 'Paul Kalanithi',
#   'publisher': 'Random House                          (first published January 12th 2016',
#   'title': 'When Breath Becomes Air',
#   'pages': '208',
#   'description': 'For readers of Atul Gawande, Andrew Solomon, and Anne Lamott, a profoundly moving, exquisitely observed memoir by a young neurosurgeon faced with a terminal cancer diagnosis who attempts to answer the question What makes a life worth living?',
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'January'},
#  {'rating': '4.49',
#   'author': 'Matthew Desmond',
#   'publisher': 'Crown',
#   'title': 'Evicted: Poverty and Profit in the American City',
#   'pages': '418',
#   'description': <b><i>New York Times </i>Bestseller<br/><br/>From Harvard sociologist and MacArthur "Genius" Matthew Desmond, a landmark work of scholarship and reportage that will forever change the way we look at poverty in America</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'March'},
#  {'rating': '4.00',
#   'author': 'Ian McGuire',
#   'publisher': 'Henry Holt and Co.                          (first published February 11th 2016',
#   'title': 'The North Water',
#   'pages': '272',
#   'description': 'LONGLISTED FOR THE MAN BOOKER PRIZE 2016',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2016',
#   'month': 'March'},
#  {'rating': '3.58',
#   'author': 'Han Kang',
#   'publisher': 'Hogarth Press                          (first published October 30th 2007',
#   'title': 'The Vegetarian',
#   'pages': '188',
#   'description': "Before the nightmare, Yeong-hye and her husband lived an ordinary life. But when splintering, blood-soaked images start haunting her thoughts, Yeong-hye decides to purge her mind and renounce eating meat. In a country where societal mores are strictly obeyed, Yeong-hye's decision to embrace a more “plant-like” existence is a shocking act of subversion. And as her passive r",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2007',
#   'month': 'February'},
#  {'rating': '3.57',
#   'author': 'Karan Mahajan',
#   'publisher': 'Viking',
#   'title': 'The Association of Small Bombs',
#   'pages': '288',
#   'description': 'FINALIST FOR THE NATIONAL BOOK AWARD 2016',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'March'},
#  {'rating': '3.81',
#   'author': 'Ann Patchett',
#   'publisher': 'Harper',
#   'title': 'Commonwealth',
#   'pages': '336',
#   'description': <strong>#1 <em>New York Times </em>Bestseller</strong>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.51',
#   'author': 'Elizabeth Strout',
#   'publisher': 'Random House                          (first published January 6th 2016',
#   'title': 'My Name Is Lucy Barton',
#   'pages': '193',
#   'description': "The profound mother-daughter bond is explored through a mother's hospital visit to her estranged daughter by the Pulitzer Prize-winning author of Olive Kitteridge and The Burgess Boys.",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'January'},
#  {'rating': '3.57',
#   'author': 'Zadie Smith',
#   'publisher': 'Hamish Hamilton',
#   'title': 'Swing Time',
#   'pages': '453',
#   'description': "Two brown girls dream of being dancers--but only one, Tracey, has talent. The other has ideas: about rhythm and time, about black bodies and black music, about what constitutes a tribe, or makes a person truly free. It's a close but complicated childhood friendship that ends abruptly in their early twenties, never to be revisited, but never quite forgotten, either.",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'November'},
#  {'rating': '3.91',
#   'author': 'Madeleine Thien',
#   'publisher': 'W. W. Norton  Company                          (first published May 31st 2016',
#   'title': 'Do Not Say We Have Nothing',
#   'pages': '480',
#   'description': '“In a single year, my father left us twice. The first time, to end his marriage, and the second, when he took his own life. I was ten years old.”',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.09',
#   'author': 'Nathan  Hill',
#   'publisher': 'Knopf',
#   'title': 'The Nix',
#   'pages': '640',
#   'description': 'A hilarious and deeply touching debut novel about a son, the mother who left him as a child, and how his search to uncover the secrets of her life leads him to reclaim his own.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.40',
#   'author': 'Deborah Levy',
#   'publisher': 'Bloomsbury USA                          (first published March 31st 2016',
#   'title': 'Hot Milk',
#   'pages': '218',
#   'description': "Sofia, a young anthropologist, has spent much of her life trying to solve the mystery of her mother's unexplainable illness. She's frustrated with Rose and her constant complaints but utterly relieved to be called to abandon her own disappointing fledgling adult life. She and Rose travel to the searing, arid coast of southern Spain to see a famous consultant, Dr. Gomez—the",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'July'},
#  {'rating': '4.36',
#   'author': 'Jane Mayer',
#   'publisher': 'Doubleday',
#   'title': 'Dark Money: The Hidden History of the Billionaires Behind the Rise of the Radical Right',
#   'pages': '464',
#   'description': 'Why is America living in an age of profound economic inequality? Why, despite the desperate need to address climate change, have even modest environmental efforts been defeated again and again? Why have protections for employees been decimated? Why do hedge-fund billionaires pay a far lower tax rate than middle-class workers?',
#   'format': 'ebook',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'January'},
#  {'rating': '3.86',
#   'author': 'Affinity Konar',
#   'publisher': 'Lee Boudreaux Books',
#   'title': 'Mischling',
#   'pages': '344',
#   'description': 'Pearl is in charge of: the sad, the good, the past.',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.74',
#   'author': 'Noah Hawley',
#   'publisher': 'Grand Central Publishing',
#   'title': 'Before the Fall',
#   'pages': '391',
#   'description': "On a foggy summer night, eleven people—ten privileged, one down-on-his-luck painter—depart Martha's Vineyard on a private jet headed for New York. Sixteen minutes later, the unthinkable happens: the plane plunges into the ocean. The only survivors are the painter Scott Burroughs and a four-year-old boy, who is now the last remaining member of an immensely wealthy and power",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '4.43',
#   'author': 'Svetlana Alexievich',
#   'publisher': 'Text Publishing                          (first published August 15th 2013',
#   'title': 'Secondhand Time: The Last of the Soviets',
#   'pages': '496',
#   'description': <p>From the 2015 winner of the Nobel Prize in Literature, Svetlana Alexievich, comes the first English translation of her latest work, an oral history of the disintegration of the Soviet Union and the emergence of a new Russia.</p>,
#   'format': 'Kindle Edition',
#   'genre': 'Nonfiction',
#   'year': '2013',
#   'month': 'May'},
#  {'rating': '3.69',
#   'author': 'Ian McEwan',
#   'publisher': 'Nan A. Talese                          (first published September 1st 2016',
#   'title': 'Nutshell',
#   'pages': '208',
#   'description': <b>Nutshell is a classic story of murder and deceit, told by a narrator with a perspective and voice unlike any in recent literature. A bravura performance, it is the finest recent work from a true master.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '4.14',
#   'author': 'Hisham Matar',
#   'publisher': 'Knopf Canada                          (first published June 2016',
#   'title': 'The Return: Fathers, Sons, and the Land in Between',
#   'pages': '288',
#   'description': "From Man Booker Prize and National Book Critics Circle Award finalist Hisham Matar, a memoir of his journey home to his native Libya in search of answers to his father's disappearance. In 2012, after the overthrow of Qaddafi, the acclaimed novelist Hisham Matar journeys to his native Libya after an absence of thirty years. \xa0\xa0\xa0\xa0 ",
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'July'},
#  {'rating': '4.42',
#   'author': 'Carol  Anderson',
#   'publisher': 'Bloomsbury USA',
#   'title': 'White Rage: The Unspoken Truth of Our Racial Divide',
#   'pages': '256',
#   'description': <b>From the Civil War to our combustible present, acclaimed historian Carol Anderson reframes our continuing conversation about race, chronicling the powerful forces opposed to black progress in America.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.87',
#   'author': 'Louise Erdrich',
#   'publisher': 'Harper',
#   'title': 'LaRose',
#   'pages': '372',
#   'description': 'In this literary masterwork, Louise Erdrich, the bestselling author of the National Book Award-winning\xa0',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.82',
#   'author': 'Michael Chabon',
#   'publisher': 'Harper',
#   'title': 'Moonglow',
#   'pages': '430',
#   'description': 'Following on the heels of his ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'November'},
#  {'rating': '3.20',
#   'author': 'Don DeLillo',
#   'publisher': 'Scribner                          (first published March 3rd 2016',
#   'title': 'Zero K',
#   'pages': '274',
#   'description': 'The wisest, richest, funniest, and most moving novel in years from Don DeLillo, one of the great American novelists of our time—an ode to language, at the heart of our humanity, a meditation on death, and an embrace of life.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.64',
#   'author': 'Jonathan Safran Foer',
#   'publisher': 'Hamish Hamilton',
#   'title': 'Here I Am',
#   'pages': '571',
#   'description': 'A monumental new novel from the bestselling author of ',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.66',
#   'author': 'David Szalay',
#   'publisher': 'Jonathan Cape',
#   'title': 'All That Man Is',
#   'pages': '448',
#   'description': <b>A magnificent and ambitiously conceived portrait of contemporary life, by a genius of realism.</b>,
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.87',
#   'author': 'Max Porter',
#   'publisher': 'Faber & Faber                          (first published August 24th 2015',
#   'title': 'Grief is the Thing with Feathers',
#   'pages': '114',
#   'description': "In a London flat, two young boys face the unbearable sadness of their mother's sudden death. Their father, a Ted Hughes scholar and scruffy romantic, imagines a future of well-meaning visitors and emptiness.",
#   'format': 'Hardcover',
#   'genre': 'Poetry',
#   'year': '2015',
#   'month': 'September'},
#  {'rating': '3.86',
#   'author': 'Jacqueline Woodson',
#   'publisher': 'Amistad',
#   'title': 'Another Brooklyn',
#   'pages': '177',
#   'description': 'Running into a long-ago friend sets memories from the 1970s in motion for August, transporting her to a time and a place where friendship was everything—until it wasn’t. For August and her girls, sharing confidences as they ambled through neighborhood streets, Brooklyn was a place where they believed that they were beautiful, talented, brilliant—a part of a future that bel',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '4.03',
#   'author': 'Hope Jahren',
#   'publisher': 'Knopf                          (first published March 1st 2016',
#   'title': 'Lab Girl',
#   'pages': '290',
#   'description': 'Acclaimed scientist Hope Jahren has built three laboratories in which she’s studied trees, flowers, seeds, and soil. Her first book is a revelatory treatise on plant life—but it is also so much more. ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'April'},
#  {'rating': '3.76',
#   'author': 'Annie Proulx',
#   'publisher': 'Scribner                          (first published January 5th 2016',
#   'title': 'Barkskins',
#   'pages': '717',
#   'description': 'In the late seventeenth century two penniless young Frenchmen, René Sel and Charles Duquet, arrive in New France. Bound to a feudal lord, a “',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '3.87',
#   'author': "Cathy O'Neil",
#   'publisher': 'Crown',
#   'title': 'Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy',
#   'pages': '259',
#   'description': <b>A former Wall Street quant sounds an alarm on mathematical modeling—a pervasive new force in society that threatens to undermine democracy and widen inequality.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.59',
#   'author': 'C.E. Morgan',
#   'publisher': '4th Estate                          (first published May 1st 2016',
#   'title': 'The Sport of Kings',
#   'pages': '545',
#   'description': 'Hellsmouth, a wilful thoroughbred filly, has the legacy of a family riding on her.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.95',
#   'author': 'Imbolo Mbue',
#   'publisher': 'Random House                          (first published March 15th 2016',
#   'title': 'Behold the Dreamers',
#   'pages': '380',
#   'description': <b>A compulsively readable debut novel about marriage, immigration, class, race, and the trapdoors in the American Dream—the unforgettable story of a young Cameroonian couple making a new life in New York just as the Great Recession upends the economy<br/><br/>Named one of BuzzFeed’s “Incredible New Books You Need to Read This Summer”</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '4.19',
#   'author': 'Eileen Myles',
#   'publisher': 'Ecco',
#   'title': 'I Must Be Living Twice: New and Selected Poems',
#   'pages': '368',
#   'description': "A collection of thrilling new and beloved past work from one of America's most celebrated poets, Eileen Myles, a cult icon and modern favorite",
#   'format': 'ebook',
#   'genre': 'Poetry',
#   'year': '2015',
#   'month': 'September'},
#  {'rating': '4.08',
#   'author': 'Richard Russo',
#   'publisher': 'Knopf',
#   'title': "Everybody's Fool",
#   'pages': '477',
#   'description': 'Richard Russo, at the very top of his game, now returns to North Bath, in upstate New York, and the characters who made Nobody\'s Fool (1993) a "confident, assured novel that sweeps the reader up," according to the San Francisco Chronicle back then. "Simple as family love, yet nearly as complicated." Or, as The Boston Globe put it, "a big, rambunctious novel with endless ri',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '4.19',
#   'author': 'Bruce Springsteen',
#   'publisher': 'Simon  Schuster',
#   'title': 'Born to Run',
#   'pages': '528',
#   'description': '“Writing about yourself is a funny business…But in a project like this, the writer has made one promise, to show the reader his mind. In these pages, I’ve tried to do this.” —Bruce Springsteen, from the pages of ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.70',
#   'author': 'Juan Gabriel Vásquez',
#   'publisher': 'Riverhead Books                          (first published May 1st 2006',
#   'title': 'Reputations',
#   'pages': '193',
#   'description': 'From the brilliant mind of the author of ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2006',
#   'month': 'September'},
#  {'rating': '4.36',
#   'author': 'Tyler Anbinder',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'title': 'City of Dreams: The 400-Year Epic History of Immigrant New York',
#   'pages': '768',
#   'description': <b>A defining American story of millions of immigrants, hundreds of languages, and one great city</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.37',
#   'author': 'Siddhartha Mukherjee',
#   'publisher': 'Scribner',
#   'title': 'The Gene: An Intimate History',
#   'pages': '592',
#   'description': 'From the Pulitzer Prize-winning, bestselling author of ',
#   'format': 'Hardcover',
#   'genre': 'Science',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.97',
#   'author': 'Simon Schama',
#   'publisher': 'Viking                          (first published January 1st 2015',
#   'title': 'The Face of Britain: The Nation Through its Portraits',
#   'pages': '632',
#   'description': "A portrait opens a window into a person's life: who they were and wanted to be, who the artist saw and how everyone else looked on.",
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2015',
#   'month': 'September'},
#  {'rating': '4.18',
#   'author': 'Candice Millard',
#   'publisher': 'Random House Large Print                          (first published April 12th 2016',
#   'title': 'Hero of the Empire: The Boer War, a Daring Escape, and the Making of Winston Churchill',
#   'pages': '563',
#   'description': <b>From <i>New York Times</i> bestselling author of <i>Destiny of the Republic</i> and <i>The River of Doubt</i>, a thrilling narrative of Winston Churchill's extraordinary and little-known exploits during the Boer War</b>,
#   'format': 'Paperback',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '4.42',
#   'author': 'David France',
#   'publisher': 'Knopf                          (first published January 1st 2013',
#   'title': 'How to Survive a Plague: The Inside Story of How Citizens and Science Tamed AIDS',
#   'pages': '640',
#   'description': <b>The definitive history of the successful battle to halt the AIDS epidemic from the creator of, and inspired by, the seminal documentary <i>How to Survive a Plague</i>. </b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2013',
#   'month': 'November'},
#  {'rating': '4.08',
#   'author': 'Elizabeth Hinton',
#   'publisher': 'Harvard University Press',
#   'title': 'From the War on Poverty to the War on Crime: The Making of Mass Incarceration in America',
#   'pages': '464',
#   'description': 'In the United States today, one in every 31 adults is under some form of penal control, including one in eleven African American men. How did the "land of the free" become the home of the world\'s largest prison system? Challenging the belief that America\'s prison problem originated with the Reagan administration\'s War on Drugs, Elizabeth Hinton traces the rise of mass inca',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '4.13',
#   'author': 'Blanche Wiesen Cook',
#   'publisher': 'Viking',
#   'title': 'Eleanor Roosevelt, Volume 3: The War Years and After, 1939-1962',
#   'pages': '688',
#   'description': <b>The magisterial concluding volume in the definitive biography of Eleanor Roosevelt</b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.42',
#   'author': 'Francine Prose',
#   'publisher': 'Harper',
#   'title': 'Mister Monkey',
#   'pages': '304',
#   'description': 'The acclaimed ',
#   'format': 'ebook',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.26',
#   'author': 'Ruth Franklin',
#   'publisher': 'Liveright',
#   'title': 'Shirley Jackson: A Rather Haunted Life',
#   'pages': '624',
#   'description': 'Instantly heralded for its “masterful” and “thrilling” portrayal (',
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.74',
#   'author': 'Nancy Isenberg',
#   'publisher': 'Viking',
#   'title': 'White Trash: The 400-Year Untold History of Class in America',
#   'pages': '460',
#   'description': <b>In her groundbreaking history of the class system in America, extending from colonial times to the present, Nancy Isenberg takes on our comforting myths about equality, uncovering the crucial legacy of the ever-present, always embarrassing––if occasionally entertaining––"poor white trash."</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '3.21',
#   'author': 'Derek Palacio',
#   'publisher': 'Tim Duggan Books',
#   'title': 'The Mortifications',
#   'pages': '320',
#   'description': 'Derek Palacio’s stunning, mythic novel marks the arrival of a fresh voice and a new chapter in the history of 21st century Cuban-American literature.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.85',
#   'author': 'Wendy  Warren',
#   'publisher': 'Liveright                          (first published June 6th 2016',
#   'title': 'New England Bound: Slavery and Colonization in Early America',
#   'pages': '368',
#   'description': <b>The most important work on seventeenth-century New England in a generation.</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '4.05',
#   'author': 'Rebecca Traister',
#   'publisher': 'Simon  Schuster',
#   'title': 'All the Single Ladies: Unmarried Women and the Rise of an Independent Nation',
#   'pages': '339',
#   'description': 'A nuanced investigation into the sexual, economic, and emotional lives of women in America. In a provocative, groundbreaking work, National Magazine Award finalist Rebecca Traister, “the most brilliant voice on feminism in the country” (Anne Lamott), traces the history of unmarried and late-married women in America who, through social, political, and economic means, have r',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'March'},
#  {'rating': '3.88',
#   'author': 'Jeffrey Toobin',
#   'publisher': 'Doubleday                          (first published April 2nd 2016',
#   'title': 'American Heiress: The Wild Saga of the Kidnapping, Crimes and Trial of Patty Hearst',
#   'pages': '368',
#   'description': 'From New Yorker staff writer and bestselling author Jeffrey Toobin, the definitive account of the kidnapping and trial that defined an insane era in American history',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.81',
#   'author': 'Nicole Y. Dennis-Benn',
#   'publisher': 'Liveright',
#   'title': 'Here Comes the Sun',
#   'pages': '352',
#   'description': 'Capturing the distinct rhythms of Jamaican life and dialect, Nicole Dennis-Benn pens a tender hymn to a world hidden among pristine beaches and the wide expanse of turquoise seas. At an opulent resort in Montego Bay, Margot hustles to send her younger sister, Thandi, to school. Taught as a girl to trade her sexuality for survival, Margot is ruthlessly determined to shield',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'July'},
#  {'rating': '4.28',
#   'author': 'Patrick Phillips',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'Blood at the Root: A Racial Cleansing in America',
#   'pages': '320',
#   'description': 'A gripping tale of racial cleansing in Forsyth County, Georgia, and a harrowing testament to the deep roots of racial violence in America.',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '4.30',
#   'author': 'Ethan Michaeli',
#   'publisher': 'Houghton Mifflin                          (first published February 4th 2014',
#   'title': 'The Defender: How the Legendary Black Newspaper Changed America',
#   'pages': '288',
#   'description': <div><b>“An extraordinary history…Deeply researched, elegantly written…a towering achievement that will not be soon forgotten.”</b> —<b>Brent Staples, <i>New York Times Book Review</i></b><br/><br/><b>NAMED ONE OF THE BEST BOOKS OF THE YEAR BY <br/><i>The New York Times Book Review • The Washington Post • Amazon</i></b><br/>  <div>Giving voice to the voiceless, the <i>Chicago Defender</i> condemned Jim Crow, catalyzed the Great Migration, and</div></div>,
#   'format': 'ebook',
#   'genre': 'History',
#   'year': '2014',
#   'month': 'January'},
#  {'rating': '3.81',
#   'author': 'Jessi Klein',
#   'publisher': 'Grand Central Publishing                          (first published June 7th 2016',
#   'title': "You'll Grow Out of It",
#   'pages': '291',
#   'description': 'INSTANT ',
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2016',
#   'month': 'July'},
#  {'rating': '3.87',
#   'author': 'Andrew Solomon',
#   'publisher': 'Scribner                          (first published April 2016',
#   'title': 'Far & Away: Reporting from the Brink of Change: Seven Continents, Twenty-Five Years',
#   'pages': '512',
#   'description': 'From the winner of the National Book Award and the National Books Critics’ Circle Award—and one of the most original thinkers of our time—a riveting collection of essays about places in dramatic transition.',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'April'},
#  {'rating': '4.19',
#   'author': 'Ed Yong',
#   'publisher': 'Ecco',
#   'title': 'I Contain Multitudes: The Microbes Within Us and a Grander View of Life',
#   'pages': '368',
#   'description': <p>Joining the ranks of popular science classics like <em>The Botany of Desire</em> and <em>The Selfish Gene,</em> a groundbreaking, wondrously informative, and vastly entertaining examination of the most significant revolution in biology since Darwin—a “microbe’s-eye view” of the world that reveals a marvelous, radically reconceived picture of life on earth.</p>,
#   'format': 'Hardcover',
#   'genre': 'Science',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '4.55',
#   'author': 'Adrienne Rich',
#   'publisher': 'W. W. Norton  Company                          (first published March 28th 2016',
#   'title': 'Collected Poems: 1950–2012',
#   'pages': '1164',
#   'description': 'Adrienne Rich was the singular voice of her generation and one of our most important American poets. She brought discussions of gender, race, and class to the forefront of poetical discourse, pushing formal boundaries and consistently examining both self and society.',
#   'format': 'Hardcover',
#   'genre': 'Poetry',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '3.73',
#   'author': 'Mitchell Duneier',
#   'publisher': 'Farrar, Straus and Giroux                          (first published December 1st 2015',
#   'title': 'Ghetto: The Invention of a Place, the History of an Idea',
#   'pages': '304',
#   'description': <b>A five-hundred-year story of exclusion and containment, from the first Jewish ghetto to the present</b>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2015',
#   'month': 'April'},
#  {'rating': '4.04',
#   'author': 'Joseph Lelyveld',
#   'publisher': 'Knopf',
#   'title': 'His Final Battle: The Last Months of Franklin Roosevelt',
#   'pages': '417',
#   'description': <b>A <i>New York Times </i>2016 Notable Book</b>,
#   'format': 'Kindle Edition',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '2.92',
#   'author': 'Boris Fishman',
#   'publisher': 'Harper',
#   'title': "Don't Let My Baby Do Rodeo",
#   'pages': '336',
#   'description': 'The author of the critically admired, award-winning ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'March'},
#  {'rating': '4.16',
#   'author': 'Magda Szabó',
#   'publisher': 'Vintage Digital                          (first published 1963',
#   'title': "Iza's Ballad",
#   'pages': '336',
#   'description': "When Ettie's husband dies, her daughter Iza insists that her mother give up the family house in the countryside and move to Budapest. Displaced from her community and her home, Ettie tries to find her place in this new life, but can't seem to get it right. She irritates the maid, hangs food outside the window because she mistrusts the fridge and, in her naivety and lonelin",
#   'format': 'Kindle Edition',
#   'genre': 'Fiction',
#   'year': '1963',
#   'month': 'August'},
#  {'rating': '4.24',
#   'author': 'Robert Tombs',
#   'publisher': 'Allen Lane',
#   'title': 'The English and their History',
#   'pages': '1024',
#   'description': 'In ',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2014',
#   'month': 'November'},
#  {'rating': '4.29',
#   'author': 'Solmaz Sharif',
#   'publisher': 'Graywolf Press',
#   'title': 'Look',
#   'pages': '98',
#   'description': <p>*Finalist for the 2017 PEN Open Book Award*<br/>*Finalist for the 2016 National Book Award*</p>,
#   'format': 'Paperback',
#   'genre': 'Poetry',
#   'year': '2016',
#   'month': 'July'},
#  {'rating': '3.81',
#   'author': 'Alexander Weinstein',
#   'publisher': 'Picador',
#   'title': 'Children of the New World',
#   'pages': '229',
#   'description': <b>AN EXTRAORDINARILY RESONANT AND PROPHETIC COLLECTION OF SPECULATIVE SHORT FICTION FOR OUR TECH-</b>,
#   'format': 'ebook',
#   'genre': 'Short Stories',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.26',
#   'author': "Edna O'Brien",
#   'publisher': 'Little Brown and Company                          (first published October 27th 2015',
#   'title': 'The Little Red Chairs',
#   'pages': '299',
#   'description': <b>The much-anticipated new novel from the literary world's master of storytelling, Edna O'Brien.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2015',
#   'month': 'March'},
#  {'rating': '3.79',
#   'author': 'Michael V. Hayden',
#   'publisher': 'Penguin Press',
#   'title': 'Playing to the Edge: American Intelligence in the Age of Terror',
#   'pages': '464',
#   'description': <b>An unprecedented high-level master narrative of America's intelligence wars, from the only person ever to helm both CIA and NSA, at a time of heinous new threats and wrenching change</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'February'},
#  {'rating': '3.63',
#   'author': 'Joy Williams',
#   'publisher': 'Blackstone Audiobooks                          (first published April 22nd 2013',
#   'title': 'Ninety-Nine Stories of God',
#   'pages': '1',
#   'description': "Pulitzer Prize and National Book Award finalist Joy Williams has a one-of-a-kind gift for capturing both the absurdity and the darkness of everyday life. In Ninety-Nine Stories of God, she takes on one of mankind's most confounding preoccupations: the Supreme Being.This series of short, fictional vignettes explores our day-to-day interactions with an ever-elusive and arbit",
#   'format': 'Audio CD',
#   'genre': 'Short Stories',
#   'year': '2013',
#   'month': 'July'},
#  {'rating': '4.22',
#   'author': 'Sarah Bakewell',
#   'publisher': 'Chatto & Windus                          (first published March 2016',
#   'title': 'At the Existentialist Café: Freedom, Being, and Apricot Cocktails',
#   'pages': '440',
#   'description': "Paris, near the turn of 1933. Three young friends meet over apricot cocktails at the Bec-de-Gaz bar on the rue Montparnasse. They are Jean-Paul Sartre, Simone de Beauvoir and their friend Raymond Aron, who opens their eyes to a radical new way of thinking. Pointing to his drink, he says, 'You can make philosophy out of ",
#   'format': 'Hardcover',
#   'genre': 'Philosophy',
#   'year': '2016',
#   'month': 'March'},
#  {'rating': '4.11',
#   'author': 'Arlie Russell Hochschild',
#   'publisher': 'New Press',
#   'title': 'Strangers in Their Own Land: Anger and Mourning on the American Right',
#   'pages': '261',
#   'description': 'In ',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.91',
#   'author': 'Susan Faludi',
#   'publisher': 'Metropolitan Books',
#   'title': 'In the Darkroom',
#   'pages': '432',
#   'description': <b>From the Pulitzer Prize-winning journalist and bestselling author of <i>Backlash</i>, comes <i>In the Darkroom</i>, an astonishing confrontation with the enigma of her father and the larger riddle of identity consuming our age.</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '3.65',
#   'author': 'Peter Ho Davies',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'title': 'The Fortunes',
#   'pages': '288',
#   'description': <b>From the author of <i>The Welsh Girl</i> comes a groundbreaking, provocative new novel.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.18',
#   'author': 'Jonathan Lethem',
#   'publisher': 'Doubleday Books',
#   'title': "A Gambler's Anatomy",
#   'pages': '304',
#   'description': 'Handsome, impeccably tuxedoed Bruno Alexander travels the world winning large sums of money from amateur "whales" who think they can challenge his peerless acumen at backgammon. Fronted by his pasty, vampiric manager, Edgar Falk, Bruno arrives in Berlin after a troubling run of bad luck in Singapore. Perhaps it was the chance encounter with his crass childhood acquaintance',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.25',
#   'author': 'Robert F. Worth',
#   'publisher': 'Farrar, Straus and Giroux                          (first published March 22nd 2016',
#   'title': 'A Rage for Order: The Middle East in Turmoil, from Tahrir Square to ISIS',
#   'pages': '272',
#   'description': <b>The definitive work of literary journalism on the Arab Spring and its troubled aftermath</b>,
#   'format': 'Paperback',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'April'},
#  {'rating': '3.40',
#   'author': 'Lara Vapnyar',
#   'publisher': 'Hogarth',
#   'title': 'Still Here',
#   'pages': '308',
#   'description': <b>A profound and dazzlingly entertaining novel from the writer Louis Menand calls "Jane Austen with a Russian soul"</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.90',
#   'author': 'Stefan Hertmans',
#   'publisher': 'Text Publishing                           (first published September 2nd 2013',
#   'title': 'War and Turpentine',
#   'pages': '304',
#   'description': "Shortly before his death in 1981, Stefan Hertmans' grandfather gave him a couple of filled exercise books. Stories he’d heard as a child had led Hertmans to suspect that their contents might be disturbing, and for years he didn’t dare to open them.",
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2013',
#   'month': 'July'},
#  {'rating': '4.01',
#   'author': 'Matti Friedman',
#   'publisher': 'Algonquin Books',
#   'title': "Pumpkinflowers: A Soldier's Story of a Forgotten War",
#   'pages': '256',
#   'description': <b>“Matti Friedman’s haunting war memoir reminds one of Michael Herr’s unforgettable Vietnam memoir, <i>Dispatches.</i> It, too, is destined to become a classic text on the absurdities of war. Evocative, emotionally wrenching, and yet clear-eyed and dispassionate, <i>Pumpkinflowers</i> is a stunning achievement.” —Kai Bird, Pulitzer Prize–winning biographer and <i>New York Times</i> bestselling a</b>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.19',
#   'author': 'Maria Semple',
#   'publisher': 'Little, Brown and Company',
#   'title': 'Today Will Be Different',
#   'pages': '259',
#   'description': <strong>A genius novel from the author of <i>Where'd You Go, Bernadette</i>, about a day in the life of Eleanor Flood, forced to abandon her small ambitions when she awakes to a strange, new future unfolding. </strong>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.47',
#   'author': 'Beth Macy',
#   'publisher': 'Little, Brown and Company',
#   'title': "Truevine: Two Brothers, a Kidnapping, and a Mother's Quest: A True Story of the Jim Crow South",
#   'pages': '420',
#   'description': 'The true story of two African-American brothers who were kidnapped and displayed as circus freaks, and whose mother endured a 28-year struggle to get them back.',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.09',
#   'author': 'Stephen King',
#   'publisher': 'Scribner',
#   'title': 'End of Watch',
#   'pages': '432',
#   'description': 'The spectacular finale to the New York Times bestselling trilogy that began with Mr. Mercedes (winner of the Edgar Award) and Finders Keepers—In End of Watch, the diabolical “Mercedes Killer” drives his enemies to suicide, and if Bill Hodges and Holly Gibney don’t figure out a way to stop him, they’ll be victims themselves.',
#   'format': 'Hardcover',
#   'genre': 'Horror',
#   'year': '2016',
#   'month': 'June'},
#  {'rating': '4.21',
#   'author': 'Adam Kirsch',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'The People and the Books: 18 Classics of Jewish Literature',
#   'pages': '432',
#   'description': 'Jews have long embraced their identity as “the people of the book.” But outside of the Bible, much of the Jewish literary tradition remains little known to nonspecialist readers. ',
#   'format': 'Hardcover',
#   'genre': 'Literature',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '4.21',
#   'author': 'Adam Kirsch',
#   'publisher': 'W. W. Norton  Company',
#   'title': 'The People and the Books: 18 Classics of Jewish Literature',
#   'pages': '432',
#   'description': 'Jews have long embraced their identity as “the people of the book.” But outside of the Bible, much of the Jewish literary tradition remains little known to nonspecialist readers. ',
#   'format': 'Hardcover',
#   'genre': 'Literature',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.45',
#   'author': 'Louise Doughty',
#   'publisher': 'Sarah Crichton Books                          (first published June 2nd 2016',
#   'title': 'Black Water',
#   'pages': '352',
#   'description': 'From the author of ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.98',
#   'author': 'Rosa Brooks',
#   'publisher': 'Simon  Schuster',
#   'title': 'How Everything Became War and the Military Became Everything: Tales from the Pentagon',
#   'pages': '448',
#   'description': 'The first serious book to examine what happens when the ancient boundary between war and peace is erased.',
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.83',
#   'author': 'Peter Fritzsche',
#   'publisher': 'Basic Books',
#   'title': 'An Iron Wind: Europe Under Hitler',
#   'pages': '376',
#   'description': 'World War II reached into the homes and lives of ordinary people in an unprecedented way. Civilians made up the vast majority of those killed by war. On Europe’s home front, the war brought the German blitzkrieg, followed by long occupations and the racial genocide of the Holocaust. ',
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.80',
#   'author': 'Melanie Finn',
#   'publisher': 'Two Dollar Radio                          (first published March 12th 2014',
#   'title': 'The Gloaming',
#   'pages': '308',
#   'description': "Pilgrim's husband left her for another woman, stranding her in a Swiss town where she is involved in an accident that leaves three children dead. Cleared of responsibility though overcome with guilt, she absconds to Africa, befriending a series of locals each with their own tragic past.",
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2014',
#   'month': 'September'},
#  {'rating': '4.43',
#   'author': 'Heather Ann Thompson',
#   'publisher': 'Pantheon Books',
#   'title': 'Blood in the Water: The Attica Prison Uprising of 1971 and Its Legacy',
#   'pages': '752',
#   'description': <i>The first definitive account of the infamous 1971 Attica prison uprising, the state’s violent response, and the victims' decades-long quest for justice including information never released to the public published to coincide with the forty-fifth anniversary of this historic event.</i>,
#   'format': 'Hardcover',
#   'genre': 'History',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '3.76',
#   'author': 'Ishion Hutchinson',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'House of Lords and Commons: Poems',
#   'pages': '96',
#   'description': <b>A stunning collection that traverses the borders of culture and time, from the 2011 winner of the PEN/Joyce Osterweil Award</b>,
#   'format': 'Hardcover',
#   'genre': 'Poetry',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.55',
#   'author': 'David Constantine',
#   'publisher': 'Comma Press',
#   'title': 'The Life-Writer',
#   'pages': '190',
#   'description': "The long anticipated novel from the author of the short story 'In Another Country', which inspired the Oscar/Academy Award nominated film, #45Years. ",
#   'format': 'Kindle Edition',
#   'genre': 'Fiction',
#   'year': '2015',
#   'month': 'August'},
#  {'rating': '3.02',
#   'author': 'Martin Seay',
#   'publisher': 'Melville House Publishing',
#   'title': 'The Mirror Thief',
#   'pages': '582',
#   'description': "The core story is set in Venice in the sixteenth century, when the famed makers of Venetian glass were perfecting one of the old world's most wondrous inventions: the mirror. An object of glittering yet fearful fascination—was it reflecting simple reality, or something more spiritually revealing?—the Venetian mirrors were state of the art technology and subject to industri",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.73',
#   'author': 'Dan Fox',
#   'publisher': 'Coffee House Press                          (first published February 10th 2016',
#   'title': 'Pretentiousness: Why It Matters',
#   'pages': '144',
#   'description': <i>Pretentiousness </i>,
#   'format': 'Paperback',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'April'},
#  {'rating': '3.89',
#   'author': 'Daniel Bergner',
#   'publisher': 'Lee Boudreaux Books',
#   'title': 'Sing for Your Life: A Story of Race, Music, and Family',
#   'pages': '320',
#   'description': <strong>The touching, triumphant story of a young black man's journey from violence and despair to one of the world's most elite artistic institutions, as if <i>The Blind Side</i> were set in the world of opera. </strong>,
#   'format': 'Hardcover',
#   'genre': 'Nonfiction',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.53',
#   'author': 'Lauren Collins',
#   'publisher': 'Penguin Press',
#   'title': 'When in French: Love in a Second Language',
#   'pages': '256',
#   'description': 'A language barrier is no match for love. Lauren Collins discovered this firsthand when, in her early thirties, she moved to London and fell for a Frenchman named Olivier—a surprising turn of events for someone who didn’t have a passport until she was in college. But what does it mean to love someone in a second language? Collins wonders, as her relationship with Olivier co',
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2016',
#   'month': 'September'},
#  {'rating': '3.13',
#   'author': 'Steve Fraser',
#   'publisher': 'Basic Books',
#   'title': 'The Limousine Liberal: How an Incendiary Image United the Right and Fractured America',
#   'pages': '304',
#   'description': 'No political metaphor in recent American history has enjoyed the impact of the limousine liberal. Taking aim at what many consider the hypocrisy of wealthy liberals who champion the cause of the poor but who have no intention of bearing the costs of doing anything about their plight, it has mobilized an enduring politics of resentment against everything from civil rights t',
#   'format': 'ebook',
#   'genre': 'Politics',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '4.32',
#   'author': 'Sebastian Mallaby',
#   'publisher': 'Penguin Press',
#   'title': 'The Man Who Knew: The Life and Times of Alan Greenspan',
#   'pages': '800',
#   'description': <b>The definitive biography of the most important economic statesman of our time</b>,
#   'format': 'Hardcover',
#   'genre': 'Economics',
#   'year': '2016',
#   'month': 'October'},
#  {'rating': '3.74',
#   'author': 'Jenny Diski',
#   'publisher': 'Bloomsbury USA                          (first published April 21st 2016',
#   'title': 'In Gratitude',
#   'pages': '256',
#   'description': <i>The future flashed before my eyes in all its pre-ordained banality. Embarrassment, at first, to the exclusion of all other feelings. But embarrassment curled at the edges with a weariness …</i>,
#   'format': 'Hardcover',
#   'genre': 'Autobiography',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '3.83',
#   'author': 'Sabina Murray',
#   'publisher': 'Grove Press',
#   'title': 'Valiant Gentlemen',
#   'pages': '489',
#   'description': <b>Following her <i>New York Times</i> Editor’s Choice collection of short stories <i>Tales of the New World</i>, historical fiction master Sabina Murray returns with an epic and bold novel of friendship and betrayal set across four continents and a 40-year time span</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2016',
#   'month': 'November'},
#  {'rating': '3.67',
#   'author': 'Lucy Wood',
#   'publisher': 'Bloomsbury Publishing',
#   'title': 'Weathering',
#   'pages': '320',
#   'description': <i>An alternative cover edition for this ISBN can be found <a href="https://www.goodreads.com/book/show/25970641-weathering" rel="nofollow">here</a></i>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2015',
#   'month': 'January'},
#  {'rating': '4.15',
#   'author': 'Robert J. Gordon',
#   'publisher': 'Princeton University Press',
#   'title': 'The Rise and Fall of American Growth: The U.S. Standard of Living Since the Civil War',
#   'pages': '784',
#   'description': 'In the century after the Civil War, an economic revolution improved the American standard of living in ways previously unimaginable. Electric lighting, indoor plumbing, motor vehicles, air travel, and television transformed households and workplaces. But has that era of unprecedented growth come to an end? Weaving together a vivid narrative, historical anecdotes, and econo',
#   'format': 'Hardcover',
#   'genre': 'Economics',
#   'year': '2016',
#   'month': 'January'},
#  {'rating': '4.44',
#   'author': 'Simon Callow',
#   'publisher': 'Viking                          (first published November 5th 2015',
#   'title': 'Orson Welles, Vol. 3: One-Man Band',
#   'pages': '496',
#   'description': <b>The third volume of Simon Callow’s acclaimed Orson Welles biography, covering the period of his exile from America (1947<b>–</b>1964), when he produced some of his greatest works, including <i>Touch of Evil</i></b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2015',
#   'month': 'April'},
#  {'rating': '4.44',
#   'author': 'Simon Callow',
#   'publisher': 'Viking                          (first published November 5th 2015',
#   'title': 'Orson Welles, Vol. 3: One-Man Band',
#   'pages': '496',
#   'description': <b>The third volume of Simon Callow’s acclaimed Orson Welles biography, covering the period of his exile from America (1947<b>–</b>1964), when he produced some of his greatest works, including <i>Touch of Evil</i></b>,
#   'format': 'Hardcover',
#   'genre': 'Biography',
#   'year': '2015',
#   'month': 'April'}]

# %%
nyt_2018_df = pd.DataFrame.from_dict(all_books)
nyt_2018_df.to_csv('csv_files/nyt_2018_df.csv', encoding='utf-8', index=False)

# %%
nyt_2017_df = pd.DataFrame.from_dict(all_books_2017)
nyt_2017_df.to_csv('csv_files/nyt_2017_df.csv', encoding='utf-8', index=False)

# %%
nyt_2016_df = pd.DataFrame.from_dict(all_books_2016)
nyt_2016_df.to_csv('csv_files/nyt_2016_df.csv', encoding='utf-8', index=False)
