# %% [markdown]
# # Good Reads Books

# %%
from bs4 import BeautifulSoup as bs
import urllib.request
import requests

# %%
link = 'https://www.goodreads.com/book/show/39863520-how-to-date-men-when-you-hate-men'
page = urllib.request.urlopen(link)

soup = bs(page, 'html.parser')

soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="desktop ">\n <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# good_reads: http://ogp.me/ns/fb/good_reads#">\n  <title>\n   How to Date Men When You Hate Men by Blythe Roberson\n  </title>\n  <script type="text/javascript">\n   var ue_t0=window.ue_t0||+new Date();\n  </script>\n  <script type="text/javascript">\n   (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n\n    if (window.ue && window.ue.tag) { window.ue.tag(\'book:show:signed_out\', ue.main_scope);window.ue.tag(\'book:show:signed_out:desktop\', ue.main_scope); }\n  </script>\n  <script type="text/javascript">\n   if (window.Mobvious === undefined) {\n          window.Mobvious = {};\n        }\n        window.Mobvious.device_type = \'desktop\';\n  </script>\n  <script src="https://s.gr-assets.com/assets/webfontloader-ea2919013845458b4794b5323cfe383c.js">\n  </script>\n  <script>\n   //<![CDATA[\n\n  WebFont.load({\n    classes: false,\n    custom: {\n      families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],\n      urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]\n    }\n  });\n\n//]]>\n  </script>\n  <link href="https://s.gr-assets.com/assets/goodreads-f775a20d457d54d8abf9f4e9695c4f93.css" media="all" rel="stylesheet"/>\n  <!--[if lte IE 9]>\n<link rel="stylesheet" media="all" href="https://s.gr-assets.com/assets/goodreads_split2-362aec2254dde6006dd5a1b94eb15c8e.css" />\n<![endif]-->\n  <!--[if lt IE 9]>\n    <link rel="stylesheet" media="screen" href="https://s.gr-assets.com/assets/ie-243e73b5c2539766a7d02b37fdf277f8.css" />\n  <![endif]-->\n  <!--[if lt IE 8]>\n    <link rel="stylesheet" media="screen" href="https://s.gr-assets.com/assets/common_images_ie-5b0cc205c33756d8e7e84ce5b8be28e3.css" />\n  <![endif]-->\n  <!--[if gte IE 8]><!-->\n  <link href="https://s.gr-assets.com/assets/common_images-67dd60a681af04727cf7d18f5c5ba498.css" media="screen" rel="stylesheet"/>\n  <!--<![endif]-->\n  <script src="https://s.gr-assets.com/assets/desktop/libraries-1c2883cf9caed935dcb88219fd720a9c.js">\n  </script>\n  <script src="https://s.gr-assets.com/assets/application-eb9b6824455e3a87cfee25a4b270379e.js">\n  </script>\n  <script>\n   //<![CDATA[\n    var gptAdSlots = gptAdSlots || [];\n    var googletag = googletag || {};\n    googletag.cmd = googletag.cmd || [];\n    (function() {\n      var gads = document.createElement("script");\n      gads.async = true;\n      gads.type = "text/javascript";\n      var useSSL = "https:" == document.location.protocol;\n      gads.src = (useSSL ? "https:" : "http:") +\n      "//www.googletagservices.com/tag/js/gpt.js";\n      var node = document.getElementsByTagName("script")[0];\n      node.parentNod ...

# %%
soup.title
# Out:
# <title>
# How to Date Men When You Hate Men by Blythe Roberson
# </title>

# %%
url = 'https://www.goodreads.com/book/reviews/39863520-how-to-date-men-when-you-hate-men?rating=&text_only=true'
r = requests.get(url).content
prefix = 'https://www.goodreads.com/review/show/'
[prefix + x.split('\\')[0] for x in str(r).split(prefix)][1:]
# Out:
# ['https://www.goodreads.com/review/show/2485843786',
#  'https://www.goodreads.com/review/show/2526013822',
#  'https://www.goodreads.com/review/show/2531161402',
#  'https://www.goodreads.com/review/show/2523399786',
#  'https://www.goodreads.com/review/show/2528847854',
#  'https://www.goodreads.com/review/show/2659372184',
#  'https://www.goodreads.com/review/show/2557301544',
#  'https://www.goodreads.com/review/show/2510917265',
#  'https://www.goodreads.com/review/show/2592884376',
#  'https://www.goodreads.com/review/show/2559122775',
#  'https://www.goodreads.com/review/show/2549570510',
#  'https://www.goodreads.com/review/show/2553921881',
#  'https://www.goodreads.com/review/show/2553192610',
#  'https://www.goodreads.com/review/show/2523825663',
#  'https://www.goodreads.com/review/show/2612203671',
#  'https://www.goodreads.com/review/show/2654676052']

# %% [markdown]
# ## Test for top books 2018

# %%
url_2018 = 'https://www.goodreads.com/choiceawards/best-fiction-books-2018'
r = urllib.request.urlopen(url_2018)

# %%
soup = bs(r, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="desktop ">
# <head>
# <title>
# Best Fiction 2018 — Goodreads Choice Awards
# </title>
# <script type="text/javascript">
#         if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#         </script>
# <script src="https://s.gr-assets.com/assets/webfontloader-ea2919013845458b4794b5323cfe383c.js"></script>
# <script>
# //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
# </script>
# <link href="https://s.gr-assets.com/assets/goodreads-f775a20d457d54d8abf9f4e9695c4f93.css" media="all" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" media="all" href="https://s.gr-assets.com/assets/goodreads_split2-362aec2254dde6006dd5a1b94eb15c8e.css" />
# <![endif]-->
# <link href="https://s.gr-assets.com/assets/choice_awards/base-1b8c3041a281fe1670f8b9a370d55ec6.css" media="screen" rel="stylesheet"/>
# <link href="https://s.gr-assets.com/assets/choice_awards/choice_category-c4e952531c7f800a451c3434f4287b52.css" media="screen" rel="stylesheet"/>
# <link href="https://s.gr-assets.com/assets/choice_awards/choice_category_current-438b7f1b490717d5e8c876d332bfda76.css" media="screen" rel="stylesheet"/>
# <!--[if lt IE 9]>
#     <link rel="stylesheet" media="screen" href="https://s.gr-assets.com/assets/ie-243e73b5c2539766a7d02b37fdf277f8.css" />
#   <![endif]-->
# <!--[if lt IE 8]>
#     <link rel="stylesheet" media="screen" href="https://s.gr-assets.com/assets/common_images_ie-5b0cc205c33756d8e7e84ce5b8be28e3.css" />
#   <![endif]-->
# <!--[if gte IE 8]><!-->
# <link href="https://s.gr-assets.com/assets/common_images-67dd60a681af04727cf7d18f5c5ba498.css" media="screen" rel="stylesheet"/>
# <!--<![endif]-->
# <script src="https://s.gr-assets.com/assets/desktop/libraries-1c2883cf9caed935dcb88219fd720a9c.js"></script>
# <script src="https://s.gr-assets.com/assets/application-eb9b6824455e3a87cfee25a4b270379e.js"></script>
# <script>
#   //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//www.googletagservices.com/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.22ebbaaf7a22a5a46b0acaeafc1e42e4");
#     googletag.pubads().setTargeting("grsession", "osid.22ebbaaf7a22a5a46b0acaeafc1e42e4");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#     googletag.pubads().setTargeting("resource", "gca_ballot_2018");
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
# </script>
# <script>
#   //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3
#     });
#   //]]>
# </script>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="XyeZQxstZWki9NTwjJgfE/m3ItdDLqyNTsDWXJyvCfFqmc7Zeqtlo18bPY+xS6I8jqQ1Oz186aB3wFVWzYqDvQ==" name="csrf-token"/>
# <meta content="Z28CSA9RVXEC52D1J7MF" name="request-id"/>
# <script src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-3081a4324a.js"></script>
# <script src="https://s.gr-assets.com/assets/react_client_side/site_header-0e63fd8fef.js"></script>
# <script src="https://s.gr-assets.com/assets/react_ujs-7d24ed3f94c45587cc007c6bd9ad12a9.js"></script>
# <!-- Plus One JS include -->
# <script type="text/javascript">
#   (function() {
#     var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
#     po.src = 'https://apis.google.com/js/plusone.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
#   })();
# </script>
# <script>
#   //<![CDATA[
#     !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#   //]]>
# </script>
# <script src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-3081a4324a.js"></script>
# <script src="https://s.gr-assets.com/assets/react_client_side/choice-77cf759b0d.js"></script>
# <script src="https://s.gr-assets.com/assets/react_ujs-7d24ed3f94c45587cc007c6bd9ad12a9.js"></script>
# <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
# <script>
# //<![CDATA[
#
#   var GoodreadsAnalytics = GoodreadsAnalytics || {};
#   var _gaq = _gaq || [];
#
#   GoodreadsAnalytics.push = function () {
#     _gaq.push.apply(_gaq, arguments);
#   }
#
#   GoodreadsAnalytics.push(['_setAccount', 'UA-968618-1']);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     1,                        // Slot 1
#     'User Status',            // Custom variable name
#     'signed_out',  // Custom variable value: signed_out, signed_in,
#                               //   signed_in_facebook_connected, or
#                               //   goodreads_member_previously_signed_in
#     2                         // Visit-level scope, which means slot 1 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_setCustomVar',
#     2,                        // Slot 2
#     'Device Type',            // Custom variable name
#     'desktop',         // Custom variable value: desktop, mobile, or
#                               //   tablet
#     2                         // Visit-level scope, which means slot 2 will be
#                               //   free when the visit ends.
#   ]);
#   GoodreadsAnalytics.push(['_trackPageview']);
#
#   (function () {
#     var ga = document.createElement('script');
#     ga.type = 'text/javascript';
#     ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(ga, s);
#   })();
#
# //]]>
# </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@goodreads" name="twitter:site"/>
# <meta content="Goodreads Choice Awards" name="twitter:title"/>
# <meta content="Announcing the best books of the year! The Goodreads Choice Awards are the only major book awards decided by readers." name="twitter:description"/>
# <meta content="https://www.goodreads.com/assets/award/2018/choice-logo-square-winners.png" name="twitter:image"/>
# <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
# <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification">
# <meta content="app-id=355833469" name="apple-itunes-app"/>
# <meta content="Best books 2018, top books 2018, 2018 Goodreads Choice Awards, votes, ratings, book reviews" property="keywords">
# <meta content="2415071772" property="fb:app_id"/>
# <meta content="Announcing the Goodreads Choice Winner in Best Fiction!" property="og:title"/>
# <meta content="https://www.goodreads.com/assets/award/2018/choice-logo-square-winners.png" property="og:image"/>
# <meta content="Congratulations to our winners in 21 categories! The Goodreads Choice Awards are the only major book awards decided by readers." property="og:description"/>
# <meta content="https://www.goodreads.com/choiceawards/best-fiction-books-2018" property="og:url"/>
# <meta content="Goodreads" property="og:site_name"/>
# </meta></meta></head>
# <body class="" id="gca2018">
# <script>
# //<![CDATA[
# ReactStores.GoogleAdsStore.initializeWith({"targeting":{"sid":"osid.22ebbaaf7a22a5a46b0acaeafc1e42e4","grsession":"osid.22ebbaaf7a22a5a46b0acaeafc1e42e4","surface":"desktop","signedin":"false","gr_author":"false","author":[],"resource":"gca_ballot_2018"},"ads":{"div-gpt-ad-goodr-gca-vote-970x66":{"isNativeAd":false,"hasCreative":false,"hasRequestedCreative":false,"path":"/4215/goodr.gca.vote.970x66","dimensions":"970x66","adSizeMapping":null,"adDeviceType":"desktop","pmetImpressionTrackUrl":"https://www.goodreads.com/dfp/impression","pmetClickTrackUrl":"https://www.goodreads.com/dfp/click","creativeSelector":"div#google_image_div","isLazyLoaded":false},"div-gpt-ad-goodr-gca-vote-160x600":{"isNativeAd":false,"hasCreative":false,"hasRequestedCreative":false,"path":"/4215/goodr.gca.vote.160x600","dimensions":"160x600","adSizeMapping":null,"adDeviceType":"desktop","pmetImpressionTrackUrl":"https://www.goodreads.com/dfp/impression","pmetClickTrackUrl":"https://www.goodreads.com/dfp/click","creativeSelector":"div#google_image_div","isLazyLoaded":false}},"nativeAds":{},"polls":{}});
# //]]>
# </script><div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}"><noscript data-react-checksum="-1447947982" data-reactid=".38jlraodfk"></noscript></div>
# <div class="content">
# <script>
#   //<![CDATA[
#     // Load Facebook JS SDK
#     $grfb.initialize({
#       appId: "2415071772",
#       grSession: false,
#       serverFBUser: "null",
#       suppressAutoLogin: "false"
#     });
#   //]]>
# </script>
# <div class="siteHeader">
# <script>
# //<![CDATA[
#   ReactStores.NotificationsStore.updateWith({});
#   ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#   ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#   ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
# //]]>
# </script><div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list","browseUrl":"/book","recommendationsUrl":"/recommendations","choiceAwardsUrl":"/choiceawards","genresIndexUrl":"/genres","giveawayUrl":"/giveaway","homeUrl":"/","listUrl":"/list","blogUrl":"/blog/index","editorsPicksUrl":"/voice","newsUrl":"/news","communityUrl":"/group","groupsUrl":"/group","quotesUrl":"/quotes","featuredAskAuthorUrl":"/ask_the_author","searchPath":"/search","discussionsUrl":"/topic","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","logoActionUrl":"/","readingNotesUrl":"/notes?ref=nd","topFullImage":{"topFullImageUrl":"/choiceawards?int=gca_eb","topFullImageAlt":"2018 Goodreads Choice Awards","xs":{"1x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_1x_v2-07f01bdd25ccf5a09f519a8c061d071b.png","2x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_xs_2x_v2-8530511915be6e5bc19b1bc407c669c7.png"},"md":{"1x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_md_1x_v2-79353a7717a3973cdfc064fe11eb55fb.png","2x":"https://s.gr-assets.com/assets/site_header/editorial_top_full_md_2x_v2-47267eedc7c48b6e62d3d29431e241c8.png"}},"newReleasesUrl":"/book/popular_by_date/2019/1","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":["newsfeed_impression_tracking","nav_bar_discussions_pane","news_page"],"defaultLogoAltText":"Goodreads Home","logoAltText":"Goodreads Home","mobviousDeviceType":"desktop"}'><header data-react-checksum="-888446854" data-reactid=".1i47v61rv9c"><div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".1i47v61rv9c.1"><div class="siteHeader__contents" data-reactid=".1i47v61rv9c.1.0"><div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".1i47v61rv9c.1.0.0"><button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".1i47v61rv9c.1.0.0.0" type="button"></button></div><a aria-label="Goodreads Home" class="siteHeader__logo" data-reactid=".1i47v61rv9c.1.0.2" href="/" title="Goodreads Home"></a><nav class="siteHeader__primaryNavInline" data-reactid=".1i47v61rv9c.1.0.3"><ul class="siteHeader__menuList" data-reactid=".1i47v61rv9c.1.0.3.0" role="menu"><li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".1i47v61rv9c.1.0.3.0.0"><a class="siteHeader__topLevelLink" data-reactid=".1i47v61rv9c.1.0.3.0.0.0" href="/">Home</a></li><li class="siteHeader__topLevelItem" data-reactid=".1i47v61rv9c.1.0.3.0.1"><a class="siteHeader__topLevelLink" data-reactid=".1i47v61rv9c.1.0.3.0.1.0" href="/review/list">My Books</a></li><li class="siteHeader__topLevelItem" data-reactid=".1i47v61rv9c.1.0.3.0.2"><div class="primaryNavMenu primaryNavMenu--siteHeaderBrowseMenu ignore-react-onclickoutside" data-reactid=".1i47v61rv9c.1.0.3.0.2.0"><a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.0" href="/book" role="button"><span data-reactid=".1i47v61rv9c.1.0.3.0.2.0.0.0">Browse ▾</span></a><div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1" role="menu"><div class="siteHeader__browseMenuDropdown" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0"><ul class="siteHeader__subNav" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0.0"><li class="menuLink" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0.0.0" role="menuitem"><a class="siteHeader__subNavLink" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0.0.0.0" href="/recommendations">Recommendations</a></li><li class="menuLink" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0.0.1" role="menuitem"><a class="siteHeader__subNavLink" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0.0.1.0" href="/choiceawards">Choice Awards</a></li><li class="menuLink" data-reactid=".1i47v61rv9c.1.0.3.0.2.0.1.0.0.2" role="menuitem"><a class="siteHeader__subNavL ...
# </div>
# <div class="siteHeaderBottomSpacer"></div>
# <script>
#   //<![CDATA[
#     ReactRailsUJS.mountComponents();
#   //]]>
# </script>
# <div class="mainContentContainer ">
# <div class="mainContent ">
# <div class="mainContentFloat ">
# <div id="flashContainer">
# </div>
# <link href="//fonts.googleapis.com/css?family=Lato:400,700|Merriweather:400,300italic|Josefin+Sans:700" media="screen" rel="stylesheet">
# <div class="gcaResults" id="choiceBody">
# <div class="gcaLeftContainer">
# <a href="/choiceawards/best-books-2018"><img alt="2018 Goodreads Choice Awards" height="" id="choiceLogo" src="https://s.gr-assets.com/assets/award/2018/choice-logo-large-def8969703c8a82f9afe8f89ec67631c.png" title="2018 Goodreads Choice Awards" width=""/></a>
# <ul class="categoriesList categoriesList--current">
# <li class="categoriesList__category categoriesList__category--selected">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current categoriesList__categoryLink--selected" href="/choiceawards/best-fiction-books-2018">Fiction
# <span class="voteNotice" id="vote_notice_poll_179510" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-mystery-thriller-books-2018">Mystery &amp; Thriller
# <span class="voteNotice" id="vote_notice_poll_179511" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-historical-fiction-books-2018">Historical Fiction
# <span class="voteNotice" id="vote_notice_poll_179512" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-fantasy-books-2018">Fantasy
# <span class="voteNotice" id="vote_notice_poll_179513" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-of-the-best-2018">Best of the Best
# <span class="voteNotice" id="vote_notice_poll_179514" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-romance-books-2018">Romance
# <span class="voteNotice" id="vote_notice_poll_179515" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-science-fiction-books-2018">Science Fiction
# <span class="voteNotice" id="vote_notice_poll_179516" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-horror-books-2018">Horror
# <span class="voteNotice" id="vote_notice_poll_179517" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-humor-books-2018">Humor
# <span class="voteNotice" id="vote_notice_poll_179518" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-nonfiction-books-2018">Nonfiction
# <span class="voteNotice" id="vote_notice_poll_179519" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-memoir-autobiography-books-2018">Memoir &amp; Autobiography
# <span class="voteNotice" id="vote_notice_poll_179520" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-history-biography-books-2018">History &amp; Biography
# <span class="voteNotice" id="vote_notice_poll_179521" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-science-technology-books-2018">Science &amp; Technology
# <span class="voteNotice" id="vote_notice_poll_179522" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-food-cookbooks-2018">Food &amp; Cookbooks
# <span class="voteNotice" id="vote_notice_poll_179523" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-graphic-novels-comics-2018">Graphic Novels &amp; Comics
# <span class="voteNotice" id="vote_notice_poll_179524" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-poetry-books-2018">Poetry
# <span class="voteNotice" id="vote_notice_poll_179525" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-debut-author-2018">Debut Author
# <span class="voteNotice" id="vote_notice_poll_179526" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-young-adult-fiction-books-2018">Young Adult Fiction
# <span class="voteNotice" id="vote_notice_poll_179527" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-young-adult-fantasy-books-2018">Young Adult Fantasy &amp; Science Fiction
# <span class="voteNotice" id="vote_notice_poll_179528" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-childrens-books-2018">Middle Grade &amp; Children's
# <span class="voteNotice" id="vote_notice_poll_179529" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# <li class="categoriesList__category">
# <a class="categoriesList__categoryLink categoriesList__categoryLink--current" href="/choiceawards/best-picture-books-2018">Picture Books
# <span class="voteNotice" id="vote_notice_poll_179530" style="display: none">
# ✓
# </span>
# <div class="voteNotice">
# view results →
# </div>
# </a></li>
# </ul>
# <ul class="otherYearsList otherYearsList--current">
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2017">2017 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2016">2016 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2015">2015 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2014">2014 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2013">2013 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2012">2012 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2011">2011 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2010">2010 Awards</a>
# </li>
# <li class="otherYearsList__year">
# <a class="otherYearsList__yearLink" href="/choiceawards/best-books-2009">2009 Awards</a>
# </li>
# </ul>
# </div>
# <div class="gcaRightContainer">
# <div class="gcaTopAd">
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"div-gpt-ad-goodr-gca-vote-970x66","className":"googleBannerAd--pushdown"}'></div>
# </div>
# <div class="gcaBody">
# <div class="gcaPollLinks">
# <a class="gcaPollLink gcaPollLink--next" href="/choiceawards/best-mystery-thriller-books-2018">Mystery &amp; Thriller</a>
# </div>
# <div class="gcaMastheader">Best Fiction</div>
# <div class="gcaSocial vcenteredLineOfBlocks inline">
# <a class="facebook_connect" href="#" onclick='$grfb.shareDialog({"resource_type":"choiceawards_2018_best-fiction-books-2018","href":"https://www.goodreads.com/choiceawards/best-fiction-books-2018?utm_campaign=gca2018\u0026utm_content=button\u0026utm_medium=social\u0026utm_source=facebook.com","display":"popup","hashtag":"#GoodreadsChoice","mobile_iframe":false}); Lightbox.hideBox();; return false;'><img alt="F29" src="https://s.gr-assets.com/assets/facebook/f29-fb02e22e90b143c997e641e721ec9d24.png"/></a>
# <div class="twitterLogoButton" data-gr-tracker-id="gca2018_best-fiction-books-2018_tweet">
# <a href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.goodreads.com%2Fchoiceawards%2Fbest-fiction-books-2018%3Futm_campaign%3Dgca2018%26utm_content%3Dbutton%26utm_medium%3Dsocial%26utm_source%3Dtwitter.com&amp;via=goodreads&amp;text=Announcing the %23GoodreadsChoice Winner in Best Fiction! See results:"><img alt="Twitter bird 29x29" src="https://s.gr-assets.com/assets/twitter/twitter-bird_29x29-cd1605d8d860cc6e97390c06ae58b021.png"/></a>
# </div>
# </div>
# <div class="awardsCta">
# New to Goodreads? Get great book recommendations!
# <a class="gcaLink" href="/user/new">Start Now</a>
# </div>
# <div class="poll">
# <h2 class="gcaSubheader" id="pollHeadline">
# </h2>
# <div class="clear"></div>
# <div class="gcaDivider">
# <div class="gcaDivider__centerpiece"></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="gcaBody js-lazyGlideContainer js-dataTooltip" data-use-wtr-tooltip="true">
# <div class="poll" id="poll_179510">
# <div class="pollContents">
# <div class="winner stacked pollVote pollVote--borderBottom box">
# <div class="winningBook">
# <div class="miniBook"><div class="miniBookCover"><span class="cover"><a href="/book/show/35791968-still-me?from_choice=true"><img alt="Still Me by Jojo Moyes" src="https://images.gr-assets.com/books/1502818159l/35791968.jpg" title="Still Me by Jojo Moyes"/></a></span></div><div class="miniBookContent"><div class="right" style="margin: 0 0 10px 10px">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_35791968">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="MyJX8pdO2oGZMQgY5jkD+tYm1tR5eHGBNytWgc5LCgEGnABo9sjaS+Te4Wfb6r7VoTXBOAcqNKwOK9WLn26ATQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_35791968"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="QnwFkO2ATQhqUwJHtWoVKhfAdjTuGXAG1ccoxjv4RNF3wlIKjAZNwhe86ziIuagFYNNh2JBLNSvsx6vMat3OnQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_35791968"/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35791968" data-submit-url="/review/rate/35791968?stars_click=true&amp;wtr_button_id=1_book_35791968" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# <a class="gr-button kcrPreviewButton buyableFeature syncPreviewButton" data-book-id="35791968" href="https://read.amazon.com/nc/?kcrFree=only&amp;tag=x_gr_w_preview_hover_gca-20&amp;asin=B073YTMMQS" id="js-kcrPreviewButton">Open Preview</a>
# <div class="wrongBookKindlePreviewScreen" id="wrongBookKindlePreviewScreenBook35791968" style="display: none;">
# <div class="wrongBookBody">
# <h2>See a Problem?</h2>
# <div class="wrongBookText">
# <div class="description">
#         We’d love your help.
#         Let us know what’s wrong with this preview of
#           <cite>Still Me</cite> by Jojo Moyes.
#       </div>
# <form accept-charset="UTF-8" action="/kindle_book_mapping_flags" class="new_kindle_book_mapping_flag" data-remote="true" id="new_kindle_book_mapping_flag" method="post"><input name="utf8" type="hidden" value="✓"/>
# <div class="reasons">
# <label for="kindle_book_mapping_flag_reason">Problem:</label>
# <select id="kindle_book_mapping_flag_reason" name="kindle_book_mapping_flag[reason]"><option value="wrongBook">It’s the wrong book</option>
# <option value="wrongEdition">It’s the wrong edition</option>
# <option value="other">Other</option></select>
# <br/>
# </div>
# <div class="otherReason">
# <label for="kindle_book_mapping_flag_other_reason">Details (if other):</label>
# <input id="kindle_book_mapping_flag_other_reason" name="kindle_book_mapping_flag[other_reason]" type="text"/>
# </div>
# <input id="kindle_book_mapping_flag_book_id" name="kindle_book_mapping_flag[book_id]" type="hidden" value="35791968"/>
# <input class="gr-button" name="commit" type="submit" value="Report Problem"/>
#
#         <button class="gr-buttonAsLink gr-buttonAsLink--quiet" id="js-wrongBookKindlePreviewScreenCancelLink" type="button">
#         Cancel
#         </button>
# </form> </div>
# </div>
# </div>
# <div class="wrongBookKindlePreviewScreenConfirmation" id="js-wrongBookKindlePreviewScreenConfirmation" style="display:none;">
# <p>Thanks for telling us about the problem.</p>
# <button class="gr-button" id="js-wrongBookKindlePreviewScreenConfirmationDismiss" type="button">
#     Return to Book Page
#   </button>
# </div>
# <div class="kindleCloudReader" id="kindleCloudReaderBook35791968" style="display: none;">
# <div class="topBanner">
# <a class="js-wrongBookKindlePreview" data-book-id="35791968" href="#" id="wrongBookLink">Not the book you’re looking for?</a>
# <h2 class="kindlePreviewHeader">
#       Preview — <cite>Still Me</cite>
#         by Jojo Moyes
#     </h2>
# </div>
# <iframe id="kindleCloudReader">
# <iframe id="wrongBookKindlePreviewScreen"></iframe>
# </iframe>
# </div>
# </div>
# <div class="gcaWinnerHeader">
# WINNER
# <span class="greyText gcaNumVotes">
# 55,300
# votes
# </span>
# </div>
# <div class="u-marginTopXSmall">
# <a class="winningTitle choice gcaBookTitle gcaBookTitle--red" href="/book/show/35791968-still-me?from_choice=true">Still Me</a>
# <div class="gcaAuthor">
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/281810.Jojo_Moyes" itemprop="url"><span itemprop="name">Jojo Moyes</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# </div>
# </div>
# <div class="readable stacked gcaBookDescription" id="description" style="right:0">
# Jojo Moyes wins the Best Fiction award for her third book in the <i>Me Before You</i> series (the first book was adapted into a tearjerker of a movie). Here heroine Louisa Clark ventures to New York City to start a new life. This is the British author’s first Goodreads Choice Award.
# </div>
# <div class="gcaSideFlourish gcaSideFlourish--left"></div>
# <div class="gcaSideFlourish gcaSideFlourish--right"></div>
# </div><div class="clear"> </div></div></div>
# </div>
# <h2 class="gcaSubheader">
# All Nominees
# •
# <div class="greyText gcaNumVotes">
# 332,119
# votes total
# </div>
# </h2>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 55,300
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="35791968" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/35791968-still-me?from_choice=true" id="bookCover_35791968"><img alt="Still Me by Jojo Moyes" src="https://images.gr-assets.com/books/1502818159l/35791968.jpg" title="Still Me by Jojo Moyes"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="2_book_35791968">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="1QX8fJqUyH3wHLie2GAaSvaFNwq6m26pxLKjoHf4Qjfgu6vm+xLIt43zUeHls6dlgZYg5sTJK4T9siCqJt3Iew=="/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_35791968"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="llKx5l0YfWgFYCh8tx/voBt5TAHGLki4E6V/LvibEQWj7OZ8PJ59oniPwQOKzFKPbGpb7bh8DZUqpfwkqb6bSQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_35791968"/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35791968" data-submit-url="/review/rate/35791968?stars_click=true&amp;wtr_button_id=2_book_35791968" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 41,826
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="33590210" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/33590210-an-american-marriage?from_choice=true" id="bookCover_33590210"><img alt="An American Marriage by Tayari Jones" src="https://images.gr-assets.com/books/1491493625l/33590210.jpg" title="An American Marriage by Tayari Jones"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="3_book_33590210">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="s44zva5djIt5PqmZ+oNBepH191rB3acn8UtwF5B8Rt2GMGQnz9uMQQTRQObHUPxV5ubgtr+P4grIS/MdwVnMkQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="33590210"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_33590210"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="fmKJ5StA8XJfwVHqhAtCeNNLsNzyvy86Mk9g9NBLjKpL3N5/SsbxuCIuuJW52P9XpFinMIztahcLT+P+gW4G5g=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_33590210"/>
# <input id="book_id" name="book_id" type="hidden" value="33590210"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="33590210" data-submit-url="/review/rate/33590210?stars_click=true&amp;wtr_button_id=3_book_33590210" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 38,981
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36373463" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36373463-us-against-you?from_choice=true" id="bookCover_36373463"><img alt="Us Against You by Fredrik Backman" src="https://images.gr-assets.com/books/1516019348l/36373463.jpg" title="Us Against You by Fredrik Backman"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="4_book_36373463">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ecFH3ZwNGkiFU3DMSBi9K/eZGSjYkKGykgjLkhZDLmNMfxBH/Ysagvi8mbN1ywAEgIoOxKbC5J+rCEiYR2akLw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36373463"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_36373463"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="4+GKgNJuNg6nlpagFek2+UrXcYhsS0FMa8nMqSvOTg3WX90as+g2xNp5f98oOovWPcRmZBIZBGFSyU+jeuvEQQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_36373463"/>
# <input id="book_id" name="book_id" type="hidden" value="36373463"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36373463" data-submit-url="/review/rate/36373463?stars_click=true&amp;wtr_button_id=4_book_36373463" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown pollAnswer--last">
# <strong class="uitext result">
# 31,447
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="left" data-resource-id="39280445" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/39280445-nine-perfect-strangers?from_choice=true" id="bookCover_39280445"><img alt="Nine Perfect Strangers by Liane Moriarty" src="https://images.gr-assets.com/books/1529076901l/39280445.jpg" title="Nine Perfect Strangers by Liane Moriarty"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="5_book_39280445">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="i+ZDleAdapM6g2IV2DnU1kk85ipA4ithpqS27uHZC62+WBQPgZtqWUdsi2rl6mn5Pi/xxj6wbkyfpDXksPyB4Q=="/>
# <input id="book_id" name="book_id" type="hidden" value="39280445"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_39280445"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="twnkoJXsrXm889fqT3UqJr7MoQCINdK5Z7EM+CtQKzyCt7M69Gqts8EcPpVyppcJyd+27PZnl5ResY/yenWhcA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_39280445"/>
# <input id="book_id" name="book_id" type="hidden" value="39280445"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# ...
# <input id="unique_id" name="unique_id" type="hidden" value="19_book_36249638"/>
# <input id="book_id" name="book_id" type="hidden" value="36249638"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36249638" data-submit-url="/review/rate/36249638?stars_click=true&amp;wtr_button_id=19_book_36249638" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 1,641
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36723245" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36723245-the-book-of-essie?from_choice=true" id="bookCover_36723245"><img alt="The Book of Essie by Meghan MacLean Weir" src="https://images.gr-assets.com/books/1515873936l/36723245.jpg" title="The Book of Essie by Meghan MacLean Weir"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="20_book_36723245">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="g5n0Gm4q8xhhKpsNeDFwUzwLyuouaphHTT2pZk/G/1O2J6OAD6zz0hzFcnJF4s18SxjdBlA43Wp0PSpsHuN1Hw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36723245"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="20_book_36723245"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="RPTzdQHh9fyFz9OudKs/Gd+ZQBXPKRQ4TuRUd0dcATxxSqTvYGf1NvggOtFJeII2qIpX+bF7URV35Nd9FnmLcA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="20_book_36723245"/>
# <input id="book_id" name="book_id" type="hidden" value="36723245"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36723245" data-submit-url="/review/rate/36723245?stars_click=true&amp;wtr_button_id=20_book_36723245" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown pollAnswer--last">
# <strong class="uitext result">
# 1,352
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="left" data-resource-id="36373648" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36373648-the-mars-room?from_choice=true" id="bookCover_36373648"><img alt="The Mars Room by Rachel Kushner" src="https://images.gr-assets.com/books/1524991696l/36373648.jpg" title="The Mars Room by Rachel Kushner"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="21_book_36373648">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Q2qp05ZxecDCKmLB0TYWxAWPMtsTy1OGGIg72k4baFN21P5J9/d5Cr/Fi77s5avrcpwlN22ZFqshiLjQHz7iHw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36373648"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="21_book_36373648"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="X5j0JQu2/LEqFToty60Ur6phMgtJmBJXFLSdTi9LS2lqJqO/ajD8e1f601L2fqmA3XIl5zfKV3ottB5Efm7BJQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="21_book_36373648"/>
# <input id="book_id" name="book_id" type="hidden" value="36373648"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36373648" data-submit-url="/review/rate/36373648?stars_click=true&amp;wtr_button_id=21_book_36373648" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="uitext loadingDialog" id="loadingVote_poll_179510" style="display:none">
# <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# Saving your vote...
# </div>
# <div class="uitext loadingDialog" id="loadingClearVote_poll_179510" style="display:none">
# <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# Clearing your vote...
# </div>
# <div class="gcaDivider">
# <div class="gcaDivider__centerpiece"></div>
# </div>
# </div>
# <div id="rulesAndEligibility" style="display: none;">
# <h1>2018 Rules &amp; Eligibility</h1>
# <p>
# The 2018 Goodreads Choice Awards have three rounds of voting open to all registered Goodreads members. Winners will be announced December 04, 2018.
# </p>
# <h2>Opening Round: Oct 30 - Nov 04</h2>
# <p>
# Voting opens to 15 official nominees, and write-in votes can be placed for any eligible book (see eligibility below).
# Our special “Best of the Best” category features the 170 past winners of the Goodreads Choice Awards. Write-in votes can not be placed in this category.
# </p>
# <h2>Semifinal Round: Nov 06 - 11</h2>
# <p>
# The top five write-in votes in each of the categories become official nominees. Additional write-ins no longer accepted.
# For our special “Best of the Best” category, the top 20 books become semifinalists.
# </p>
# <h2>Final Round: Nov 13 - 26</h2>
# <p>
# The field narrows to the top 10 books in each category, and members have one last chance to vote!
# </p>
# <h1>2018 Eligibility</h1>
# <p>
# Books published in the United States in English, including works in translation and other significant rereleases, between November 16, 2017, and November 15, 2018, are eligible for the 2018 Goodreads Choice Awards. Books published between November 16, 2018, and December 31, 2018, will be eligible for the 2019 awards.
# </p>
# <p>
# We analyze statistics from the millions of books added, rated, and reviewed on Goodreads to nominate 15 books in each category. Opening round official nominees must have an average rating of 3.50 or higher at the time of launch. Write-in votes may be cast for eligible books with any average rating, and write-in votes will be weighted by the book's Goodreads statistics to determine the top five books to be added as official nominees in the Semifinal Round. A book may be nominated in no more than one genre category, but can also be nominated in the Debut Author category. Only one book in a series may be nominated per category. An author may receive multiple nominations within a single category if he or she has more than one eligible series or more than one eligible stand-alone book.
# </p>
# </div>
# </div>
# <script>
#   //<![CDATA[
#     $j('#write_in_form_poll_179510').
#       on("ajax:beforeSend", function() {
#         $('poll_179510').modalDialog($('loadingVote_poll_179510') || 'Loading...')
#       }).
#       on("ajax:success", function(event, data, status, request) {
#         $j('#poll_179510').replaceWith(request.responseText);
#
#         // Show the "you voted" lightbox.
#         $j('#vote_notice_poll_179510').show();
#
#         $('poll_179510').scrollTo();
#       }).
#       on("ajax:error", function(event, request) {
#         $j('#write-in-errors_poll_179510').replaceWith("<div style=\"background-color: #FFFBD9; padding: 15px;\"><div style=\"color: #D3A52E; font-weight: bold; margin-bottom: 10px;\">That book is ineligible. Please try again!</div>" + request.responseText.replace("Resource", "") + "</div>");
#         $j('#write-in-errors_poll_179510').show();
#         $('poll_179510').clearModalDialog();
#       });
#   //]]>
# </script>
# <div class="gcaPollLinks">
# <a class="gcaPollLink gcaPollLink--next" href="/choiceawards/best-mystery-thriller-books-2018">Mystery &amp; Thriller</a>
# </div>
# </div>
# <div class="gcaSideAd">
# <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"div-gpt-ad-goodr-gca-vote-160x600","className":""}'></div>
# </div>
# </div>
# </div>
# </link></div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# <div class="footerContainer">
# <div class="footer">
# <div class="copyright">
# ©
# 2019
# Goodreads Inc
# </div>
# <div class="adminLinksContainer">
# <ul class="adminLinks">
# <li>
# <a class="first" href="/about/us" rel="nofollow">about us</a>
# </li>
# <li>
# <a href="/advertisers" rel="nofollow">advertise</a>
# </li>
# <li>
# <a href="/author/program" rel="nofollow">author program</a>
# </li>
# <li>
# <a href="/jobs" rel="nofollow">jobs</a>
# </li>
# <li>
# <a href="/api" rel="nofollow">api</a>
# </li>
# <li>
# <a href="/news" rel="nofollow">our blog</a>
# </li>
# <li>
# <a href="/news?content_type=author_blogs" rel="nofollow">authors &amp; advertisers blog</a>
# </li>
# <li>
# <a href="/about/terms" rel="nofollow">terms</a>
# </li>
# <li>
# <a href="/about/privacy" rel="nofollow">privacy</a>
# </li>
# <li>
# <a class="last" href="/help" rel="nofollow">help</a>
# </li>
# <li class="mobileToggleLink">
# <span class="label">switch to:</span>
# <a href="/toggle_mobile?switch_to=mobile" rel="nofollow">mobile version</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'><noscript data-react-checksum="-1523838749" data-reactid=".a89z9umdj4"></noscript></div>
# <div id="overlay" onclick="Lightbox.hideBox()" style="display:none"></div>
# <div id="box" style="display:none">
# <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window"></div>
# <div id="boxContents"></div>
# <div id="boxContentsLeftovers" style="display:none"></div>
# <div class="clear"></div>
# </div>
# <div id="fbSigninNotification" style="display:none;">
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>
# <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
# </div>
# <div id="fb-root"></div>
# <script type="text/javascript">
# //<![CDATA[
#   $grfb.initialize({
#     appId: "2415071772",
#     grSession: false,
#     serverFBUser: null,
#     suppressAutoLogin: false
#   });
# //]]>
# </script>
# <script>
#   //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY', uid: ''};
#   //]]>
# </script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
# </noscript>
# <script>
#   //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
# </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0">
# </img></noscript>
# </body>
# </html>
# <!-- This is a random-length HTML comment: ... -->

# %%
soup.find('div', {"class":"pollContents"})
# Out:
# <div class="pollContents">
# <div class="winner stacked pollVote pollVote--borderBottom box">
# <div class="winningBook">
# <div class="miniBook"><div class="miniBookCover"><span class="cover"><a href="/book/show/35791968-still-me?from_choice=true"><img alt="Still Me by Jojo Moyes" src="https://images.gr-assets.com/books/1502818159l/35791968.jpg" title="Still Me by Jojo Moyes"/></a></span></div><div class="miniBookContent"><div class="right" style="margin: 0 0 10px 10px">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_35791968">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="MyJX8pdO2oGZMQgY5jkD+tYm1tR5eHGBNytWgc5LCgEGnABo9sjaS+Te4Wfb6r7VoTXBOAcqNKwOK9WLn26ATQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_35791968"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="QnwFkO2ATQhqUwJHtWoVKhfAdjTuGXAG1ccoxjv4RNF3wlIKjAZNwhe86ziIuagFYNNh2JBLNSvsx6vMat3OnQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_35791968"/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35791968" data-submit-url="/review/rate/35791968?stars_click=true&amp;wtr_button_id=1_book_35791968" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# <a class="gr-button kcrPreviewButton buyableFeature syncPreviewButton" data-book-id="35791968" href="https://read.amazon.com/nc/?kcrFree=only&amp;tag=x_gr_w_preview_hover_gca-20&amp;asin=B073YTMMQS" id="js-kcrPreviewButton">Open Preview</a>
# <div class="wrongBookKindlePreviewScreen" id="wrongBookKindlePreviewScreenBook35791968" style="display: none;">
# <div class="wrongBookBody">
# <h2>See a Problem?</h2>
# <div class="wrongBookText">
# <div class="description">
#         We’d love your help.
#         Let us know what’s wrong with this preview of
#           <cite>Still Me</cite> by Jojo Moyes.
#       </div>
# <form accept-charset="UTF-8" action="/kindle_book_mapping_flags" class="new_kindle_book_mapping_flag" data-remote="true" id="new_kindle_book_mapping_flag" method="post"><input name="utf8" type="hidden" value="✓"/>
# <div class="reasons">
# <label for="kindle_book_mapping_flag_reason">Problem:</label>
# <select id="kindle_book_mapping_flag_reason" name="kindle_book_mapping_flag[reason]"><option value="wrongBook">It’s the wrong book</option>
# <option value="wrongEdition">It’s the wrong edition</option>
# <option value="other">Other</option></select>
# <br/>
# </div>
# <div class="otherReason">
# <label for="kindle_book_mapping_flag_other_reason">Details (if other):</label>
# <input id="kindle_book_mapping_flag_other_reason" name="kindle_book_mapping_flag[other_reason]" type="text"/>
# </div>
# <input id="kindle_book_mapping_flag_book_id" name="kindle_book_mapping_flag[book_id]" type="hidden" value="35791968"/>
# <input class="gr-button" name="commit" type="submit" value="Report Problem"/>
#
#         <button class="gr-buttonAsLink gr-buttonAsLink--quiet" id="js-wrongBookKindlePreviewScreenCancelLink" type="button">
#         Cancel
#         </button>
# </form> </div>
# </div>
# </div>
# <div class="wrongBookKindlePreviewScreenConfirmation" id="js-wrongBookKindlePreviewScreenConfirmation" style="display:none;">
# <p>Thanks for telling us about the problem.</p>
# <button class="gr-button" id="js-wrongBookKindlePreviewScreenConfirmationDismiss" type="button">
#     Return to Book Page
#   </button>
# </div>
# <div class="kindleCloudReader" id="kindleCloudReaderBook35791968" style="display: none;">
# <div class="topBanner">
# <a class="js-wrongBookKindlePreview" data-book-id="35791968" href="#" id="wrongBookLink">Not the book you’re looking for?</a>
# <h2 class="kindlePreviewHeader">
#       Preview — <cite>Still Me</cite>
#         by Jojo Moyes
#     </h2>
# </div>
# <iframe id="kindleCloudReader">
# <iframe id="wrongBookKindlePreviewScreen"></iframe>
# </iframe>
# </div>
# </div>
# <div class="gcaWinnerHeader">
# WINNER
# <span class="greyText gcaNumVotes">
# 55,300
# votes
# </span>
# </div>
# <div class="u-marginTopXSmall">
# <a class="winningTitle choice gcaBookTitle gcaBookTitle--red" href="/book/show/35791968-still-me?from_choice=true">Still Me</a>
# <div class="gcaAuthor">
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/281810.Jojo_Moyes" itemprop="url"><span itemprop="name">Jojo Moyes</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# </div>
# </div>
# <div class="readable stacked gcaBookDescription" id="description" style="right:0">
# Jojo Moyes wins the Best Fiction award for her third book in the <i>Me Before You</i> series (the first book was adapted into a tearjerker of a movie). Here heroine Louisa Clark ventures to New York City to start a new life. This is the British author’s first Goodreads Choice Award.
# </div>
# <div class="gcaSideFlourish gcaSideFlourish--left"></div>
# <div class="gcaSideFlourish gcaSideFlourish--right"></div>
# </div><div class="clear"> </div></div></div>
# </div>
# <h2 class="gcaSubheader">
# All Nominees
# •
# <div class="greyText gcaNumVotes">
# 332,119
# votes total
# </div>
# </h2>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 55,300
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="35791968" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/35791968-still-me?from_choice=true" id="bookCover_35791968"><img alt="Still Me by Jojo Moyes" src="https://images.gr-assets.com/books/1502818159l/35791968.jpg" title="Still Me by Jojo Moyes"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="2_book_35791968">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="1QX8fJqUyH3wHLie2GAaSvaFNwq6m26pxLKjoHf4Qjfgu6vm+xLIt43zUeHls6dlgZYg5sTJK4T9siCqJt3Iew=="/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_35791968"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="llKx5l0YfWgFYCh8tx/voBt5TAHGLki4E6V/LvibEQWj7OZ8PJ59oniPwQOKzFKPbGpb7bh8DZUqpfwkqb6bSQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_35791968"/>
# <input id="book_id" name="book_id" type="hidden" value="35791968"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35791968" data-submit-url="/review/rate/35791968?stars_click=true&amp;wtr_button_id=2_book_35791968" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 41,826
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="33590210" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/33590210-an-american-marriage?from_choice=true" id="bookCover_33590210"><img alt="An American Marriage by Tayari Jones" src="https://images.gr-assets.com/books/1491493625l/33590210.jpg" title="An American Marriage by Tayari Jones"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="3_book_33590210">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="s44zva5djIt5PqmZ+oNBepH191rB3acn8UtwF5B8Rt2GMGQnz9uMQQTRQObHUPxV5ubgtr+P4grIS/MdwVnMkQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="33590210"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_33590210"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="fmKJ5StA8XJfwVHqhAtCeNNLsNzyvy86Mk9g9NBLjKpL3N5/SsbxuCIuuJW52P9XpFinMIztahcLT+P+gW4G5g=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_33590210"/>
# <input id="book_id" name="book_id" type="hidden" value="33590210"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="33590210" data-submit-url="/review/rate/33590210?stars_click=true&amp;wtr_button_id=3_book_33590210" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 38,981
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36373463" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36373463-us-against-you?from_choice=true" id="bookCover_36373463"><img alt="Us Against You by Fredrik Backman" src="https://images.gr-assets.com/books/1516019348l/36373463.jpg" title="Us Against You by Fredrik Backman"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="4_book_36373463">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ecFH3ZwNGkiFU3DMSBi9K/eZGSjYkKGykgjLkhZDLmNMfxBH/Ysagvi8mbN1ywAEgIoOxKbC5J+rCEiYR2akLw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36373463"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_36373463"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="4+GKgNJuNg6nlpagFek2+UrXcYhsS0FMa8nMqSvOTg3WX90as+g2xNp5f98oOovWPcRmZBIZBGFSyU+jeuvEQQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_36373463"/>
# <input id="book_id" name="book_id" type="hidden" value="36373463"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36373463" data-submit-url="/review/rate/36373463?stars_click=true&amp;wtr_button_id=4_book_36373463" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown pollAnswer--last">
# <strong class="uitext result">
# 31,447
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="left" data-resource-id="39280445" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/39280445-nine-perfect-strangers?from_choice=true" id="bookCover_39280445"><img alt="Nine Perfect Strangers by Liane Moriarty" src="https://images.gr-assets.com/books/1529076901l/39280445.jpg" title="Nine Perfect Strangers by Liane Moriarty"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="5_book_39280445">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="i+ZDleAdapM6g2IV2DnU1kk85ipA4ithpqS27uHZC62+WBQPgZtqWUdsi2rl6mn5Pi/xxj6wbkyfpDXksPyB4Q=="/>
# <input id="book_id" name="book_id" type="hidden" value="39280445"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_39280445"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="twnkoJXsrXm889fqT3UqJr7MoQCINdK5Z7EM+CtQKzyCt7M69Gqts8EcPpVyppcJyd+27PZnl5ResY/yenWhcA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_39280445"/>
# <input id="book_id" name="book_id" type="hidden" value="39280445"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="39280445" data-submit-url="/review/rate/39280445?stars_click=true&amp;wtr_button_id=5_book_39280445" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 24,363
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="38186611" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/38186611-an-absolutely-remarkable-thing?from_choice=true" id="bookCover_38186611"><img alt="An Absolutely Remarkable Thing by Hank Green" src="https://images.gr-assets.com/books/1520448919l/38186611.jpg" title="An Absolutely Remarkable Thing by Hank Green"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="6_book_38186611">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Xk7ZHd5f9ys/F2XtBJ8Mg1EuUPcI2xD6kEglpLOVYDxr8I6Hv9n34UL4jJI5TLGsJj1HG3aJVdepSKau4rDqcA=="/>
# <input id="book_id" name="book_id" type="hidden" value="38186611"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="6_book_38186611"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="bOVTe1rSjlTWoSlv8PIsjJEKTMnYfUSIkxzFyAaKxfNZWwThO1SOnqtOwBDNIZGj5hlbJaYvAaWqHEbCV69Pvw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="6_book_38186611"/>
# <input id="book_id" name="book_id" type="hidden" value="38186611"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="38186611" data-submit-url="/review/rate/38186611?stars_click=true&amp;wtr_button_id=6_book_38186611" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 23,695
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="38820047" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/38820047-killing-commendatore?from_choice=true" id="bookCover_38820047"><img alt="Killing Commendatore by Haruki Murakami" src="https://images.gr-assets.com/books/1527854255l/38820047.jpg" title="Killing Commendatore by Haruki Murakami"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="7_book_38820047">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Sjoe2ge1ERT8x3Ic0WMPfnRzBfd9LrlBD6zSNTqM1GB/hElAZjMR3oEom2PssLJRA2ASGwN8/Gw2rFE/a6leLA=="/>
# <input id="book_id" name="book_id" type="hidden" value="38820047"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="7_book_38820047"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Q1D2MhgnozasD7hvQ5yM4DAio2ekGR+XYQgTenEm/wh27qGoeaGj/NHgURB+TzHPRzG0i9pLWrpYCJBwIAN1RA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="7_book_38820047"/>
# <input id="book_id" name="book_id" type="hidden" value="38820047"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="38820047" data-submit-url="/review/rate/38820047?stars_click=true&amp;wtr_button_id=7_book_38820047" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 18,614
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36692478" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36692478-there-there?from_choice=true" id="bookCover_36692478"><img alt="There There by Tommy Orange" src="https://images.gr-assets.com/books/1512071034l/36692478.jpg" title="There There by Tommy Orange"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="8_book_36692478">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="z+JdjBHoZv9t9ZHEnw+RqJ0H5PrDXYB3xTcamkbTtET6XAoWcG5mNRAaeLui3CyH6hTzFr0PxVr8N5mQF/Y+CA=="/>
# <input id="book_id" name="book_id" type="hidden" value="36692478"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="8_book_36692478"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ttXgp4eJO9qnilL7j1FlaS6tnbD0Uod1nQIgjQekIyKDa7c95g87ENplu4SygthGWb6KXIoAwlikAqOHVoGpbg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="8_book_36692478"/>
# <input id="book_id" name="book_id" type="hidden" value="36692478"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36692478" data-submit-url="/review/rate/36692478?stars_click=true&amp;wtr_button_id=8_book_36692478" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown pollAnswer--last">
# <strong class="uitext result">
# 17,854
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="left" data-resource-id="34275212" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/34275212-girls-burn-brighter?from_choice=true" id="bookCover_34275212"><img alt="Girls Burn Brighter by Shobha Rao" src="https://images.gr-assets.com/books/1520279618l/34275212.jpg" title="Girls Burn Brighter by Shobha Rao"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="9_book_34275212">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="l4DxAjl9+pxl5dRsKWWhWFhlczK44u4EeGw0gkI7L7qiPqaYWPv6VhgKPRMUthx3L3Zk3sawqylBbLeIEx6l9g=="/>
# <input id="book_id" name="book_id" type="hidden" value="34275212"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="9_book_34275212"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Kg1O5Vp15Rg/sa2Z3FSyI5vdBB7SlJdcGwQBC5hHAl4fsxl/O/Pl0kJeRObhhw8M7M4T8qzG0nEiBIIByWKIEg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="9_book_34275212"/>
# <input id="book_id" name="book_id" type="hidden" value="34275212"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="34275212" data-submit-url="/review/rate/34275212?stars_click=true&amp;wtr_button_id=9_book_34275212" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 17,490
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36723031" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36723031-all-we-ever-wanted?from_choice=true" id="bookCover_36723031"><img alt="All We Ever Wanted by Emily Giffin" src="https://images.gr-assets.com/books/1512578780l/36723031.jpg" title="All We Ever Wanted by Emily Giffin"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="10_book_36723031">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Im7PGlA49+TNj04C03IoDhVU9Lv7ZTG16+D8+TOmhDQX0JiAMb73LrBgp33uoZUhYkfjV4U3dJjS4H/zYoMOeA=="/>
# <input id="book_id" name="book_id" type="hidden" value="36723031"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="10_book_36723031"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Ws+JMntfbo3D5QO39+a+ehDskM7VP5frk04zhEJ3o1Jvcd6oGtluR74K6sjKNQNVZ/+HIqtt0saqTrCOE1IpHg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="10_book_36723031"/>
# <input id="book_id" name="book_id" type="hidden" value="36723031"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36723031" data-submit-url="/review/rate/36723031?stars_click=true&amp;wtr_button_id=10_book_36723031" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 15,427
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36082326" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36082326-every-note-played?from_choice=true" id="bookCover_36082326"><img alt="Every Note Played by Lisa Genova" src="https://images.gr-assets.com/books/1521364066l/36082326.jpg" title="Every Note Played by Lisa Genova"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="11_book_36082326">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="9lYebatGeS1reAZhuCHfxvAMARAy6ltnIWxm0n6Wwo/D6En3ysB55xaX7x6F8mLphx8W/Ey4HkoYbOXYL7NIww=="/>
# <input id="book_id" name="book_id" type="hidden" value="36082326"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="11_book_36082326"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="tfnMZ2yRzLfilwCXu/+UIB49F0h+hjdActCJJlahDa6AR5v9DRfMfZ946eiGLCkPaS4ApADUcm1L0AosB4SH4g=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="11_book_36082326"/>
# <input id="book_id" name="book_id" type="hidden" value="36082326"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36082326" data-submit-url="/review/rate/36082326?stars_click=true&amp;wtr_button_id=11_book_36082326" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 7,343
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="35480518" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/35480518-the-female-persuasion?from_choice=true" id="bookCover_35480518"><img alt="The Female Persuasion by Meg Wolitzer" src="https://images.gr-assets.com/books/1503001734l/35480518.jpg" title="The Female Persuasion by Meg Wolitzer"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="12_book_35480518">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="WRUEPq8heEPtuj6AB5udTnYKMaTNzCXppmFH1NG/1YBsq1Okzqd4iZBV1/86SCBhARkmSLOeYMSfYcTegJpfzA=="/>
# <input id="book_id" name="book_id" type="hidden" value="35480518"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="12_book_35480518"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="bLfqeIJWY2m9jPYcutxrwhTfqMj8jqWVxnxYavU2ITNZCb3i49Bjo8BjH2OHD9btY8y/JILc4Lj/fNtgpBOrfw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="12_book_35480518"/>
# <input id="book_id" name="book_id" type="hidden" value="35480518"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35480518" data-submit-url="/review/rate/35480518?stars_click=true&amp;wtr_button_id=12_book_35480518" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown pollAnswer--last">
# <strong class="uitext result">
# 6,839
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="left" data-resource-id="36840397" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36840397-a-place-for-us?from_choice=true" id="bookCover_36840397"><img alt="A Place for Us by Fatima Farheen Mirza" src="https://images.gr-assets.com/books/1517006183l/36840397.jpg" title="A Place for Us by Fatima Farheen Mirza"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="13_book_36840397">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="LBaICWUPxQS+obDFLFmAKoaZkJca4kz6dSesUwXHFKgZqN+TBInFzsNOWboRij0F8YqHe2SwCddMJy9ZVOKe5A=="/>
# <input id="book_id" name="book_id" type="hidden" value="36840397"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="13_book_36840397"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="rME9EdReOBecr6rPLwDNagNd5WuVWr4tMdhdoyqWAEmZf2qLtdg43eFAQ7AS03BFdE7yh+sI+wAI2N6pe7OKBQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="13_book_36840397"/>
# <input id="book_id" name="book_id" type="hidden" value="36840397"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# ...
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Ld93mb7o9VeqxaQrhArcTX+GlYnSKTzBruCRzWFln0sYYSAD3271ndcqTVS52WFiCJWCZax7eeyX4BLHMEAVBw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="17_book_35187203"/>
# <input id="book_id" name="book_id" type="hidden" value="35187203"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35187203" data-submit-url="/review/rate/35187203?stars_click=true&amp;wtr_button_id=17_book_35187203" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 3,126
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="35952871" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/35952871-you-think-it-i-ll-say-it?from_choice=true" id="bookCover_35952871"><img alt="You Think It, I'll Say It by Curtis Sittenfeld" src="https://images.gr-assets.com/books/1509832627l/35952871.jpg" title="You Think It, I'll Say It by Curtis Sittenfeld"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="18_book_35952871">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="5SWPpp97d+R3Oc1k0CuMjeDnpsJbw2ulSPNMY308TyrQm9g8/v13LgrWJBvt+DGil/SxLiWRLohx889pLBnFZg=="/>
# <input id="book_id" name="book_id" type="hidden" value="35952871"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="18_book_35952871"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="BhyLcMolI/wGNQW7SXBDz9pfxM47zLdPJ4gOX9B9LT4zotzqq6MjNnva7MR0o/7grUzTIkWe8mIeiI1VgVincg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="18_book_35952871"/>
# <input id="book_id" name="book_id" type="hidden" value="35952871"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="35952871" data-submit-url="/review/rate/35952871?stars_click=true&amp;wtr_button_id=18_book_35952871" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 1,973
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36249638" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36249638-how-to-walk-away?from_choice=true" id="bookCover_36249638"><img alt="How to Walk Away by Katherine Center" src="https://images.gr-assets.com/books/1507579931l/36249638.jpg" title="How to Walk Away by Katherine Center"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="19_book_36249638">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="y/v2xta4ePnLkOjZyWj8vnAltdKgwok9304nxLcVNDP+RaFctz54M7Z/Aab0u0GRBzaiPt6QzBDmTqTO5jC+fw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36249638"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="19_book_36249638"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="I5EsdFLBd/JRMfLXc1VPH42oimmyW+phRT5YGe2Gy+MWL3vuM0d3OCzeG6hOhvIw+rudhcwJr0x8PtsTvKNBrw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="19_book_36249638"/>
# <input id="book_id" name="book_id" type="hidden" value="36249638"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36249638" data-submit-url="/review/rate/36249638?stars_click=true&amp;wtr_button_id=19_book_36249638" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown">
# <strong class="uitext result">
# 1,641
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="right" data-resource-id="36723245" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36723245-the-book-of-essie?from_choice=true" id="bookCover_36723245"><img alt="The Book of Essie by Meghan MacLean Weir" src="https://images.gr-assets.com/books/1515873936l/36723245.jpg" title="The Book of Essie by Meghan MacLean Weir"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="20_book_36723245">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="g5n0Gm4q8xhhKpsNeDFwUzwLyuouaphHTT2pZk/G/1O2J6OAD6zz0hzFcnJF4s18SxjdBlA43Wp0PSpsHuN1Hw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36723245"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="20_book_36723245"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="RPTzdQHh9fyFz9OudKs/Gd+ZQBXPKRQ4TuRUd0dcATxxSqTvYGf1NvggOtFJeII2qIpX+bF7URV35Nd9FnmLcA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="20_book_36723245"/>
# <input id="book_id" name="book_id" type="hidden" value="36723245"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36723245" data-submit-url="/review/rate/36723245?stars_click=true&amp;wtr_button_id=20_book_36723245" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="inlineblock pollAnswer resultShown pollAnswer--last">
# <strong class="uitext result">
# 1,352
# votes
# </strong>
# <div class="answerWrapper">
# <div class="js-tooltipTrigger tooltipTrigger" data-placement="left" data-resource-id="36373648" data-resource-type="GCA">
# <a class="pollAnswer__bookLink" href="/book/show/36373648-the-mars-room?from_choice=true" id="bookCover_36373648"><img alt="The Mars Room by Rachel Kushner" src="https://images.gr-assets.com/books/1524991696l/36373648.jpg" title="The Mars Room by Rachel Kushner"/></a>
# </div>
# </div>
# <div class="answerVoteWrapper__wtr">
# <div class="wtrButtonContainer wtrSignedOut" id="21_book_36373648">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Q2qp05ZxecDCKmLB0TYWxAWPMtsTy1OGGIg72k4baFN21P5J9/d5Cr/Fi77s5avrcpwlN22ZFqshiLjQHz7iHw=="/>
# <input id="book_id" name="book_id" type="hidden" value="36373648"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="21_book_36373648"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="X5j0JQu2/LEqFToty60Ur6phMgtJmBJXFLSdTi9LS2lqJqO/ajD8e1f601L2fqmA3XIl5zfKV3ottB5Efm7BJQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="21_book_36373648"/>
# <input id="book_id" name="book_id" type="hidden" value="36373648"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="true"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="36373648" data-submit-url="/review/rate/36373648?stars_click=true&amp;wtr_button_id=21_book_36373648" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="uitext loadingDialog" id="loadingVote_poll_179510" style="display:none">
# <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# Saving your vote...
# </div>
# <div class="uitext loadingDialog" id="loadingClearVote_poll_179510" style="display:none">
# <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# Clearing your vote...
# </div>
# <div class="gcaDivider">
# <div class="gcaDivider__centerpiece"></div>
# </div>
# </div>

# %%
coolcats = soup.find_all('a', {"class":"pollAnswer__bookLink"})[0]

# %%
fiction__book_list_2018 = []
for a in soup.find_all('a',{"class":"pollAnswer__bookLink"},  href=True):
    fiction__book_list_2018.append('https://www.goodreads.com' + (a['href']))

# %%
#urls for all best fiction books 2018 (for one genre only)
fiction__book_list_2018
# Out:
# ['https://www.goodreads.com/book/show/35791968-still-me?from_choice=true',
#  'https://www.goodreads.com/book/show/33590210-an-american-marriage?from_choice=true',
#  'https://www.goodreads.com/book/show/36373463-us-against-you?from_choice=true',
#  'https://www.goodreads.com/book/show/39280445-nine-perfect-strangers?from_choice=true',
#  'https://www.goodreads.com/book/show/38186611-an-absolutely-remarkable-thing?from_choice=true',
#  'https://www.goodreads.com/book/show/38820047-killing-commendatore?from_choice=true',
#  'https://www.goodreads.com/book/show/36692478-there-there?from_choice=true',
#  'https://www.goodreads.com/book/show/34275212-girls-burn-brighter?from_choice=true',
#  'https://www.goodreads.com/book/show/36723031-all-we-ever-wanted?from_choice=true',
#  'https://www.goodreads.com/book/show/36082326-every-note-played?from_choice=true',
#  'https://www.goodreads.com/book/show/35480518-the-female-persuasion?from_choice=true',
#  'https://www.goodreads.com/book/show/36840397-a-place-for-us?from_choice=true',
#  'https://www.goodreads.com/book/show/39072220-a-spark-of-light?from_choice=true',
#  'https://www.goodreads.com/book/show/36203391-my-year-of-rest-and-relaxation?from_choice=true',
#  'https://www.goodreads.com/book/show/34262106-everything-here-is-beautiful?from_choice=true',
#  'https://www.goodreads.com/book/show/35187203-the-overstory?from_choice=true',
#  'https://www.goodreads.com/book/show/35952871-you-think-it-i-ll-say-it?from_choice=true',
#  'https://www.goodreads.com/book/show/36249638-how-to-walk-away?from_choice=true',
#  'https://www.goodreads.com/book/show/36723245-the-book-of-essie?from_choice=true',
#  'https://www.goodreads.com/book/show/36373648-the-mars-room?from_choice=true']

# %%
#this pulls urls for every genre
soup.find_all('a', {'class':'categoriesList__categoryLink categoriesList__categoryLink--current'})
choice_rewards_genre_list_2018 = []
for a in soup.find_all('a',{'class':"categoriesList__categoryLink categoriesList__categoryLink--current"},  href=True):
    choice_rewards_genre_list_2018.append('https://www.goodreads.com' + (a['href']))

# %%
choice_rewards_genre_list_2018[0]
# Out:
# 'https://www.goodreads.com/choiceawards/best-mystery-thriller-books-2018'
