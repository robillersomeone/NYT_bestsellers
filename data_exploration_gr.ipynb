# %% [markdown]
# # Good Reads Books Dataframe

# %% [markdown]
# Using BeautifulSoup and requests for webscraping.

# %%
from bs4 import BeautifulSoup as bs
import urllib.request
import requests
import re
import time
import pandas as pd

# %% [markdown]
# Testing out the initial web page.

# %%
link = 'https://www.goodreads.com/book/show/39863520-how-to-date-men-when-you-hate-men'
page = urllib.request.urlopen(link)

soup = bs(page, 'html.parser')

#soup.prettify()

# %%
soup.title
# Out:
# <title>
# How to Date Men When You Hate Men by Blythe Roberson
# </title>

# %% [markdown]
# Get a list of URLs for 15 comments about a book.

# %%
url = 'https://www.goodreads.com/book/reviews/39863520-how-to-date-men-when-you-hate-men?rating=&text_only=true'
r = requests.get(url).content
prefix = 'https://www.goodreads.com/review/show/'
[prefix + x.split('\\')[0] for x in str(r).split(prefix)][1:]
# Out:
# ['https://www.goodreads.com/review/show/2485843786',
#  'https://www.goodreads.com/review/show/2526013822',
#  'https://www.goodreads.com/review/show/2531161402',
#  'https://www.goodreads.com/review/show/2523399786',
#  'https://www.goodreads.com/review/show/2659372184',
#  'https://www.goodreads.com/review/show/2528847854',
#  'https://www.goodreads.com/review/show/2557301544',
#  'https://www.goodreads.com/review/show/2510917265',
#  'https://www.goodreads.com/review/show/2663926644',
#  'https://www.goodreads.com/review/show/2592884376',
#  'https://www.goodreads.com/review/show/2559122775',
#  'https://www.goodreads.com/review/show/2549570510',
#  'https://www.goodreads.com/review/show/2553921881',
#  'https://www.goodreads.com/review/show/2553192610',
#  'https://www.goodreads.com/review/show/2654676052',
#  'https://www.goodreads.com/review/show/2523825663',
#  'https://www.goodreads.com/review/show/2612203671']

# %% [markdown]
# ## URLs for the top books 2018

# %% [markdown]
# We started by getting the webpages for the best fiction books of 2018.

# %%
url_2018 = 'https://www.goodreads.com/choiceawards/best-fiction-books-2018'
r = urllib.request.urlopen(url_2018)

# %%
soup = bs(r, 'html.parser')
#soup

# %%
# looking at all the divs with this class
#soup.find('div', {"class":"pollContents"})

# %%
coolcats = soup.find_all('a', {"class":"pollAnswer__bookLink"})[0]

# %% [markdown]
# Making a list to get the URLs from each book on the best fiction 2018 page.

# %%
fiction__book_list_2018 = []
for a in soup.find_all('a',{"class":"pollAnswer__bookLink"},  href=True):
    fiction__book_list_2018.append('https://www.goodreads.com' + (a['href']))

# %%
#urls for all best fiction books 2018 (for one genre only)
# there are 20 books on each of the best of pages
fiction__book_list_2018
# Out:
# ['https://www.goodreads.com/book/show/35791968-still-me?from_choice=true',
#  'https://www.goodreads.com/book/show/33590210-an-american-marriage?from_choice=true',
#  'https://www.goodreads.com/book/show/36373463-us-against-you?from_choice=true',
#  'https://www.goodreads.com/book/show/39280445-nine-perfect-strangers?from_choice=true',
#  'https://www.goodreads.com/book/show/38186611-an-absolutely-remarkable-thing?from_choice=true',
#  'https://www.goodreads.com/book/show/38820047-killing-commendatore?from_choice=true',
#  'https://www.goodreads.com/book/show/36692478-there-there?from_choice=true',
#  'https://www.goodreads.com/book/show/34275212-girls-burn-brighter?from_choice=true',
#  'https://www.goodreads.com/book/show/36723031-all-we-ever-wanted?from_choice=true',
#  'https://www.goodreads.com/book/show/36082326-every-note-played?from_choice=true',
#  'https://www.goodreads.com/book/show/35480518-the-female-persuasion?from_choice=true',
#  'https://www.goodreads.com/book/show/36840397-a-place-for-us?from_choice=true',
#  'https://www.goodreads.com/book/show/39072220-a-spark-of-light?from_choice=true',
#  'https://www.goodreads.com/book/show/36203391-my-year-of-rest-and-relaxation?from_choice=true',
#  'https://www.goodreads.com/book/show/34262106-everything-here-is-beautiful?from_choice=true',
#  'https://www.goodreads.com/book/show/35187203-the-overstory?from_choice=true',
#  'https://www.goodreads.com/book/show/35952871-you-think-it-i-ll-say-it?from_choice=true',
#  'https://www.goodreads.com/book/show/36249638-how-to-walk-away?from_choice=true',
#  'https://www.goodreads.com/book/show/36723245-the-book-of-essie?from_choice=true',
#  'https://www.goodreads.com/book/show/36373648-the-mars-room?from_choice=true']

# %%
#this pulls urls for every genre
soup.find_all('a', {'class':'categoriesList__categoryLink categoriesList__categoryLink--current'})
choice_rewards_genre_list_2018 = []
for a in soup.find_all('a',{'class':"categoriesList__categoryLink categoriesList__categoryLink--current"},  href=True):
    choice_rewards_genre_list_2018.append('https://www.goodreads.com' + (a['href']))

# %%
choice_rewards_genre_list_2018
# Out:
# ['https://www.goodreads.com/choiceawards/best-mystery-thriller-books-2018',
#  'https://www.goodreads.com/choiceawards/best-historical-fiction-books-2018',
#  'https://www.goodreads.com/choiceawards/best-fantasy-books-2018',
#  'https://www.goodreads.com/choiceawards/best-of-the-best-2018',
#  'https://www.goodreads.com/choiceawards/best-romance-books-2018',
#  'https://www.goodreads.com/choiceawards/best-science-fiction-books-2018',
#  'https://www.goodreads.com/choiceawards/best-horror-books-2018',
#  'https://www.goodreads.com/choiceawards/best-humor-books-2018',
#  'https://www.goodreads.com/choiceawards/best-nonfiction-books-2018',
#  'https://www.goodreads.com/choiceawards/best-memoir-autobiography-books-2018',
#  'https://www.goodreads.com/choiceawards/best-history-biography-books-2018',
#  'https://www.goodreads.com/choiceawards/best-science-technology-books-2018',
#  'https://www.goodreads.com/choiceawards/best-food-cookbooks-2018',
#  'https://www.goodreads.com/choiceawards/best-graphic-novels-comics-2018',
#  'https://www.goodreads.com/choiceawards/best-poetry-books-2018',
#  'https://www.goodreads.com/choiceawards/best-debut-author-2018',
#  'https://www.goodreads.com/choiceawards/best-young-adult-fiction-books-2018',
#  'https://www.goodreads.com/choiceawards/best-young-adult-fantasy-books-2018',
#  'https://www.goodreads.com/choiceawards/best-childrens-books-2018',
#  'https://www.goodreads.com/choiceawards/best-picture-books-2018']

# %% [markdown]
# book_list_2018 is all URLs for the best books of 2018.

# %%
book_list_2018 = []
for i in choice_rewards_genre_list_2018:
    url = i
    r = urllib.request.urlopen(url)
    soup = bs(r, 'html.parser')
    for a in soup.find_all('a',{"class":"pollAnswer__bookLink"},  href=True):
        book_list_2018.append('https://www.goodreads.com' + (a['href']))

# %%
book_list_2018 = book_list_2018 + fiction__book_list_2018
len(book_list_2018 + fiction__book_list_2018)
# Out:
# 440

# %%
# this is all urls for the best books of 2018
len(book_list_2018)
# Out:
# 420

# %%
book_list_2018
# Out:
# ['https://www.goodreads.com/book/show/36124936-the-outsider?from_choice=true',
#  'https://www.goodreads.com/book/show/34848682-the-woman-in-the-window?from_choice=true',
#  'https://www.goodreads.com/book/show/40696964-lethal-white?from_choice=true',
#  'https://www.goodreads.com/book/show/34189556-the-wife-between-us?from_choice=true',
#  'https://www.goodreads.com/book/show/35297426-then-she-was-gone?from_choice=true',
#  'https://www.goodreads.com/book/show/35085389-the-president-is-missing?from_choice=true',
#  'https://www.goodreads.com/book/show/36373481-the-death-of-mrs-westaway?from_choice=true',
#  'https://www.goodreads.com/book/show/39723581-the-witch-elm?from_choice=true',
#  'https://www.goodreads.com/book/show/34275222-force-of-nature?from_choice=true',
#  'https://www.goodreads.com/book/show/34275231-sometimes-i-lie?from_choice=true',
#  'https://www.goodreads.com/book/show/36337550-the-7-deaths-of-evelyn-hardcastle?from_choice=true',
#  'https://www.goodreads.com/book/show/36388243-something-in-the-water?from_choice=true',
#  'https://www.goodreads.com/book/show/35356382-the-chalk-man?from_choice=true',
#  'https://www.goodreads.com/book/show/35133064-the-widows-of-malabar-hill?from_choice=true',
#  'https://www.goodreads.com/book/show/37638161-leverage-in-death?from_choice=true',
#  'https://www.goodreads.com/book/show/36448554-bring-me-back?from_choice=true',
#  'https://www.goodreads.com/book/show/35305625-the-broken-girls?from_choice=true',
#  'https://www.goodreads.com/book/show/36750068-the-last-time-i-lied?from_choice=true',
#  'https://www.goodreads.com/book/show/36604959-jane-doe?from_choice=true',
#  'https://www.goodreads.com/book/show/38496758-wrecked?from_choice=true',
#  'https://www.goodreads.com/book/show/34927828-the-great-alone?from_choice=true',
#  'https://www.goodreads.com/book/show/37486222-the-tattooist-of-auschwitz?from_choice=true',
#  'https://www.goodreads.com/book/show/30288282-the-immortalists?from_choice=true',
#  'https://www.goodreads.com/book/show/38530939-the-clockmaker-s-daughter?from_choice=true',
#  'https://www.goodreads.com/book/show/37703550-where-the-crawdads-sing?from_choice=true',
#  'https://www.goodreads.com/book/show/34374628-next-year-in-havana?from_choice=true',
#  'https://www.goodreads.com/book/show/36373417-the-map-of-salt-and-stars?from_choice=true',
#  'https://www.goodreads.com/book/show/37946414-transcription?from_choice=true',
#  'https://www.goodreads.com/book/show/36723246-warlight?from_choice=true',
#  'https://www.goodreads.com/book/show/36381085-the-summer-wives?from_choice=true',
#  'https://www.goodreads.com/book/show/35397026-my-dear-hamilton?from_choice=true',
#  'https://www.goodreads.com/book/show/38236861-unsheltered?from_choice=true',
#  'https://www.goodreads.com/book/show/36097619-the-tuscan-child?from_choice=true',
#  'https://www.goodreads.com/book/show/36636727-fruit-of-the-drunken-tree?from_choice=true',
#  'https://www.goodreads.com/book/show/36614133-love-and-ruin?from_choice=true',
#  'https://www.goodreads.com/book/show/35889209-white-rose-black-forest?from_choice=true',
#  'https://www.goodreads.com/book/show/37946116-war-of-the-wolf?from_choice=true',
#  'https://www.goodreads.com/book/show/39828805-bellewether?from_choice=true',
#  'https://www.goodreads.com/book/show/35995489-the-extraordinary-life-of-sam-hell?from_choice=true',
#  'https://www.goodreads.com/book/show/36739329-the-great-believers?from_choice=true',
#  'https://www.goodreads.com/book/show/35959740-circe?from_choice=true',
#  'https://www.goodreads.com/book/show/36521316-the-shape-of-water?from_choice=true',
#  'https://www.goodreads.com/book/show/37168303-spinning-silver?from_choice=true',
#  'https://www.goodreads.com/book/show/34311452-year-one?from_choice=true',
#  'https://www.goodreads.com/book/show/35126152-iron-and-magic?from_choice=true',
#  'https://www.goodreads.com/book/show/35887181-the-poppy-war?from_choice=true',
#  'https://www.goodreads.com/book/show/27366528-beneath-the-sugar-sky?from_choice=true',
#  'https://www.goodreads.com/book/show/35457273-high-voltage?from_choice=true',
#  'https://www.goodreads.com/book/show/35839437-burn-bright?from_choice=true',
#  'https://www.goodreads.com/book/show/35710709-grey-sister?from_choice=true',
#  'https://www.goodreads.com/book/show/36204070-the-book-of-m?from_choice=true',
#  'https://www.goodreads.com/book/show/34050917-the-girl-in-the-tower?from_choice=true',
#  'https://www.goodreads.com/book/show/35342928-age-of-war?from_choice=true',
#  'https://www.goodreads.com/book/show/40629159-the-land?from_choice=true',
#  'https://www.goodreads.com/book/show/38395454-time-s-convert?from_choice=true',
#  'https://www.goodreads.com/book/show/17333180-magic-triumphs?from_choice=true',
#  'https://www.goodreads.com/book/show/35271523-senlin-ascends?from_choice=true',
#  'https://www.goodreads.com/book/show/28811018-wrath-of-empire?from_choice=true',
#  'https://www.goodreads.com/book/show/37007781-foundryside?from_choice=true',
#  'https://www.goodreads.com/book/show/35052265-bloody-rose?from_choice=true',
#  'https://www.goodreads.com/book/show/32075671-the-hate-u-give?from_choice=true',
#  'https://www.goodreads.com/book/show/18143977-all-the-light-we-cannot-see?from_choice=true',
#  'https://www.goodreads.com/book/show/26073150-a-court-of-mist-and-fury?from_choice=true',
#  'https://www.goodreads.com/book/show/4667024-the-help?from_choice=true',
#  'https://www.goodreads.com/book/show/21853621-the-nightingale?from_choice=true',
#  'https://www.goodreads.com/book/show/18007564-the-martian?from_choice=true',
#  'https://www.goodreads.com/book/show/12837725-gone-girl?from_choice=true',
#  'https://www.goodreads.com/book/show/15783514-the-ocean-at-the-end-of-the-lane?from_choice=true',
#  'https://www.goodreads.com/book/show/6148028-catching-fire?from_choice=true',
#  'https://www.goodreads.com/book/show/11870085-the-fault-in-our-stars?from_choice=true',
#  'https://www.goodreads.com/book/show/10644930-11-22-63?from_choice=true',
#  'https://www.goodreads.com/book/show/18006496-queen-of-shadows?from_choice=true',
#  'https://www.goodreads.com/book/show/13422727-a-dance-with-dragons?from_choice=true',
#  'https://www.goodreads.com/book/show/34273236-little-fires-everywhere?from_choice=true',
#  'https://www.goodreads.com/book/show/15745753-eleanor-park?from_choice=true',
#  'https://www.goodreads.com/book/show/27276318-it-ends-with-us?from_choice=true',
#  'https://www.goodreads.com/book/show/15839976-red-rising?from_choice=true',
#  'https://www.goodreads.com/book/show/23766634-a-court-of-wings-and-ruin?from_choice=true',
#  'https://www.goodreads.com/book/show/32148570-before-we-were-yours?from_choice=true',
#  'https://www.goodreads.com/book/show/18460392-all-the-bright-places?from_choice=true',
#  'https://www.goodreads.com/book/show/36577586-the-kiss-quotient?from_choice=true',
#  'https://www.goodreads.com/book/show/37588357-all-your-perfects?from_choice=true',
#  'https://www.goodreads.com/book/show/35259631-the-wedding-date?from_choice=true',
#  'https://www.goodreads.com/book/show/35819729-the-thief?from_choice=true',
#  'https://www.goodreads.com/book/show/32024902-darker?from_choice=true',
#  'https://www.goodreads.com/book/show/37769929-pestilence?from_choice=true',
#  'https://www.goodreads.com/book/show/38503484-from-lukov-with-love?from_choice=true',
#  'https://www.goodreads.com/book/show/34466910-roomies?from_choice=true',
#  'https://www.goodreads.com/book/show/36587905-the-hookup?from_choice=true',
#  'https://www.goodreads.com/book/show/35271196-hello-stranger?from_choice=true',
#  'https://www.goodreads.com/book/show/39862558-birthday-girl?from_choice=true',
#  'https://www.goodreads.com/book/show/36593240-sex-not-love?from_choice=true',
#  'https://www.goodreads.com/book/show/35271238-a-princess-in-theory?from_choice=true',
#  'https://www.goodreads.com/book/show/39086215-robbie?from_choice=true',
#  'https://www.goodreads.com/book/show/36301036-wicked-and-the-wallflower?from_choice=true',
#  'https://www.goodreads.com/book/show/40189670-josh-and-hazel-s-guide-to-not-dating?from_choice=true',
#  'https://www.goodreads.com/book/show/36395874-dr-strange-beard?from_choice=true',
#  'https://www.goodreads.com/book/show/36373564-the-simple-wild?from_choice=true',
#  'https://www.goodreads.com/book/show/36395764-marriage-of-inconvenience?from_choice=true',
#  'https://www.goodreads.com/book/show/39655232-alphas-like-us?from_choice=true',
#  'https://www.goodreads.com/book/show/37534835-vengeful?from_choice=true',
#  'https://www.goodreads.com/book/show/33257757-iron-gold?from_choice=true',
#  'https://www.goodreads.com/book/show/37796866-vox?from_choice=true',
#  'https://www.goodreads.com/book/show/35820656-only-human?from_choice=true',
#  'https://www.goodreads.com/book/show/35099035-red-clocks?from_choice=true',
#  'https://www.goodreads.com/book/show/34386617-the-night-masquerade?from_choice=true',
#  'https://www.goodreads.com/book/show/33357930-persepolis-rising?from_choice=true',
#  'https://www.goodreads.com/book/show/36223860-artificial-condition?from_choice=true',
#  'https://www.goodreads.com/book/show/35230913-the-oracle-year?from_choice=true',
#  'https://www.goodreads.com/book/show/35018901-head-on?from_choice=true',
#  'https://www.goodreads.com/book/show/36220698-record-of-a-spaceborn-few?from_choice=true',
#  'https://www.goodreads.com/book/show/36385830-alliances?from_choice=true',
#  'https://www.goodreads.com/book/show/36348525-severance?from_choice=true',
#  'https://www.goodreads.com/book/show/33080122-the-calculating-stars?from_choice=true',
#  'https://www.goodreads.com/book/show/38362809-rosewater?from_choice=true',
#  'https://www.goodreads.com/book/show/32076670-ball-lightning?from_choice=true',
#  'https://www.goodreads.com/book/show/35297390-space-opera?from_choice=true',
#  'https://www.goodreads.com/book/show/33413556-the-gone-world?from_choice=true',
#  'https://www.goodreads.com/book/show/36373688-revenant-gun?from_choice=true',
#  'https://www.goodreads.com/book/show/37534901-the-consuming-fire?from_choice=true',
#  'https://www.goodreads.com/book/show/38355410-elevation?from_choice=true',
#  'https://www.goodreads.com/book/show/35410511-baby-teeth?from_choice=true',
#  'https://www.goodreads.com/book/show/38363799-dracul?from_choice=true',
#  'https://www.goodreads.com/book/show/34449265-the-passion-of-cleopatra?from_choice=true',
#  'https://www.goodreads.com/book/show/36373398-the-woman-in-the-woods?from_choice=true',
#  'https://www.goodreads.com/book/show/36381091-the-cabin-at-the-end-of-the-world?from_choice=true',
#  'https://www.goodreads.com/book/show/37824221-craven-manor?from_choice=true',
#  'https://www.goodreads.com/book/show/30285766-the-hunger?from_choice=true',
#  'https://www.goodreads.com/book/show/39790706-we-sold-our-souls?from_choice=true',
#  'https://www.goodreads.com/book/show/39217966-flight-or-fright?from_choice=true',
#  'https://www.goodreads.com/book/show/36342156-the-anomaly?from_choice=true',
#  'https://www.goodreads.com/book/show/35035160-the-merry-spinster?from_choice=true',
#  'https://www.goodreads.com/book/show/37510662-foe?from_choice=true',
#  'https://www.goodreads.com/book/show/39707880-the-carrow-haunt?from_choice=true',
#  'https://www.goodreads.com/book/show/35655156-the-summer-children?from_choice=true',
#  'https://www.goodreads.com/book/show/38608066-the-siren-and-the-specter?from_choice=true',
#  'https://www.goodreads.com/book/show/38392331-generation-z?from_choice=true',
#  'https://www.goodreads.com/book/show/35297544-zero-day?from_choice=true',
#  'https://www.goodreads.com/book/show/36049101-the-devil-and-the-deep?from_choice=true',
#  'https://www.goodreads.com/book/show/36694914-the-labyrinth-index?from_choice=true',
#  'https://www.goodreads.com/book/show/34974310-the-last-black-unicorn?from_choice=true',
#  'https://www.goodreads.com/book/show/36341620-calypso?from_choice=true',
#  'https://www.goodreads.com/book/show/38919266-the-greatest-love-story-ever-told?from_choice=true',
#  'https://www.goodreads.com/book/show/40598936-this-will-only-hurt-a-little?from_choice=true',
#  'https://www.goodreads.com/book/show/36875820-hope-never-dies?from_choice=true',
#  'https://www.goodreads.com/book/show/36467874-so-close-to-being-the-sh-t-y-all-don-t-even-know?from_choice=true',
#  'https://www.goodreads.com/book/show/38649805-everything-s-trash-but-it-s-okay?from_choice=true',
#  'https://www.goodreads.com/book/show/36261280-i-see-life-through-ros--colored-glasses?from_choice=true',
#  'https://www.goodreads.com/book/show/35959613-how-to-american?from_choice=true',
#  'https://www.goodreads.com/book/show/40170039-how-not-to-get-shot?from_choice=true',
#  'https://www.goodreads.com/book/show/38532145-my-squirrel-days?from_choice=true',
#  'https://www.goodreads.com/book/show/39022876-always-look-on-the-bright-side-of-life?from_choice=true',
#  'https://www.goodreads.com/book/show/36373406-my-life-as-a-goddess?from_choice=true',
#  'https://www.goodreads.com/book/show/36220700-springfield-confidential?from_choice=true',
#  'https://www.goodreads.com/book/show/30531870-just-the-funny-parts?from_choice=true',
#  'https://www.goodreads.com/book/show/36546633-hits-and-misses?from_choice=true',
#  'https://www.goodreads.com/book/show/35259574-look-alive-out-there?from_choice=true',
#  'https://www.goodreads.com/book/show/36742998-your-dad-stole-my-rake?from_choice=true',
#  'https://www.goodreads.com/book/show/37954228-feminasty?from_choice=true',
#  'https://www.goodreads.com/book/show/36906099-maeve-in-america?from_choice=true',
#  'https://www.goodreads.com/book/show/35271190-i-ll-be-gone-in-the-dark?from_choice=true',
#  'https://www.goodreads.com/book/show/35754629-girl-wash-your-face?from_choice=true',
#  'https://www.goodreads.com/book/show/41012533-fear?from_choice=true',
#  'https://www.goodreads.com/book/show/40009804-whiskey-in-a-teacup?from_choice=true',
#  'https://www.goodreads.com/book/show/39507318-the-library-book?from_choice=true',
#  'https://www.goodreads.com/book/show/38820046-21-lessons-for-the-21st-century?from_choice=true',
#  'https://www.goodreads.com/book/show/36381052-not-that-bad?from_choice=true',
#  'https://www.goodreads.com/book/show/35099718-so-you-want-to-talk-about-race?from_choice=true',
#  'https://www.goodreads.com/book/show/30257963-12-rules-for-life?from_choice=true',
#  'https://www.goodreads.com/book/show/40933227-factfulness?from_choice=true',
#  'https://www.goodreads.com/book/show/37976541-bad-blood?from_choice=true',
#  'https://www.goodreads.com/book/show/35820413-fascism?from_choice=true',
#  'https://www.goodreads.com/book/show/35181833-all-american-murder?from_choice=true',
#  'https://www.goodreads.com/book/show/35696171-enlightenment-now?from_choice=true',
#  'https://www.goodreads.com/book/show/40121378-atomic-habits?from_choice=true',
#  'https://www.goodreads.com/book/show/36222733-russian-roulette?from_choice=true',
#  'https://www.goodreads.com/book/show/37486540-dopesick?from_choice=true',
#  'https://www.goodreads.com/book/show/35901186-the-feather-thief?from_choice=true',
#  'https://www.goodreads.com/book/show/36507099-skin-in-the-game?from_choice=true',
#  'https://www.goodreads.com/book/show/36638638-the-path-between-us?from_choice=true',
#  'https://www.goodreads.com/book/show/35133922-educated?from_choice=true',
#  'https://www.goodreads.com/book/show/38744839-becoming?from_choice=true',
#  'https://www.goodreads.com/book/show/38508771-in-pieces?from_choice=true',
#  'https://www.goodreads.com/book/show/35582344-this-is-me?from_choice=true',
#  'https://www.goodreads.com/book/show/35718164-a-river-in-darkness?from_choice=true',
#  'https://www.goodreads.com/book/show/34964998-when-they-call-you-a-terrorist?from_choice=true',
#  'https://www.goodreads.com/book/show/35108805-a-higher-loyalty?from_choice=true',
#  'https://www.goodreads.com/book/show/35137915-i-am-i-am-i-am?from_choice=true',
#  'https://www.goodreads.com/book/show/36086537-the-girl-who-smiled-beads?from_choice=true',
#  'https://www.goodreads.com/book/show/35133923-everything-happens-for-a-reason?from_choice=true',
#  'https://www.goodreads.com/book/show/34964905-the-sun-does-shine?from_choice=true',
#  'https://www.goodreads.com/book/show/35840657-heart-berries?from_choice=true',
#  'https://www.goodreads.com/book/show/30297153-all-you-can-ever-know?from_choice=true',
#  'https://www.goodreads.com/book/show/35018200-tell-me-more?from_choice=true',
#  'https://www.goodreads.com/book/show/39218044-small-fry?from_choice=true',
#  'https://www.goodreads.com/book/show/35068683-brave?from_choice=true',
#  'https://www.goodreads.com/book/show/35959678-and-now-we-have-everything?from_choice=true',
#  'https://www.goodreads.com/book/show/35340555-room-to-dream?from_choice=true',
#  'https://www.goodreads.com/book/show/36373407-tragedy-plus-time?from_choice=true',
#  'https://www.goodreads.com/book/show/29430746-heavy?from_choice=true',
#  'https://www.goodreads.com/book/show/38656999-the-good-neighbor?from_choice=true',
#  'https://www.goodreads.com/book/show/37534762-robin?from_choice=true',
#  'https://www.goodreads.com/book/show/35959199-barracoon?from_choice=true',
#  'https://www.goodreads.com/book/show/36369872-house-of-dreams?from_choice=true',
#  'https://www.goodreads.com/book/show/35743037-the-woman-s-hour?from_choice=true',
#  'https://www.goodreads.com/book/show/34859714-jefferson-s-daughters?from_choice=true',
#  'https://www.goodreads.com/book/show/37488430-fly-girls?from_choice=true',
#  'https://www.goodreads.com/book/show/35414997-rocket-men?from_choice=true',
#  'https://www.goodreads.com/book/show/38363272-in-the-hurricane-s-eye?from_choice=true',
#  'https://www.goodreads.com/book/show/35342927-the-monk-of-mokha?from_choice=true',
#  'https://www.goodreads.com/book/show/38657386-leadership?from_choice=true',
#  'https://www.goodreads.com/book/show/36743867-lincoln-s-last-trial?from_choice=true',
#  'https://www.goodreads.com/book/show/36204285-origin-story?from_choice=true',
#  'https://www.goodreads.com/book/show/38212158-these-truths?from_choice=true',
#  'https://www.goodreads.com/book/show/33598223-rise-and-kill-first?from_choice=true',
#  'https://www.goodreads.com/book/show/22318476-boom-town?from_choice=true',
#  'https://www.goodreads.com/book/show/35457359-god-save-texas?from_choice=true',
#  'https://www.goodreads.com/book/show/38714362-killing-the-ss?from_choice=true',
#  'https://www.goodreads.com/book/show/36373560-indianapolis?from_choice=true',
#  'https://www.goodreads.com/book/show/38525349-the-soul-of-america?from_choice=true',
#  'https://www.goodreads.com/book/show/35820369-the-rise-and-fall-of-the-dinosaurs?from_choice=true',
#  'https://www.goodreads.com/book/show/40277241-brief-answers-to-the-big-questions?from_choice=true',
#  'https://www.goodreads.com/book/show/36391536-she-has-her-mother-s-laugh?from_choice=true',
#  'https://www.goodreads.com/book/show/35953464-broad-band?from_choice=true',
#  'https://www.goodreads.com/book/show/36710811-how-to-change-your-mind?from_choice=true',
#  'https://www.goodreads.com/book/show/36739330-spying-on-whales?from_choice=true',
#  'https://www.goodreads.com/book/show/36407347-the-future-of-humanity?from_choice=true',
#  'https://www.goodreads.com/book/show/35412097-when?from_choice=true',
#  'https://www.goodreads.com/book/show/36442813-the-order-of-time?from_choice=true',
#  'https://www.goodreads.com/book/show/38589832-accessory-to-war?from_choice=true',
#  'https://www.goodreads.com/book/show/35604796-what-is-real?from_choice=true',
#  'https://www.goodreads.com/book/show/36205015-the-space-barons?from_choice=true',
#  'https://www.goodreads.com/book/show/38749668-the-sawbones-book?from_choice=true',
#  'https://www.goodreads.com/book/show/36341728-lost-in-math?from_choice=true',
#  'https://www.goodreads.com/book/show/35876360-the-big-ones?from_choice=true',
#  'https://www.goodreads.com/book/show/39026990-how-to-invent-everything?from_choice=true',
#  'https://www.goodreads.com/book/show/36722606-taming-the-sun?from_choice=true',
#  'https://www.goodreads.com/book/show/35749414-who-we-are-and-how-we-got-here?from_choice=true',
#  'https://www.goodreads.com/book/show/34762552-algorithms-of-oppression?from_choice=true',
#  'https://www.goodreads.com/book/show/36373639-the-tangled-tree?from_choice=true',
#  'https://www.goodreads.com/book/show/40004097-cravings?from_choice=true',
#  'https://www.goodreads.com/book/show/36381100-magnolia-table?from_choice=true',
#  'https://www.goodreads.com/book/show/36627287-tasty-latest-and-greatest?from_choice=true',
#  'https://www.goodreads.com/book/show/35804613-a-literary-tea-party?from_choice=true',
#  'https://www.goodreads.com/book/show/40006421-cook-like-a-pro?from_choice=true',
#  'https://www.goodreads.com/book/show/38502290-are-you-there-god-it-s-me-margarita?from_choice=true',
#  'https://www.goodreads.com/book/show/35306053-hot-for-food-vegan-comfort-classics?from_choice=true',
#  'https://www.goodreads.com/book/show/36001408-sweet-revenge?from_choice=true',
#  'https://www.goodreads.com/book/show/35741051-giada-s-italy?from_choice=true',
#  'https://www.goodreads.com/book/show/35398011-vegan-100?from_choice=true',
#  'https://www.goodreads.com/book/show/33656178-bobby-flay-fit?from_choice=true',
#  'https://www.goodreads.com/book/show/38532190-baking-all-year-round?from_choice=true',
#  'https://www.goodreads.com/book/show/35342935-the-food-explorer?from_choice=true',
#  'https://www.goodreads.com/book/show/35592077-buttermilk-graffiti?from_choice=true',
#  'https://www.goodreads.com/book/show/38121211-skinnytaste-one-and-done?from_choice=true',
#  'https://www.goodreads.com/book/show/39797678-ottolenghi-simple?from_choice=true',
#  'https://www.goodreads.com/book/show/36711236-milk?from_choice=true',
#  'https://www.goodreads.com/book/show/36856216-killing-it?from_choice=true',
#  'https://www.goodreads.com/book/show/34017050-hippie-food?from_choice=true',
#  'https://www.goodreads.com/book/show/37826508-now-again?from_choice=true',
#  'https://www.goodreads.com/book/show/35924705-herding-cats?from_choice=true',
#  'https://www.goodreads.com/book/show/36374390-little-moments-of-love?from_choice=true',
#  'https://www.goodreads.com/book/show/34963526-saga-vol-8?from_choice=true',
#  'https://www.goodreads.com/book/show/34849019-ms-marvel-vol-8?from_choice=true',
#  'https://www.goodreads.com/book/show/34506912-the-prince-and-the-dressmaker?from_choice=true',
#  'https://www.goodreads.com/book/show/35989512-paper-girls-vol-4?from_choice=true',
#  'https://www.goodreads.com/book/show/35684941-the-adventure-zone?from_choice=true',
#  'https://www.goodreads.com/book/show/34506937-brazen?from_choice=true',
#  'https://www.goodreads.com/book/show/36373825-fence-vol-1?from_choice=true',
#  'https://www.goodreads.com/book/show/35758072-am-i-there-yet-the-loop-de-loop-zigzagging-journey-to-adulthood?from_choice=true',
#  'https://www.goodreads.com/book/show/30623067-be-prepared?from_choice=true',
#  'https://www.goodreads.com/book/show/36963204-bingo-love?from_choice=true',
#  'https://www.goodreads.com/book/show/34930815-gone-rogue?from_choice=true',
#  'https://www.goodreads.com/book/show/37534577-check-please?from_choice=true',
#  'https://www.goodreads.com/book/show/37533587-sabrina?from_choice=true',
#  'https://www.goodreads.com/book/show/35651693-the-wicked-the-divine-vol-6?from_choice=true',
#  'https://www.goodreads.com/book/show/37491890-monstress-vol-3?from_choice=true',
#  'https://www.goodreads.com/book/show/37822649-hey-kiddo?from_choice=true',
#  'https://www.goodreads.com/book/show/34954925-black-hammer-vol-2?from_choice=true',
#  'https://www.goodreads.com/book/show/34849021-black-bolt-vol-1?from_choice=true',
#  'https://www.goodreads.com/book/show/35924698-the-witch-doesn-t-burn-in-this-one?from_choice=true',
#  'https://www.goodreads.com/book/show/35396841-the-poet-x?from_choice=true',
#  'https://www.goodreads.com/book/show/38255339-useless-magic?from_choice=true',
#  'https://www.goodreads.com/book/show/38926449-the-dark-between-stars?from_choice=true',
#  'https://www.goodreads.com/book/show/38532187-taking-the-arrow-out-of-the-heart?from_choice=true',
#  'https://www.goodreads.com/book/show/35999004-rebound?from_choice=true',
#  'https://www.goodreads.com/book/show/36477795-if-they-come-for-us?from_choice=true',
#  'https://www.goodreads.com/book/show/35260128-take-me-with-you?from_choice=true',
#  'https://www.goodreads.com/book/show/36100966-sea-of-strangers?from_choice=true',
#  'https://www.goodreads.com/book/show/36456129-she-felt-like-feeling-nothing?from_choice=true',
#  'https://www.goodreads.com/book/show/34594981-helium?from_choice=true',
#  'https://www.goodreads.com/book/show/35297455-for-every-one?from_choice=true',
#  'https://www.goodreads.com/book/show/35782247-wade-in-the-water?from_choice=true',
#  'https://www.goodreads.com/book/show/36479694-the-future?from_choice=true',
#  'https://www.goodreads.com/book/show/41241311-a-love-letter-from-the-girls-who-feel-everything?from_choice=true',
#  'https://www.goodreads.com/book/show/36036176-heart-talk?from_choice=true',
#  'https://www.goodreads.com/book/show/36479356-american-sonnets-for-my-past-and-future-assassin?from_choice=true',
#  'https://www.goodreads.com/book/show/35540804-blood-water-paint?from_choice=true',
#  'https://www.goodreads.com/book/show/37941942-the-flame?from_choice=true',
#  'https://www.goodreads.com/book/show/35356376-brown?from_choice=true',
#  'https://www.goodreads.com/book/show/34728667-children-of-blood-and-bone?from_choice=true',
#  'https://www.goodreads.com/book/show/34848682-the-woman-in-the-window?from_choice=true',
#  'https://www.goodreads.com/book/show/37486222-the-tattooist-of-auschwitz?from_choice=true',
#  'https://www.goodreads.com/book/show/36577586-the-kiss-quotient?from_choice=true',
#  'https://www.goodreads.com/book/show/34499221-to-kill-a-kingdom?from_choice=true',
#  'https://www.goodreads.com/book/show/36692478-there-there?from_choice=true',
#  'https://www.goodreads.com/book/show/35887181-the-poppy-war?from_choice=true',
#  'https://www.goodreads.com/book/show/35604686-the-astonishing-color-of-after?from_choice=true',
#  'https://www.goodreads.com/book/show/36388243-something-in-the-water?from_choice=true',
#  'https://www.goodreads.com/book/show/35356382-the-chalk-man?from_choice=true',
#  'https://www.goodreads.com/book/show/38186611-an-absolutely-remarkable-thing?from_choice=true',
#  'https://www.goodreads.com/book/show/36840397-a-place-for-us?from_choice=true',
#  'https://www.goodreads.com/book/show/36373417-the-map-of-salt-and-stars?from_choice=true',
#  'https://www.goodreads.com/book/show/36337550-the-7-deaths-of-evelyn-hardcastle?from_choice=true',
#  'https://www.goodreads.com/book/show/34726469-sky-in-the-deep?from_choice=true',
#  'https://www.goodreads.com/book/show/34275212-girls-burn-brighter?from_choice=true',
#  'https://www.goodreads.com/book/show/34262106-everything-here-is-beautiful?from_choice=true',
#  'https://www.goodreads.com/book/show/36636727-fruit-of-the-drunken-tree?from_choice=true',
#  'https://www.goodreads.com/book/show/36187116-witchmark?from_choice=true',
#  'https://www.goodreads.com/book/show/35297106-the-terminal-list?from_choice=true',
#  'https://www.goodreads.com/book/show/31180248-leah-on-the-offbeat?from_choice=true',
#  'https://www.goodreads.com/book/show/34810320-sadie?from_choice=true',
#  'https://www.goodreads.com/book/show/36341204-what-if-it-s-us?from_choice=true',
#  'https://www.goodreads.com/book/show/36987719-all-the-little-lights?from_choice=true',
#  'https://www.goodreads.com/book/show/37880094-the-lady-s-guide-to-petticoats-and-piracy?from_choice=true',
#  'https://www.goodreads.com/book/show/35604686-the-astonishing-color-of-after?from_choice=true',
#  'https://www.goodreads.com/book/show/32333338-save-the-date?from_choice=true',
#  'https://www.goodreads.com/book/show/29589074-truly-devious?from_choice=true',
#  'https://www.goodreads.com/book/show/35887533-puddin?from_choice=true',
#  'https://www.goodreads.com/book/show/35297272-emergency-contact?from_choice=true',
#  'https://www.goodreads.com/book/show/35520012-love-life-and-the-list?from_choice=true',
#  'https://www.goodreads.com/book/show/31625048-let-s-talk-about-love?from_choice=true',
#  'https://www.goodreads.com/book/show/35297469-starry-eyes?from_choice=true',
#  'https://www.goodreads.com/book/show/30969755-the-cheerleaders?from_choice=true',
#  'https://www.goodreads.com/book/show/33810737-the-case-for-jamie?from_choice=true',
#  'https://www.goodreads.com/book/show/31207017-love-hate-other-filters?from_choice=true',
#  'https://www.goodreads.com/book/show/38720939-a-very-large-expanse-of-sea?from_choice=true',
#  'https://www.goodreads.com/book/show/35604682-tyler-johnson-was-here?from_choice=true',
#  'https://www.goodreads.com/book/show/34325090-i-was-born-for-this?from_choice=true',
#  'https://www.goodreads.com/book/show/40239755-the-accidentals?from_choice=true',
#  'https://www.goodreads.com/book/show/33590260-kingdom-of-ash?from_choice=true',
#  'https://www.goodreads.com/book/show/34728667-children-of-blood-and-bone?from_choice=true',
#  'https://www.goodreads.com/book/show/26032825-the-cruel-prince?from_choice=true',
#  'https://www.goodreads.com/book/show/27188596-war-storm?from_choice=true',
#  'https://www.goodreads.com/book/show/31076583-a-court-of-frost-and-starlight?from_choice=true',
#  'https://www.goodreads.com/book/show/24909347-obsidio?from_choice=true',
#  'https://www.goodreads.com/book/show/33555224-thunderhead?from_choice=true',
#  'https://www.goodreads.com/book/show/34992929-restore-me?from_choice=true',
#  'https://www.goodreads.com/book/show/30809786-a-reaper-at-the-gates?from_choice=true',
#  'https://www.goodreads.com/book/show/29386918-wildcard?from_choice=true',
#  'https://www.goodreads.com/book/show/23197837-the-belles?from_choice=true',
#  'https://www.goodreads.com/book/show/30223025-dread-nation?from_choice=true',
#  'https://www.goodreads.com/book/show/35820633-the-fates-divide?from_choice=true',
#  'https://www.goodreads.com/book/show/34726469-sky-in-the-deep?from_choice=true',
#  'https://www.goodreads.com/book/show/25446343-muse-of-nightmares?from_choice=true',
#  'https://www.goodreads.com/book/show/39348113-skyward?from_choice=true',
#  'https://www.goodreads.com/book/show/34275232-the-hazel-wood?from_choice=true',
#  'https://www.goodreads.com/book/show/36329818-legendary?from_choice=true',
#  'https://www.goodreads.com/book/show/29456569-lifel1k3?from_choice=true',
#  'https://www.goodreads.com/book/show/35495083-sightwitch?from_choice=true',
#  'https://www.goodreads.com/book/show/28006096-the-burning-maze?from_choice=true',
#  'https://www.goodreads.com/book/show/35403058-city-of-ghosts?from_choice=true',
#  'https://www.goodreads.com/book/show/33784323-the-magic-misfits?from_choice=true',
#  'https://www.goodreads.com/book/show/36222611-aru-shah-and-the-end-of-time?from_choice=true',
#  'https://www.goodreads.com/book/show/36086513-amal-unbound?from_choice=true',
#  'https://www.goodreads.com/book/show/35959634-ghost-boys?from_choice=true',
#  'https://www.goodreads.com/book/show/36644148-the-penderwicks-at-last?from_choice=true',
#  'https://www.goodreads.com/book/show/36546966-willa-of-the-wood?from_choice=true',
#  'https://www.goodreads.com/book/show/33004208-the-miscalculations-of-lightning-girl?from_choice=true',
#  'https://www.goodreads.com/book/show/36443315-bob?from_choice=true',
#  'https://www.goodreads.com/book/show/36127488-front-desk?from_choice=true',
#  'https://www.goodreads.com/book/show/35297562-sunny?from_choice=true',
#  'https://www.goodreads.com/book/show/35068526-you-go-first?from_choice=true',
#  'https://www.goodreads.com/book/show/35464020-the-night-diary?from_choice=true',
#  'https://www.goodreads.com/book/show/32618983-the-serpent-s-secret?from_choice=true',
#  'https://www.goodreads.com/book/show/39217633-louisiana-s-way-home?from_choice=true',
#  'https://www.goodreads.com/book/show/37822631-the-golden-tower?from_choice=true',
#  'https://www.goodreads.com/book/show/38903002-wrath-of-the-dragon-king?from_choice=true',
#  'https://www.goodreads.com/book/show/36959639-small-spaces?from_choice=true',
#  'https://www.goodreads.com/book/show/36373280-the-unforgettable-guinevere-st-clair?from_choice=true',
#  'https://www.goodreads.com/book/show/35396839-i-am-enough?from_choice=true',
#  'https://www.goodreads.com/book/show/39319247-a-day-in-the-life-of-marlon-bundo?from_choice=true',
#  'https://www.goodreads.com/book/show/35488059-little-leaders?from_choice=true',
#  'https://www.goodreads.com/book/show/36341954-we-don-t-eat-our-classmates?from_choice=true',
#  'https://www.goodreads.com/book/show/35138182-petra?from_choice=true',
#  'https://www.goodreads.com/book/show/35248504-the-rabbit-listened?from_choice=true',
#  'https://www.goodreads.com/book/show/35580105-hello-lighthouse?from_choice=true',
#  'https://www.goodreads.com/book/show/36373562-ocean-meets-sky?from_choice=true',
#  'https://www.goodreads.com/book/show/35356379-love?from_choice=true',
#  'https://www.goodreads.com/book/show/26532714-juli-n-is-a-mermaid?from_choice=true',
#  'https://www.goodreads.com/book/show/35566693-the-word-collector?from_choice=true',
#  'https://www.goodreads.com/book/show/35182933-baby-monkey-private-eye?from_choice=true',
#  'https://www.goodreads.com/book/show/34791219-drawn-together?from_choice=true',
#  'https://www.goodreads.com/book/show/35631757-islandborn?from_choice=true',
#  'https://www.goodreads.com/book/show/40524608-lulu-is-a-rhinoceros?from_choice=true',
#  'https://www.goodreads.com/book/show/37506301-the-day-you-begin?from_choice=true',
#  'https://www.goodreads.com/book/show/34204247-prince-knight?from_choice=true',
#  'https://www.goodreads.com/book/show/35833840-they-say-blue?from_choice=true',
#  'https://www.goodreads.com/book/show/41443051-the-truth-pixie?from_choice=true',
#  'https://www.goodreads.com/book/show/38495981-franklin-and-luna-go-to-the-moon?from_choice=true',
#  'https://www.goodreads.com/book/show/35791968-still-me?from_choice=true',
#  'https://www.goodreads.com/book/show/33590210-an-american-marriage?from_choice=true',
#  'https://www.goodreads.com/book/show/36373463-us-against-you?from_choice=true',
#  'https://www.goodreads.com/book/show/39280445-nine-perfect-strangers?from_choice=true',
#  'https://www.goodreads.com/book/show/38186611-an-absolutely-remarkable-thing?from_choice=true',
#  'https://www.goodreads.com/book/show/38820047-killing-commendatore?from_choice=true',
#  'https://www.goodreads.com/book/show/36692478-there-there?from_choice=true',
#  'https://www.goodreads.com/book/show/34275212-girls-burn-brighter?from_choice=true',
#  'https://www.goodreads.com/book/show/36723031-all-we-ever-wanted?from_choice=true',
#  'https://www.goodreads.com/book/show/36082326-every-note-played?from_choice=true',
#  'https://www.goodreads.com/book/show/35480518-the-female-persuasion?from_choice=true',
#  'https://www.goodreads.com/book/show/36840397-a-place-for-us?from_choice=true',
#  'https://www.goodreads.com/book/show/39072220-a-spark-of-light?from_choice=true',
#  'https://www.goodreads.com/book/show/36203391-my-year-of-rest-and-relaxation?from_choice=true',
#  'https://www.goodreads.com/book/show/34262106-everything-here-is-beautiful?from_choice=true',
#  'https://www.goodreads.com/book/show/35187203-the-overstory?from_choice=true',
#  'https://www.goodreads.com/book/show/35952871-you-think-it-i-ll-say-it?from_choice=true',
#  'https://www.goodreads.com/book/show/36249638-how-to-walk-away?from_choice=true',
#  'https://www.goodreads.com/book/show/36723245-the-book-of-essie?from_choice=true',
#  'https://www.goodreads.com/book/show/36373648-the-mars-room?from_choice=true']

# %%
# goodreads rating
#testing one book's info
link = 'https://www.goodreads.com/book/show/36124936-the-outsider?from_choice=true'
page = urllib.request.urlopen(link)

soup = bs(page, 'html.parser')

soup.find('span',{"itemprop":"ratingValue"})
# Out:
# <span itemprop="ratingValue">
#   4.07
# </span>

# %%
def get_rating(soup):    
    get_rating = soup.find('span',{"itemprop":"ratingValue"})
    get_rating = get_rating.get_text().replace('\n', '').replace(' ', '')
    return get_rating

# %%
rating = get_rating()
rating
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-219-38a44956b048> in <module>()
# ----> 1 rating = get_rating()
#       2 rating
#
# TypeError: get_rating() missing 1 required positional argument: 'soup'

# %%
def get_title(soup):
    get_title = soup.find('h1',{"id":"bookTitle"})
    get_title = get_title.get_text().replace('\n', '').replace('  ', '')
    return get_title

# %%
title = get_title()
title
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-221-82f0db9e951e> in <module>()
# ----> 1 title = get_title()
#       2 title
#
# TypeError: get_title() missing 1 required positional argument: 'soup'

# %%
def get_author(soup):
    get_author = soup.find('span', {'itemprop':"name"})
    get_author = get_author.get_text()
    return get_author

# %%
author = get_author()
author
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-223-026c319427cb> in <module>()
# ----> 1 author = get_author()
#       2 author
#
# TypeError: get_author() missing 1 required positional argument: 'soup'

# %%
def get_publisher(soup):
    get_publisher = soup.find('div', {'id':"details"})
    get_publisher = get_publisher.contents[3].get_text()
    get_publisher = get_publisher.replace('\n', '')
    get_publisher = re.findall(r'(?<=by ).+\b', get_publisher)[0]
    return get_publisher

# %%
publisher = get_publisher()
publisher
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-225-ce578ee7d7ec> in <module>()
# ----> 1 publisher = get_publisher()
#       2 publisher
#
# TypeError: get_publisher() missing 1 required positional argument: 'soup'

# %%
get_publisher
# Out:
# <function __main__.get_publisher(soup)>

# %%
# ((?<=Published        ).+\b)(\d{4})
def get_date(soup):
    get_date = soup.find('div', {'id':"details"})
    get_date = get_date.contents[3].get_text()
    get_date = get_date.replace('\n', '')
    get_date = re.findall(r'((?<=Published        ).+\b)(\d{4})', get_date)[0]
    return get_date
def get_month_day(soup):
    get_month_day = get_date(soup)[0]
    return get_month_day
def get_month(soup):
    get_month = get_date(soup)[0].split(' ')[0]
    return get_month
def get_year(soup):
    get_year = get_date(soup)[1]
    return get_year

# %%
month = get_month()
month
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-228-d91ffbcd9865> in <module>()
# ----> 1 month = get_month()
#       2 month
#
# TypeError: get_month() missing 1 required positional argument: 'soup'

# %%
year = get_year()
year
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-229-ca1546a892f0> in <module>()
# ----> 1 year = get_year()
#       2 year
#
# TypeError: get_year() missing 1 required positional argument: 'soup'

# %%
def get_pages(soup):
    get_pages = soup.find('span', {'itemprop':"numberOfPages"})
    get_pages = get_pages.get_text().split(' ')[0]
    return get_pages

# %%
pages = get_pages()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-231-6e23e942d495> in <module>()
# ----> 1 pages = get_pages()
#
# TypeError: get_pages() missing 1 required positional argument: 'soup'

# %%
def get_genre(soup):
    get_genre = soup.find('a', {'class':"actionLinkLite bookPageGenreLink"})
    get_genre = get_genre.get_text()
    return get_genre

# %%
genre = get_genre()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-233-fa5c13dc893a> in <module>()
# ----> 1 genre = get_genre()
#
# TypeError: get_genre() missing 1 required positional argument: 'soup'

# %%
def get_descrip(soup):
    get_descrip = soup.find('div', {'id':"description"})
    get_descrip = get_descrip.find('span').contents[0]
    return get_descrip

# %%
descrip = get_descrip()
descrip
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-dd38f3cdc9cb> in <module>()
# ----> 1 descrip = get_descrip()
#       2 descrip
#
# TypeError: get_descrip() missing 1 required positional argument: 'soup'

# %%
def get_format(soup):
    get_format = soup.find('span', {'itemprop':"bookFormat"})
    get_format = get_format.get_text()
    return get_format

# %%
forma = get_format()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-237-855c34188218> in <module>()
# ----> 1 forma = get_format()
#
# TypeError: get_format() missing 1 required positional argument: 'soup'

# %%
# take a list and return a list of dictionaries

def book_info(url):
    all_the_books = []
    for x in url:
        link = x
        #link = 'https://www.goodreads.com/book/show/6148028-catching-fire?from_choice=true'
        #probably add timer here
        time.sleep(2)
        page = urllib.request.urlopen(link)
        soup = bs(page, 'html.parser')
        try:
            dictionary = {'rating': get_rating(soup), 'author': get_author(soup), 'publisher' : get_publisher(soup),'title':get_title(soup), 'pages': get_pages(soup),
             'description': get_descrip(soup), 'format': get_format(soup), 'genre': get_genre(soup), 'year': get_year(soup), 'month': get_month(soup)}
        except:
            try:
                dictionary = {'rating': get_rating(soup), 'author': get_author(soup),'publisher' : get_publisher(soup), 'title':get_title(soup), 'pages': get_pages(soup),
                 'description': get_descrip(soup), 'format': get_format(soup), 'genre': get_genre(soup)}
            except:
                pass
        all_the_books.append(dictionary)
    #print(all_the_books)
    return all_the_books

# %%
fire = book_info()

# %%
fire
# Out:
# {'rating': '4.29',
#  'author': 'Suzanne Collins',
#  'publisher': 'Scholastic Press',
#  'title': 'Catching Fire',
#  'pages': '391',
#  'description': <b>Sparks are igniting.<br/>Flames are spreading.<br/>And the Capitol wants revenge.</b>,
#  'format': 'Hardcover',
#  'genre': 'Young Adult',
#  'year': '2009',
#  'month': 'September'}

# %%
# put timer, loop through every book lol

# %%
all_books = book_info(book_list_2018)

# %%
all_books
# Out:
# [{'rating': '4.07',
#   'author': 'Stephen King',
#   'publisher': 'Scribner',
#   'title': 'The Outsider',
#   'pages': '561',
#   'description': 'An unspeakable crime. A confounding investigation. At a time when the King brand has never been stronger, he has delivered one of his most unsettling and compulsively readable stories.',
#   'format': 'Hardcover',
#   'genre': 'Horror',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.96',
#   'author': 'A.J. Finn',
#   'publisher': 'William Morrow',
#   'title': 'The Woman in the Window',
#   'pages': '431',
#   'description': 'Anna Fox lives alone—a recluse in her New York City home, unable to venture outside. She spends her day drinking wine (maybe too much), watching old movies, recalling happier times . . . and spying on her neighbors.',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.30',
#   'author': 'Robert Galbraith',
#   'publisher': 'Mulholland Books',
#   'title': 'Lethal White',
#   'pages': '650',
#   'description': <i>“I seen a kid killed…He strangled it, up by the horse.”</i>,
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.85',
#   'author': 'Greer Hendricks',
#   'publisher': "St. Martin's Press",
#   'title': 'The Wife Between Us',
#   'pages': '346',
#   'description': 'When you read this book, you will make many assumptions.',
#   'format': 'Hardcover',
#   'genre': 'Thriller',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.09',
#   'author': 'Lisa Jewell',
#   'publisher': 'Atria Books',
#   'title': 'Then She Was Gone',
#   'pages': '359',
#   'description': 'THEN',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.87',
#   'author': 'Bill Clinton',
#   'publisher': 'Little, Brown and Company and Knopf',
#   'title': 'The President Is Missing',
#   'pages': '513',
#   'description': <i>The President Is Missing</i>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.84',
#   'author': 'Ruth Ware',
#   'publisher': 'Gallery/Scout Press',
#   'title': 'The Death of Mrs. Westaway',
#   'pages': '368',
#   'description': 'On a day that begins like any other, Hal receives a mysterious letter bequeathing her a substantial inheritance. She realizes very quickly that the letter was sent to the wrong person—but also that the cold-reading skills she’s honed as a tarot card reader might help her claim the money.',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.63',
#   'author': 'Tana French',
#   'publisher': 'Viking',
#   'title': 'The Witch Elm',
#   'pages': '509',
#   'description': 'Toby is a happy-go-lucky charmer who’s dodged a scrape at work and is celebrating with friends when the night takes a turn that will change his life – he surprises two burglars who beat him and leave him for dead. Struggling to recover from his injuries, beginning to understand that he might never be the same man again, he takes refuge at his family’s ancestral home to car',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.87',
#   'author': 'Jane Harper',
#   'publisher': 'Flatiron Books                          (first published September 26th 2017',
#   'title': 'Force of Nature',
#   'pages': '326',
#   'description': 'Five women reluctantly pick up their backpacks and start walking along a muddy track.',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '3.86',
#   'author': 'Alice Feeney',
#   'publisher': 'Flatiron Books',
#   'title': 'Sometimes I Lie',
#   'pages': '262',
#   'description': <b> <i>My name is Amber Reynolds. There are three things you should know about me:</i> </b>,
#   'format': 'Hardcover',
#   'genre': 'Thriller',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.03',
#   'author': 'Stuart Turton',
#   'publisher': 'Sourcebooks Landmark                          (first published February 8th 2018',
#   'title': 'The 7½ Deaths of Evelyn Hardcastle',
#   'pages': '438',
#   'description': <b>The Rules of Blackheath</b>,
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.66',
#   'author': 'Catherine Steadman',
#   'publisher': 'Ballantine',
#   'title': 'Something in the Water',
#   'pages': '342',
#   'description': <b>A shocking discovery on a honeymoon in paradise changes the lives of a picture-perfect couple in this taut psychological thriller debut--for readers of Ruth Ware, Paula Hawkins, and Shari Lapena.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.73',
#   'author': 'C.J. Tudor',
#   'publisher': 'Crown Publishing Group (NY',
#   'title': 'The Chalk Man',
#   'pages': '280',
#   'description': 'In 1986, Eddie and his friends are just kids on the verge of adolescence. They spend their days biking around their sleepy English village and looking for any taste of excitement they can get. The chalk men are their secret code: little chalk stick figures they leave for one another as messages only they can understand. But then a mysterious chalk man leads them right to a',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '3.94',
#   'author': 'Sujata Massey',
#   'publisher': 'Soho Press',
#   'title': 'The Widows of Malabar Hill',
#   'pages': '385',
#   'description': "Bombay, 1921: Perveen Mistry, the daughter of a respected Zoroastrian family, has just joined her father's law firm, becoming one of the first female lawyers in India. Armed with a legal education from Oxford, Perveen also has a tragic personal history that makes her especially devoted to championing and protecting women's rights. ",
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.37',
#   'author': 'J.D. Robb',
#   'publisher': "St. Martin's Press",
#   'title': 'Leverage in Death',
#   'pages': '385',
#   'description': 'Lieutenant Eve Dallas puzzles over a bizarre suicide bombing in a Wall St. office building in the latest in the #1 New York Times bestselling series…',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.50',
#   'author': 'B.A. Paris',
#   'publisher': "St. Martin's Press                          (first published March 8th 2018",
#   'title': 'Bring Me Back',
#   'pages': '291',
#   'description': 'Finn and Layla are young, in love, and on vacation. They’re driving along the highway when Finn decides to stop at a service station to use the restroom. He hops out of the car, locks the doors behind him, and goes inside. When he returns Layla is gone—never to be seen again. That is the story Finn told to the police. But it is not the whole story.',
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.08',
#   'author': 'Simone St. James',
#   'publisher': 'Berkley Books',
#   'title': 'The Broken Girls',
#   'pages': '336',
#   'description': <b>A breakout suspense novel from the award-winning author of <i>The Haunting of Maddy Clare</i>.</b>,
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.10',
#   'author': 'Riley Sager',
#   'publisher': 'Dutton Books',
#   'title': 'The Last Time I Lied',
#   'pages': '370',
#   'description': <b>In the new novel from the bestselling author of <i>Final Girls</i>, <i>The Last Time I Lied </i>follows a young woman as she returns to her childhood summer camp to uncover the truth about a tragedy that happened there fifteen years ago.</b>,
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.09',
#   'author': 'Victoria Helen Stone',
#   'publisher': 'Lake Union Publishing',
#   'title': 'Jane Doe',
#   'pages': '258',
#   'description': <b>A double life with a single purpose: revenge.</b>,
#   'format': 'Hardcover',
#   'genre': 'Thriller',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '3.94',
#   'author': 'Joe Ide',
#   'publisher': 'Mulholland Books',
#   'title': 'Wrecked',
#   'pages': '352',
#   'description': "Isaiah Quintabe--IQ for short--has never been more successful, or felt more alone. A series of high-profile wins in his hometown of East Long Beach have made him so notorious that he can hardly go to the corner store without being recognized. Dodson, once his sidekick, is now his full-fledged partner, hell-bent on giving IQ's PI business some real legitimacy: a Facebook pa",
#   'format': 'Hardcover',
#   'genre': 'Mystery',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '4.33',
#   'author': 'Kristin Hannah',
#   'publisher': "St. Martin's Press",
#   'title': 'The Great Alone',
#   'pages': '440',
#   'description': 'Alaska, 1974.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.33',
#   'author': 'Heather   Morris',
#   'publisher': 'Harper Paperbacks                          (first published January 2018',
#   'title': 'The Tattooist of Auschwitz',
#   'pages': '272',
#   'description': 'Based on interviews that were conducted with Holocaust survivor and Auschwitz-Birkenau tattooist Ludwig (Lale) Sokolov—a love story in the midst of atrocity.',
#   'format': 'Paperback',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.73',
#   'author': 'Chloe  Benjamin',
#   'publisher': "G.P. Putnam's Sons",
#   'title': 'The Immortalists',
#   'pages': '346',
#   'description': 'If you knew the date of your death, how would you live your life?',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '3.80',
#   'author': 'Kate Morton',
#   'publisher': 'Atria Books                          (first published September 20th 2018',
#   'title': "The Clockmaker's Daughter",
#   'pages': '485',
#   'description': <i>My real name, no one remembers. The truth about that summer, no one else knows.</i>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '4.53',
#   'author': 'Delia Owens',
#   'publisher': "G.P. Putnam's Sons",
#   'title': 'Where the Crawdads Sing',
#   'pages': '384',
#   'description': <b>A novel about a young woman determined to make her way in the wilds of North Carolina, and the two men that will break her isolation open.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.01',
#   'author': 'Chanel Cleeton',
#   'publisher': 'Penguin/Berkley',
#   'title': 'Next Year in Havana',
#   'pages': '361',
#   'description': 'After the death of her beloved grandmother, a Cuban-American woman travels to Havana, where she discovers the roots of her identity--and unearths a family secret hidden since the revolution...',
#   'format': 'Paperback',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '3.89',
#   'author': 'Jennifer Zeynab Joukhadar',
#   'publisher': 'Touchstone',
#   'title': 'The Map of Salt and Stars',
#   'pages': '361',
#   'description': 'The story of two girls living eight hundred years apart—a modern-day Syrian refugee seeking safety and a medieval adventurer apprenticed to a legendary mapmaker.',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.60',
#   'author': 'Kate Atkinson',
#   'publisher': 'Little, Brown and Company                          (first published September 6th 2018',
#   'title': 'Transcription',
#   'pages': '352',
#   'description': 'In 1940, eighteen-year old Juliet Armstrong is reluctantly recruited into the world of espionage. Sent to an obscure department of MI5 tasked with monitoring the comings and goings of British Fascist sympathizers, she discovers the work to be by turns both tedious and terrifying. But after the war has ended, she presumes the events of those years have been relegated to the',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.73',
#   'author': 'Michael Ondaatje',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'Warlight',
#   'pages': '285',
#   'description': <b>A novel that tells a story set in the decade after World War II through the lives of a small group of characters and two teenagers whose lives are indelibly shaped by their unwitting involvement.</b>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.75',
#   'author': 'Beatriz Williams',
#   'publisher': 'William Morrow                          (first published July 3rd 2018',
#   'title': 'The Summer Wives',
#   'pages': '384',
#   'description': <i>New York Times</i>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.27',
#   'author': 'Stephanie Dray',
#   'publisher': 'William Morrow',
#   'title': 'My Dear Hamilton',
#   'pages': '641',
#   'description': <i>A general’s daughter…</i>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.69',
#   'author': 'Barbara Kingsolver',
#   'publisher': 'Harper',
#   'title': 'Unsheltered',
#   'pages': '464',
#   'description': 'The ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.98',
#   'author': 'Rhys Bowen',
#   'publisher': 'Lake Union Publishing',
#   'title': 'The Tuscan Child',
#   'pages': '336',
#   'description': <b>A novel about a woman who braves her father’s hidden past to discover his secrets…</b>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '3.96',
#   'author': 'Ingrid Rojas Contreras',
#   'publisher': 'Doubleday',
#   'title': 'Fruit of the Drunken Tree',
#   'pages': '304',
#   'description': "In the vein of Isabel Allende and Gabriel Garcia Marquez, a mesmerizing debut set against the backdrop of the devastating violence of 1990's Colombia about a sheltered young girl and a teenage maid who strike an unlikely friendship that threatens to undo them both.",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.84',
#   'author': 'Paula McLain',
#   'publisher': 'Ballantine Books',
#   'title': 'Love and Ruin',
#   'pages': '389',
#   'description': 'The bestselling author of The Paris Wife returns to the subject of Ernest Hemingway in a novel about his passionate, stormy marriage to Martha Gellhorn—a fiercely independent, ambitious young woman who would become one of the greatest war correspondents of the twentieth century',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.12',
#   'author': 'Eoin Dempsey',
#   'publisher': 'Lake Union Publishing',
#   'title': 'White Rose, Black Forest',
#   'pages': '270',
#   'description': <b>In the shadows of World War II, trust becomes the greatest risk of all for two strangers.</b>,
#   'format': 'Paperback',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.35',
#   'author': 'Bernard Cornwell',
#   'publisher': 'Harper',
#   'title': 'War of the Wolf',
#   'pages': '352',
#   'description': 'Bernard Cornwell’s epic story of the making of England continues in this eleventh installment in the bestselling Saxon Tales series—"like ',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.98',
#   'author': 'Susanna Kearsley',
#   'publisher': 'Sourcebooks Landmark                          (first published August 6th 2018',
#   'title': 'Bellewether',
#   'pages': '448',
#   'description': <em> <strong>"The house, when I first saw it, seemed intent on guarding what it knew; but we all learned, by the end of it, that secrets aren't such easy things to keep."</strong> </em>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.36',
#   'author': 'Robert Dugoni',
#   'publisher': 'Lake Union Publishing',
#   'title': 'The Extraordinary Life of Sam Hell',
#   'pages': '448',
#   'description': <b>From #1 <i>Wall Street Journal</i> and <i>New York Times</i> bestselling author Robert Dugoni.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.12',
#   'author': 'Rebecca Makkai',
#   'publisher': 'Viking',
#   'title': 'The Great Believers',
#   'pages': '421',
#   'description': 'A dazzling new novel of friendship and redemption in the face of tragedy and loss set in 1980s Chicago and contemporary Paris, by the acclaimed and award-winning author Rebecca Makkai.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.34',
#   'author': 'Madeline Miller',
#   'publisher': 'Little, Brown and Company',
#   'title': 'Circe',
#   'pages': '393',
#   'description': 'In the house of Helios, god of the sun and mightiest of the Titans, a daughter is born. But Circe is a strange child—not powerful, like her father, nor viciously alluring like her mother. Turning to the world of mortals for companionship, she discovers that she does possess power—the power of witchcraft, which can transform rivals into monsters and menace the gods themselv',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.96',
#   'author': 'Guillermo del Toro',
#   'publisher': 'Feiwel & Friends                          (first published February 2018',
#   'title': 'The Shape of Water',
#   'pages': '315',
#   'description': 'It is 1962, and Elisa Esposito—mute her whole life, orphaned as a child—is struggling with her humdrum existence as a janitor working the graveyard shift at Baltimore’s Occam Aerospace Research Center. Were it not for Zelda, a protective coworker, and Giles, her loving neighbor, she doesn’t know how she’d make it through the day.',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.31',
#   'author': 'Naomi Novik',
#   'publisher': 'Del Rey',
#   'title': 'Spinning Silver',
#   'pages': '466',
#   'description': "Miryem is the daughter and granddaughter of moneylenders, but her father's inability to collect his debts has left his family on the edge of poverty--until Miryem takes matters into her own hands. Hardening her heart, the young woman sets out to claim what is owed and soon gains a reputation for being able to turn silver into gold. ",
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.06',
#   'author': 'Nora Roberts',
#   'publisher': "St. Martin's Press",
#   'title': 'Year One',
#   'pages': '419',
#   'description': "It began on New Year's Eve.",
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2017',
#   'month': 'December'},
#  {'rating': '4.45',
#   'author': 'Ilona Andrews',
#   'publisher': 'Nancy Yost Literary Agency, Inc',
#   'title': 'Iron and Magic',
#   'pages': '380',
#   'description': <b>No day is ordinary in a world where Technology and Magic compete for supremacy…But no matter which force is winning, in the apocalypse, a sword will always work.</b>,
#   'format': 'Trade Paperback',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.06',
#   'author': 'R.F. Kuang',
#   'publisher': 'Harper Voyager',
#   'title': 'The Poppy War',
#   'pages': '530',
#   'description': 'When Rin aced the Keju—the Empire-wide test to find the most talented youth to learn at the Academies—it was a shock to everyone: to the test officials, who couldn’t believe a war orphan from Rooster Province could pass without cheating; to Rin’s guardians, who believed they’d finally be able to marry her off and further their criminal enterprise; and to Rin herself, who r',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.07',
#   'author': 'Seanan McGuire',
#   'publisher': 'tor.com',
#   'title': 'Beneath the Sugar Sky',
#   'pages': '174',
#   'description': <i>Beneath the Sugar Sky</i>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.33',
#   'author': 'Karen Marie Moning',
#   'publisher': 'Delacorte Press',
#   'title': 'High Voltage',
#   'pages': '479',
#   'description': 'There is no action without consequence…',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.28',
#   'author': 'Patricia Briggs',
#   'publisher': 'Ace',
#   'title': 'Burn Bright',
#   'pages': '308',
#   'description': 'In her bestselling Alpha and Omega series, Patricia Briggs “spins tales of werewolves, coyote shifters, and magic and, my, does she do it well” (USATODAY.com). Now mated werewolves Charles Cornick and Anna Latham face a threat like no other–one that lurks too close to home…',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.46',
#   'author': 'Mark  Lawrence',
#   'publisher': 'Ace Books',
#   'title': 'Grey Sister',
#   'pages': '432',
#   'description': <b>The second novel in a brilliant fantasy series from the international bestselling author of <i>Prince of Thorns</i>.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.74',
#   'author': 'Peng Shepherd',
#   'publisher': 'William Morrow',
#   'title': 'The Book of M',
#   'pages': '485',
#   'description': <b>Set in a dangerous near future world, <i>The Book of M</i> tells the captivating story of a group of ordinary people caught in an extraordinary catastrophe who risk everything to save the ones they love. It is a sweeping debut that illuminates the power that memories have not only on the heart, but on the world itself.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.42',
#   'author': 'Katherine Arden',
#   'publisher': 'Del Rey',
#   'title': 'The Girl in the Tower',
#   'pages': '363',
#   'description': <b>The magical adventure begun in <i>The Bear and the Nightingale</i> continues as brave Vasya, now a young woman, is forced to choose between marriage or life in a convent and instead flees her home—but soon finds herself called upon to help defend the city of Moscow when it comes under siege.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2017',
#   'month': 'December'},
#  {'rating': '4.45',
#   'author': 'Michael J. Sullivan',
#   'publisher': 'Del Rey Books',
#   'title': 'Age of War',
#   'pages': '420',
#   'description': <b>Rich in magic and adventure, Michael J. Sullivan’s soaring fantasy novels are masterworks of heroism, love, and sacrifice. Now, in Age of War, the epic battle between humankind and the cruel godlike beings who once ruled them finally ignites in all its fury.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.59',
#   'author': 'Aleron Kong',
#   'publisher': 'Tamori Publications LLC',
#   'title': 'The Land: Predators',
#   'pages': '1132',
#   'description': 'In ',
#   'format': 'Hardcover',
#   'genre': 'Fantasy'},
#  {'rating': '3.89',
#   'author': 'Deborah Harkness',
#   'publisher': 'Viking',
#   'title': "Time's Convert",
#   'pages': '436',
#   'description': <b>From the #1 <i>New York Times</i> bestselling author of <i>A Discovery of Witches</i>, a novel about what it takes to become a vampire. </b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.59',
#   'author': 'Ilona Andrews',
#   'publisher': 'Ace',
#   'title': 'Magic Triumphs',
#   'pages': '327',
#   'description': <b>Mercenary Kate Daniels must risk all to protect everything she holds dear in this epic, can't-miss entry in the thrilling #1 <i>New York Times</i> bestselling urban fantasy series.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.23',
#   'author': 'Josiah Bancroft',
#   'publisher': 'Orbit                          (first published February 18th 2013',
#   'title': 'Senlin Ascends',
#   'pages': '448',
#   'description': 'The Tower of Babel is the greatest marvel in the world. Immense as a mountain, the ancient Tower holds unnumbered ringdoms, warring and peaceful, stacked one on the other like the layers of a cake. It is a world of geniuses and tyrants, of airships and steam engines, of unusual animals and mysterious machines.',
#   'format': 'Paperback',
#   'genre': 'Fantasy',
#   'year': '2013',
#   'month': 'January'},
#  {'rating': '4.56',
#   'author': 'Brian  McClellan',
#   'publisher': 'Orbit',
#   'title': 'Wrath of Empire',
#   'pages': '639',
#   'description': "The country is in turmoil. With the capital city occupied, half a million refugees are on the march, looking for safety on the frontier, accompanied by Lady Flint's soldiers. But escaping war is never easy, and soon the battle may find them, whether they are prepared or not.",
#   'format': 'Paperback',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.32',
#   'author': 'Robert Jackson Bennett',
#   'publisher': 'Crown Publishing Group (NY',
#   'title': 'Foundryside',
#   'pages': '505',
#   'description': <i>In a city that runs on industrialized magic, a secret war will be fought to overwrite reality itself--the first in a dazzling new fantasy series from </i>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.32',
#   'author': 'Nicholas Eames',
#   'publisher': 'Orbit',
#   'title': 'Bloody Rose',
#   'pages': '515',
#   'description': 'Live fast, die young.',
#   'format': 'Paperback',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.55',
#   'author': 'Angie Thomas',
#   'publisher': 'Balzer + Bray',
#   'title': 'The Hate U Give',
#   'pages': '444',
#   'description': <b>A three-time winner of Goodreads Choice Awards</b>,
#   'format': 'Hardcover',
#   'genre': 'Young Adult',
#   'year': '2017',
#   'month': 'February'},
#  {'rating': '4.33',
#   'author': 'Anthony Doerr',
#   'publisher': 'Scribner',
#   'title': 'All the Light We Cannot See',
#   'pages': '531',
#   'description': <i>An alternate cover for this ISBN can be found <a href="https://www.goodreads.com/book/show/25210408-all-the-light-we-cannot-see" rel="nofollow">here</a></i>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2014',
#   'month': 'May'},
#  {'rating': '4.69',
#   'author': 'Sarah J. Maas',
#   'publisher': 'Bloomsbury USA Childrens',
#   'title': 'A Court of Mist and Fury',
#   'pages': '624',
#   'description': "Feyre survived Amarantha's clutches to return to the Spring Court—but at a steep cost. Though she now has the powers of the High Fae, her heart remains human, and it can't forget the terrible deeds she performed to save Tamlin's people.",
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2016',
#   'month': 'May'},
#  {'rating': '4.46',
#   'author': 'Kathryn Stockett',
#   'publisher': 'Amy Einhorn Books',
#   'title': 'The Help',
#   'pages': '465',
#   'description': 'Be prepared to meet three unforgettable women:',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2009',
#   'month': 'February'},
#  {'rating': '4.56',
#   'author': 'Kristin Hannah',
#   'publisher': "St. Martin's Press",
#   'title': 'The Nightingale',
#   'pages': '440',
#   'description': <i>In love we find out who we want to be. In war we find out who we are.</i>,
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2015',
#   'month': 'February'},
#  {'rating': '4.40',
#   'author': 'Andy Weir',
#   'publisher': 'Crown                          (first published September 27th 2012',
#   'title': 'The Martian',
#   'pages': '369',
#   'description': 'Six days ago, astronaut Mark Watney became one of the first people to walk on Mars. ',
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2012',
#   'month': 'February'},
#  {'rating': '4.05',
#   'author': 'Gillian Flynn',
#   'publisher': 'Crown Publishers                          (first published May 24th 2012',
#   'title': 'Gone Girl',
#   'pages': '419',
#   'description': "On a warm summer morning in North Carthage, Missouri, it is Nick and Amy Dunne's fifth wedding anniversary. Presents are being wrapped and reservations are being made when Nick's clever and beautiful wife disappears from their rented McMansion on the Mississippi River. Husband-of-the-Year Nick isn't doing himself any favors with cringe-worthy daydreams about the slope and",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2012',
#   'month': 'June'},
#  {'rating': '3.99',
#   'author': 'Neil Gaiman',
#   'publisher': 'William Morrow Books',
#   'title': 'The Ocean at the End of the Lane',
#   'pages': '181',
#   'description': "Sussex, England. A middle-aged man returns to his childhood home to attend a funeral. Although the house he lived in is long gone, he is drawn to the farm at the end of the road, where, when he was seven, he encountered a most remarkable girl, Lettie Hempstock, and her mother and grandmother. He hasn't thought of Lettie in decades, and yet as he sits by the pond (a pond th",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2013',
#   'month': 'June'},
#  {'rating': '4.29',
#   'author': 'Suzanne Collins',
#   'publisher': 'Scholastic Press',
#   'title': 'Catching Fire',
#   'pages': '391',
#   'description': <b>Sparks are igniting.<br/>Flames are spreading.<br/>And the Capitol wants revenge.</b>,
#   'format': 'Hardcover',
#   'genre': 'Young Adult',
#   'year': '2009',
#   'month': 'September'},
#  {'rating': '4.24',
#   'author': 'John Green',
#   'publisher': 'Dutton Books',
#   'title': 'The Fault in Our Stars',
#   'pages': '313',
#   'description': "Despite the tumor-shrinking medical miracle that has bought her a few years, Hazel has never been anything but terminal, her final chapter inscribed upon diagnosis. But when a gorgeous plot twist named Augustus Waters suddenly appears at Cancer Kid Support Group, Hazel's story is about to be completely rewritten.",
#   'format': 'Hardcover',
#   'genre': 'Young Adult',
#   'year': '2012',
#   'month': 'January'},
#  {'rating': '4.30',
#   'author': 'Stephen King',
#   'publisher': 'Scribner',
#   'title': '11/22/63',
#   'pages': '849',
#   'description': 'Life can turn on a dime—or stumble into the extraordinary, as it does for Jake Epping, a high school English teacher in Lisbon Falls, Maine. While grading essays by his GED students, Jake reads a gruesome, enthralling piece penned by janitor Harry Dunning: fifty years ago, Harry somehow survived his father’s sledgehammer slaughter of his entire family. Jake is blown away..',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2011',
#   'month': 'November'},
#  {'rating': '4.58',
#   'author': 'Sarah J. Maas',
#   'publisher': 'Bloomsbury USA Childrens',
#   'title': 'Queen of Shadows',
#   'pages': '648',
#   'description': <i>The queen has returned.</i>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2015',
#   'month': 'September'},
#  {'rating': '4.32',
#   'author': 'George R.R. Martin',
#   'publisher': 'Bantam',
#   'title': 'A Dance with Dragons',
#   'pages': '1016',
#   'description': 'In the aftermath of a colossal battle, the future of the Seven Kingdoms hangs in the balance—beset by newly emerging threats from every direction. In the east, Daenerys Targaryen, the last scion of House Targaryen, rules with her three dragons as queen of a city built on dust and death. But Daenerys has thousands of enemies, and many have set out to find her. As they gathe',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2011',
#   'month': 'July'},
#  {'rating': '4.13',
#   'author': 'Celeste Ng',
#   'publisher': 'Penguin Press',
#   'title': 'Little Fires Everywhere',
#   'pages': '338',
#   'description': <p> <i>Everyone in Shaker Heights was talking about it that summer: how Isabelle, the last of the Richardson children, had finally gone around the bend and burned the house down. </i> </p>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'September'},
#  {'rating': '4.09',
#   'author': 'Rainbow Rowell',
#   'publisher': "St. Martin's Press",
#   'title': 'Eleanor & Park',
#   'pages': '328',
#   'description': <i>Two misfits.<br>One extraordinary love.<br/><br/>Eleanor</br></i>,
#   'format': 'Hardcover',
#   'genre': 'Young Adult',
#   'year': '2013',
#   'month': 'February'},
#  {'rating': '4.41',
#   'author': 'Colleen Hoover',
#   'publisher': 'Atria Books',
#   'title': 'It Ends with Us',
#   'pages': '376',
#   'description': 'Sometimes it is the one who loves you who hurts you the most.',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2016',
#   'month': 'August'},
#  {'rating': '4.27',
#   'author': 'Pierce Brown',
#   'publisher': 'Del Rey (Random House',
#   'title': 'Red Rising',
#   'pages': '382',
#   'description': <i>"I live for the dream that my children will be born free," she says. "That they will be what they like. That they will own the land their father gave them."<br/><br/>"I live for you," I say sadly.<br/><br/>Eo kisses my cheek. "Then you must live for more."</i>,
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2014',
#   'month': 'January'},
#  {'rating': '4.50',
#   'author': 'Sarah J. Maas',
#   'publisher': 'Bloomsbury Childrens Books',
#   'title': 'A Court of Wings and Ruin',
#   'pages': '699',
#   'description': 'Looming war threatens all Feyre holds dear in the third volume of the #1 ',
#   'format': 'Paperback',
#   'genre': 'Fantasy',
#   'year': '2017',
#   'month': 'May'},
#  {'rating': '4.36',
#   'author': 'Lisa Wingate',
#   'publisher': 'Ballantine Books',
#   'title': 'Before We Were Yours',
#   'pages': '342',
#   'description': 'THE BLOCKBUSTER HIT—A New York Times, USA Today, Wall Street Journal, and Publishers Weekly Bestseller',
#   'format': 'Hardcover',
#   'genre': 'Historical',
#   'year': '2017',
#   'month': 'June'},
#  {'rating': '4.18',
#   'author': 'Jennifer Niven',
#   'publisher': 'Knopf',
#   'title': 'All the Bright Places',
#   'pages': '378',
#   'description': <b><i>The Fault in Our Stars</i> meets <i>Eleanor and Park</i> in this exhilarating and heart-wrenching love story about a girl who learns to live from a boy who intends to die.<br/></b>,
#   'format': 'Hardcover',
#   'genre': 'Young Adult',
#   'year': '2015',
#   'month': 'January'},
#  {'rating': '3.99',
#   'author': 'Helen Hoang',
#   'publisher': 'Berkley                          (first published May 30th 2018',
#   'title': 'The Kiss Quotient (The Kiss Quotient, #1)',
#   'pages': '317',
#   'description': <b>A heartwarming and refreshing debut novel that proves one thing: there's not enough data in the world to predict what will make your heart tick.</b>,
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.31',
#   'author': 'Colleen Hoover',
#   'publisher': 'Atria Books',
#   'title': 'All Your Perfects',
#   'pages': '308',
#   'description': "Quinn and Graham's perfect love is threatened by their imperfect marriage. The memories, mistakes, and secrets that they have built up over the years are now tearing them apart. The one thing that could save them might also be the very thing that pushes their marriage beyond the point of repair.",
#   'format': 'Hardcover',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.51',
#   'author': 'Jasmine Guillory',
#   'publisher': 'Berkley Books',
#   'title': 'The Wedding Date',
#   'pages': '310',
#   'description': <b>A groomsman and his last-minute guest are about to discover if a fake date can go the distance in a fun and flirty debut novel.</b>,
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.28',
#   'author': 'J.R. Ward',
#   'publisher': 'Ballantine Books',
#   'title': 'The Thief',
#   'pages': '454',
#   'description': <b>New enemies rise and desire burns in the next thrilling novel of the #1 <i>New York Times </i>bestselling paranormal romance series the Black Dagger Brotherhood.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.11',
#   'author': 'E.L. James',
#   'publisher': 'Vintage Books',
#   'title': 'Darker',
#   'pages': '546',
#   'description': 'E L James revisits the world of Fifty Shades with a deeper and darker take on the love story that has enthralled millions of readers around the globe.',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2017',
#   'month': 'November'},
#  {'rating': '4.05',
#   'author': 'Laura Thalassa',
#   'publisher': 'CreateSpace                          (first published March 20th 2018',
#   'title': 'Pestilence',
#   'pages': '381',
#   'description': <i>They came to earth—Pestilence, War, Famine, Death—four horsemen riding their screaming steeds, racing to the corners of the world. Four horsemen with the power to destroy all of humanity. They came to earth, and they came to end us all. </i>,
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.34',
#   'author': 'Mariana Zapata',
#   'publisher': 'Mariana Zapata',
#   'title': 'From Lukov with Love',
#   'pages': '522',
#   'description': "If someone were to ask Jasmine Santos to describe the last few years of her life with a single word, it would definitely be a four-letter one. After seventeen years-and countless broken bones and broken promises-she knows her window to compete in figure skating is coming to a close. But when the offer of a lifetime comes in from an arrogant idiot she's spent the last decad",
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '3.91',
#   'author': 'Christina Lauren',
#   'publisher': 'Gallery Books',
#   'title': 'Roomies',
#   'pages': '368',
#   'description': <b>From subway to Broadway to happily ever after. Modern love in all its thrill, hilarity, and uncertainty has never been so compulsively readable as in New York Times bestselling author Christina Lauren’s romantic novel.</b>,
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2017',
#   'month': 'December'},
#  {'rating': '4.18',
#   'author': 'Kristen Ashley',
#   'publisher': 'CreateSpace Independent Publishing Platform',
#   'title': 'The Hookup',
#   'pages': '358',
#   'description': 'When the new girl in town, Eliza “Izzy” Forrester decides to hit the local drinking hole, she’s not ready to meet the town’s good, solid guy. She’s definitely not prepared to engage in her very first hookup with him.',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2017',
#   'month': 'December'},
#  {'rating': '4.07',
#   'author': 'Lisa Kleypas',
#   'publisher': 'Avon',
#   'title': 'Hello Stranger',
#   'pages': '286',
#   'description': <i>A woman who defies her time</i>,
#   'format': 'Hardcover',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.16',
#   'author': 'Penelope Douglas',
#   'publisher': 'CreateSpace Independent Publishing Platform                          (first published April 15th 2018',
#   'title': 'Birthday Girl',
#   'pages': '406',
#   'description': 'From ',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.25',
#   'author': 'Vi Keeland',
#   'publisher': 'C. Scott Publishing Corp',
#   'title': 'Sex, Not Love',
#   'pages': '300',
#   'description': 'From ',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '3.87',
#   'author': 'Alyssa Cole',
#   'publisher': 'Avon',
#   'title': 'A Princess in Theory',
#   'pages': '360',
#   'description': <strong> <em>From acclaimed author Alyssa Cole comes the tale of a city Cinderella </em> </strong>,
#   'format': 'Mass Market Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.43',
#   'author': 'Ella Frank',
#   'publisher': 'CreateSpace Independent Publishing Platform',
#   'title': 'Robbie',
#   'pages': '296',
#   'description': "Relationships are complex. Love ever-changing. And when it comes to rules of the heart, they were made to be broken… That's what Robert Antonio Bianchi was telling himself, anyway. Otherwise, he really had no excuse for what-or who-he'd done. No excuse, except for his lonely heart, a pitcher of margaritas, four Bitter Bitches, and the apparent need to confess all his weakn",
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.04',
#   'author': 'Sarah MacLean',
#   'publisher': 'Avon',
#   'title': 'Wicked and the Wallflower',
#   'pages': '368',
#   'description': <b>When Wicked Comes Calling...</b>,
#   'format': 'Hardcover',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.17',
#   'author': 'Christina Lauren',
#   'publisher': 'Gallery Books',
#   'title': "Josh and Hazel's Guide to Not Dating",
#   'pages': '309',
#   'description': 'Hazel Camille Bradford knows she’s a lot to take—and frankly, most men aren’t up to the challenge. If her army of pets and thrill for the absurd don’t send them running, her lack of filter means she’ll say exactly the wrong thing in a delicate moment. Their loss. She’s a good soul in search of honest fun.',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.17',
#   'author': 'Penny Reid',
#   'publisher': 'EverAfter Romance',
#   'title': 'Dr. Strange Beard',
#   'pages': '422',
#   'description': 'Everyone in Green Valley, Tennessee knows that the six bearded Winston brothers have been imbued with an unfair share of charm and charisma and are prone to mischief.',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '4.51',
#   'author': 'K.A. Tucker',
#   'publisher': 'Atria Books',
#   'title': 'The Simple Wild',
#   'pages': '388',
#   'description': "Calla Fletcher wasn't even two when her mother took her and fled the Alaskan wild, unable to handle the isolation of the extreme, rural lifestyle, leaving behind Calla’s father, Wren Fletcher, in the process. Calla never looked back, and at twenty-six, a busy life in Toronto is all she knows. But when Calla learns that Wren’s days may be numbered, she knows that it’s time",
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.18',
#   'author': 'Penny Reid',
#   'publisher': 'EverAfter Romance',
#   'title': 'Marriage of Inconvenience',
#   'pages': '510',
#   'description': 'There are three things you need to know about Kat Tanner (aka Kathleen Tyson... and yes, she is *that* Kathleen Tyson): 1) She’s determined to make good decisions, 2) She must get married ASAP, and 3) She knows how to knit.',
#   'format': 'Paperback',
#   'genre': 'Romance',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.36',
#   'author': 'Krista Ritchie',
#   'publisher': 'Everafter Romance                          (first published March 13th 2018',
#   'title': 'Alphas Like Us',
#   'pages': '429',
#   'description': <b>His Bodyguard. His Love.</b>,
#   'format': 'Paperback',
#   'genre': 'New Adult',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.37',
#   'author': 'V.E. Schwab',
#   'publisher': 'Tor Books',
#   'title': 'Vengeful',
#   'pages': '478',
#   'description': 'Eli Ever and Victor Vale were only medical students when their mutual discovery that near-death experiences can, under the right conditions, manifest extraordinary abilities.',
#   'format': 'Hardcover',
#   'genre': 'Fantasy',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.25',
#   'author': 'Pierce Brown',
#   'publisher': 'Del Rey Books',
#   'title': 'Iron Gold',
#   'pages': '601',
#   'description': <i>They call him father, liberator, warlord, Reaper. But he feels a boy as he falls toward the pale blue planet, his armor red, his army vast, his heart heavy. It is the tenth year of war and the thirty-second of his life.</i>,
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '3.66',
#   'author': 'Christina Dalcher',
#   'publisher': 'Berkley',
#   'title': 'Vox',
#   'pages': '336',
#   'description': 'Set in an America where half the population has been silenced, ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '3.67',
#   'author': 'Sylvain Neuvel',
#   'publisher': 'Del Rey Books',
#   'title': 'Only Human',
#   'pages': '336',
#   'description': 'In her childhood, Rose Franklin accidentally discovered a giant metal hand buried beneath the ground outside Deadwood, South Dakota. As an adult, Dr. Rose Franklin led the team that uncovered the rest of the body parts which together form Themis: a powerful robot of mysterious alien origin. She, along with linguist Vincent, pilot Kara, and the unnamed Interviewer, protecte',
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.71',
#   'author': 'Leni Zumas',
#   'publisher': 'Little, Brown and Company',
#   'title': 'Red Clocks',
#   'pages': '356',
#   'description': <strong>Five women. One question. What is a woman for?</strong>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.14',
#   'author': 'Nnedi Okorafor',
#   'publisher': 'Tor.com',
#   'title': 'The Night Masquerade',
#   'pages': '208',
#   'description': "The concluding part of the highly-acclaimed science fiction trilogy that began with Nnedi Okorafor's Hugo- and Nebula Award-winning BINTI.",
#   'format': 'Paperback',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.35',
#   'author': 'James S.A. Corey',
#   'publisher': 'Orbit',
#   'title': 'Persepolis Rising',
#   'pages': '560',
#   'description': "The seventh novel in James S. A. Corey's New York Times bestselling Expanse series--now a major television series.",
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2017',
#   'month': 'December'},
#  {'rating': '4.30',
#   'author': 'Martha Wells',
#   'publisher': 'Tor.com / Tom Doherty Associates',
#   'title': 'Artificial Condition',
#   'pages': '158',
#   'description': 'It has a dark past – one in which a number of humans were killed. A past that caused it to christen itself “Murderbot”. But it has only vague memories of the massacre that spawned that title, and it wants to know more.',
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.71',
#   'author': 'Charles Soule',
#   'publisher': 'Harper Perennial',
#   'title': 'The Oracle Year',
#   'pages': '402',
#   'description': 'From bestselling comic-book franchise writer Charles Soule comes a clever and witty first novel of a twentysomething New Yorker who wakes up one morning with the power to predict the future—perfect for fans of Joe Hill and Brad Meltzer, or books like ',
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.02',
#   'author': 'John Scalzi',
#   'publisher': 'Tor Books',
#   'title': 'Head On',
#   'pages': '335',
#   'description': 'John Scalzi returns with ',
#   'format': 'Hardcover',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.20',
#   'author': 'Becky Chambers',
#   'publisher': 'Harper Voyager',
#   'title': 'Record of a Spaceborn Few',
#   'pages': '368',
#   'description': 'Return to the sprawling universe of the Galactic Commons, as humans, artificial intelligence, aliens, and some beings yet undiscovered explore what it means to be a community in this exciting third adventure in the acclaimed and multi-award-nominated science fiction Wayfarers series, brimming with heartwarming characters and dazzling space adventure.',
#   'format': 'Paperback',
#   'genre': 'Science Fiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.95',
#   'author': 'Timothy Zahn',
#   'publisher': 'Del Rey',
#   'title': 'Alliances',
#   'pages': '368',
#   'description': <b>Grand Admiral Thrawn and Darth Vader team up against a threat to the Empire in this thrilling novel from bestselling author Timothy Zahn.</b>,
#   'format': 'Hardcover',
#   'genre': 'Media Tie In',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.91',
#   'author': 'Ling  Ma',
#   'publisher': 'Farrar, Straus and Giroux',
#   'title': 'Severance',
#   'pages': '304',
#   'description': 'An offbeat office novel turns apocalyptic satire as a young woman transforms from orphan to worker bee to survivor',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
# ...
#   'title': 'Ocean Meets Sky',
#   'pages': '48',
#   'description': 'Finn lives by the sea and the sea lives by him. Every time he looks out his window it’s a constant reminder of the stories his grandfather told him about the place where the ocean meets the sky. Where whales and jellyfish soar and birds and castles float.',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.26',
#   'author': 'Matt de la Pena',
#   'publisher': "G.P. Putnam's Sons Books for Young Readers",
#   'title': 'Love',
#   'pages': '40',
#   'description': <b> <b>From Newbery Medal-winning author Matt de la Peña and bestselling illustrator Loren Long comes a story about the strongest bond there is and the diverse and powerful ways it connects us all.</b> </b>,
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.43',
#   'author': 'Jessica    Love',
#   'publisher': 'Candlewick',
#   'title': 'Julián Is a Mermaid',
#   'pages': '40',
#   'description': <b>In an exuberant picture book, a glimpse of costumed mermaids leaves one boy flooded with wonder and ready to dazzle the world.</b>,
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '4.25',
#   'author': 'Peter H. Reynolds',
#   'publisher': 'Orchard Books',
#   'title': 'The Word Collector',
#   'pages': '40',
#   'description': <i>Some people collect stamps.<br/>Some people collect coins.<br/>Some people collect art.<br/>And Jerome?<br/>Jerome collected words . . . </i>,
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '3.89',
#   'author': 'Brian Selznick',
#   'publisher': 'Scholastic Press',
#   'title': 'Baby Monkey, Private Eye',
#   'pages': '192',
#   'description': 'Who is Baby Monkey?',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.28',
#   'author': 'Minh Lê',
#   'publisher': 'Disney-Hyperion',
#   'title': 'Drawn Together',
#   'pages': '40',
#   'description': 'When a young boy visits his grandfather, their lack of a common language leads to confusion, frustration, and silence. But as they sit down to draw together, something magical happens-with a shared love of art and storytelling, the two form a bond that goes beyond words.',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.48',
#   'author': 'Junot Díaz',
#   'publisher': 'Dial Books                          (first published 2018',
#   'title': 'Islandborn',
#   'pages': '48',
#   'description': <b>From <em>New York Times</em> bestseller and Pulitzer Prize winner Junot Díaz comes a debut picture book about the magic of memory and the infinite power of the imagination.</b>,
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.48',
#   'author': 'Junot Díaz',
#   'publisher': 'Dial Books                          (first published 2018',
#   'title': 'Islandborn',
#   'pages': '48',
#   'description': <b>From <em>New York Times</em> bestseller and Pulitzer Prize winner Junot Díaz comes a debut picture book about the magic of memory and the infinite power of the imagination.</b>,
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.55',
#   'author': 'Jacqueline Woodson',
#   'publisher': 'Nancy Paulsen Books',
#   'title': 'The Day You Begin',
#   'pages': '32',
#   'description': 'National Book Award winner Jacqueline Woodson and two-time Pura Belpre Illustrator Award winner Rafael Lopez have teamed up to create a poignant, yet heartening book about finding courage to connect, even when you feel scared and alone.',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'August'},
#  {'rating': '4.40',
#   'author': 'Daniel Haack',
#   'publisher': 'Little Bee Books',
#   'title': 'Prince & Knight',
#   'pages': '40',
#   'description': 'In this modern fairy tale, a noble prince and a brave knight come together to defeat a terrible monster and in the process find true love in a most unexpected place.',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.87',
#   'author': 'Jillian Tamaki',
#   'publisher': 'Groundwood Books',
#   'title': 'They Say Blue',
#   'pages': '40',
#   'description': 'Caldecott and Printz Honor-winning illustrator Jillian Tamaki brings us a poetic exploration of colour and nature from a young child’s point of view. ',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '4.30',
#   'author': 'Matt Haig',
#   'publisher': 'Canongate Books',
#   'title': 'The Truth Pixie',
#   'pages': '119',
#   'description': 'From number one bestselling author Matt Haig comes a hilarious and heartwarming story, brilliantly illustrated throughout by Chris Mould Wherever she is, whatever the day, She only has one kind of thing to say. Just as cats go miaow and cows go moo, The Truth Pixie can only say things that are true.',
#   'format': 'Hardcover',
#   'genre': 'Poetry',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '4.29',
#   'author': 'Jen Campbell',
#   'publisher': 'Thames & Hudson',
#   'title': 'Franklin and Luna Go to the Moon',
#   'pages': '32',
#   'description': 'Luna’s best friend, Franklin, is a dragon. They love to read stories about everything from trampolining to deep-sea diving. One day, they are reading about where werewolves live and Franklin begins to wonder where he is from. He is 605 years old and has no idea where to find other dragons!',
#   'format': 'Hardcover',
#   'genre': 'Childrens',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '4.19',
#   'author': 'Jojo Moyes',
#   'publisher': 'Pamela Dorman Books',
#   'title': 'Still Me',
#   'pages': '390',
#   'description': <b>From the #1 New York Times bestselling author Jojo Moyes, a new book featuring her iconic heroine of <i>Me Before You</i> and <i>After You</i>, Louisa Clark.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.01',
#   'author': 'Tayari Jones',
#   'publisher': 'Algonquin Books                          (first published January 29th 2018',
#   'title': 'An American Marriage',
#   'pages': '308',
#   'description': 'Newlyweds Celestial and Roy are the embodiment of both the American Dream and the New South. He is a young executive, and she is an artist on the brink of an exciting career. But as they settle into the routine of their life together, they are ripped apart by circumstances neither could have imagined. In this deft exploration of love, loyalty, race, justice, and both Black',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'February'},
#  {'rating': '4.38',
#   'author': 'Fredrik Backman',
#   'publisher': 'Atria Books                          (first published August 21st 2017',
#   'title': 'Us Against You',
#   'pages': '448',
#   'description': 'After everything that the citizens of Beartown have gone through, they are struck yet another blow when they hear that their beloved local hockey team will soon be disbanded. What makes it worse is the obvious satisfaction that all the former Beartown players, who now play for a rival team in Hed, take in that fact. Amidst the mounting tension between the two rivals, a sur',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'June'},
#  {'rating': '3.58',
#   'author': 'Liane Moriarty',
#   'publisher': 'Flatiron Books                          (first published October 2018',
#   'title': 'Nine Perfect Strangers',
#   'pages': '453',
#   'description': 'Could ten days at a health resort really change you forever? In Liane Moriarty’s latest page-turner, nine perfect strangers are about to find out...',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'November'},
#  {'rating': '4.13',
#   'author': 'Hank Green',
#   'publisher': 'Dutton',
#   'title': 'An Absolutely Remarkable Thing',
#   'pages': '343',
#   'description': <b>In his much-anticipated debut novel, Hank Green--cocreator of Crash Course, Vlogbrothers, and SciShow--spins a sweeping, cinematic tale about a young woman who becomes an overnight celebrity before realizing she's part of something bigger, and stranger, than anyone could have possibly imagined.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'September'},
#  {'rating': '3.93',
#   'author': 'Haruki Murakami',
#   'publisher': 'Knopf Publishing Group                          (first published February 24th 2017',
#   'title': 'Killing Commendatore',
#   'pages': '688',
#   'description': 'The epic new novel from the internationally acclaimed and best-selling author of 1Q84',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2017',
#   'month': 'October'},
#  {'rating': '4.07',
#   'author': 'Tommy Orange',
#   'publisher': 'Knopf',
#   'title': 'There There',
#   'pages': '294',
#   'description': 'Fierce, angry, funny, heartbreaking—Tommy Orange’s first novel is a wondrous and shattering portrait of an America few of us have ever seen, and it introduces a brilliant new author at the start of a major career. ',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.81',
#   'author': 'Shobha Rao',
#   'publisher': 'Flatiron Books',
#   'title': 'Girls Burn Brighter',
#   'pages': '304',
#   'description': 'A searing, electrifying debut novel set in India and America, about a once-in-a-lifetime friendship between two girls who are driven apart but never stop trying to find one another again.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '3.91',
#   'author': 'Emily Giffin',
#   'publisher': 'Ballantine Books',
#   'title': 'All We Ever Wanted',
#   'pages': '400',
#   'description': <b>In the riveting new novel from the #1 New York Times bestselling author of First Comes Love and Something Borrowed, three very different people must choose between their family and their values.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '4.13',
#   'author': 'Lisa Genova',
#   'publisher': 'Scout Press',
#   'title': 'Every Note Played',
#   'pages': '307',
#   'description': <b>From neuroscientist and <i>New York Times</i> bestselling author of <i>Still Alice</i> comes a powerful exploration of regret, forgiveness, freedom, and what it means to be alive.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'March'},
#  {'rating': '3.64',
#   'author': 'Meg Wolitzer',
#   'publisher': 'Riverhead Books',
#   'title': 'The Female Persuasion',
#   'pages': '454',
#   'description': "Greer Kadetsky is a shy college freshman when she meets the woman she hopes will change her life. Faith Frank, dazzlingly persuasive and elegant at sixty-three, has been a central pillar of the women's movement for decades, a figure who inspires others to influence the world. Upon hearing Faith speak for the first time, Greer--madly in love with her boyfriend, Cory, but st",
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.17',
#   'author': 'Fatima Farheen Mirza',
#   'publisher': 'SJP for Hogarth',
#   'title': 'A Place for Us',
#   'pages': '385',
#   'description': <i>A Place for Us</i>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.69',
#   'author': 'Jodi Picoult',
#   'publisher': 'Ballantine Books',
#   'title': 'A Spark of Light',
#   'pages': '352',
#   'description': 'The warm fall day starts like any other at the Center—a women’s reproductive health services clinic—its staff offering care to anyone who passes through its doors. Then, in late morning, a desperate and distraught gunman bursts in and opens fire, taking all inside hostage.',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'October'},
#  {'rating': '3.76',
#   'author': 'Ottessa Moshfegh',
#   'publisher': 'Jonathan Cape                          (first published July 10th 2018',
#   'title': 'My Year of Rest and Relaxation',
#   'pages': '304',
#   'description': 'A shocking, hilarious and strangely tender novel about a young woman’s experiment in narcotic hibernation, aided and abetted by one of the worst psychiatrists in the annals of literature. Our narrator has many of the advantages of life, on the surface. Young, thin, pretty, a recent Columbia graduate, she lives in an apartment on the Upper East Side of Manhattan paid for, l',
#   'format': 'Paperback',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'July'},
#  {'rating': '3.95',
#   'author': 'Mira T. Lee',
#   'publisher': 'Pamela Dorman Books',
#   'title': 'Everything Here Is Beautiful',
#   'pages': '368',
#   'description': 'Two Chinese-American sisters—Miranda, the older, responsible one, always her younger sister’s protector; Lucia, the headstrong, unpredictable one, whose impulses are huge and, often, life changing. When Lucia starts hearing voices, it is Miranda who must find a way to reach her sister. Lucia impetuously plows ahead, but the bitter constant is that she is, in fact, mentally',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'January'},
#  {'rating': '4.25',
#   'author': 'Richard Powers',
#   'publisher': 'W. W. Norton & Company',
#   'title': 'The Overstory',
#   'pages': '502',
#   'description': 'An Air Force loadmaster in the Vietnam War is shot out of the sky, then saved by falling into a banyan. An artist inherits a hundred years of photographic portraits, all of the same doomed American chestnut. A hard-partying undergraduate in the late 1980s electrocutes herself, dies, and is sent back into life by creatures of air and light. A hearing- and speech-impaired sc',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '3.78',
#   'author': 'Curtis Sittenfeld',
#   'publisher': 'Random House',
#   'title': "You Think It, I'll Say It",
#   'pages': '226',
#   'description': 'A suburban mother of two fantasizes about the downfall of an old friend whose wholesome lifestyle empire may or may not be built on a lie. A high-powered lawyer honeymooning with her husband is caught off guard by the appearance of the girl who tormented her in high school. A shy Ivy League student learns the truth about a classmate’s seemingly enviable life.',
#   'format': 'Hardcover',
#   'genre': 'Short Stories',
#   'year': '2018',
#   'month': 'April'},
#  {'rating': '4.09',
#   'author': 'Katherine Center',
#   'publisher': "St. Martin's Press",
#   'title': 'How to Walk Away',
#   'pages': '320',
#   'description': <b>From the author of <i>Happiness for Beginners</i> comes an unforgettable love story about finding joy even in the darkest of circumstances.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'May'},
#  {'rating': '3.98',
#   'author': 'Meghan MacLean Weir',
#   'publisher': 'Knopf Publishing Group',
#   'title': 'The Book of Essie',
#   'pages': '319',
#   'description': <b>A debut novel of family, fame, and religion that tells the emotionally stirring, wildly captivating story of the seventeen-year-old daughter of an evangelical preacher, star of the family's hit reality show, and the secret pregnancy that threatens to blow their entire world apart.</b>,
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'June'},
#  {'rating': '3.53',
#   'author': 'Rachel Kushner',
#   'publisher': 'Scribner',
#   'title': 'The Mars Room',
#   'pages': '338',
#   'description': 'It’s 2003 and Romy Hall is at the start of two consecutive life sentences at Stanville Women’s Correctional Facility, deep in California’s Central Valley. Outside is the world from which she has been severed: the San Francisco of her youth and her young son, Jackson. Inside is a new reality: thousands of women hustling for the bare essentials needed to survive; the bluffin',
#   'format': 'Hardcover',
#   'genre': 'Fiction',
#   'year': '2018',
#   'month': 'May'}]

# %%
goodreads_2018_df = pd.DataFrame.from_dict(all_books)

# %%
goodreads_2018_df.to_csv('csv_files/goodreads_2018_df', encoding='utf-8', index=False)

# %%
goodreads_2018_df
# Out:
#                         author  \
# 0                 Stephen King
# 1                    A.J. Finn
# 2             Robert Galbraith
# 3              Greer Hendricks
# 4                  Lisa Jewell
# 5                 Bill Clinton
# 6                    Ruth Ware
# 7                  Tana French
# 8                  Jane Harper
# 9                 Alice Feeney
# 10               Stuart Turton
# 11          Catherine Steadman
# 12                  C.J. Tudor
# 13               Sujata Massey
# 14                   J.D. Robb
# 15                  B.A. Paris
# 16            Simone St. James
# 17                 Riley Sager
# 18        Victoria Helen Stone
# 19                     Joe Ide
# 20              Kristin Hannah
# 21            Heather   Morris
# 22             Chloe  Benjamin
# 23                 Kate Morton
# 24                 Delia Owens
# 25              Chanel Cleeton
# 26   Jennifer Zeynab Joukhadar
# 27               Kate Atkinson
# 28            Michael Ondaatje
# 29            Beatriz Williams
# ..                         ...
# 390          Peter H. Reynolds
# 391             Brian Selznick
# 392                    Minh Lê
# 393                 Junot Díaz
# 394                 Junot Díaz
# 395         Jacqueline Woodson
# 396               Daniel Haack
# 397             Jillian Tamaki
# 398                  Matt Haig
# 399               Jen Campbell
# 400                 Jojo Moyes
# 401               Tayari Jones
# 402            Fredrik Backman
# 403             Liane Moriarty
# 404                 Hank Green
# 405            Haruki Murakami
# 406               Tommy Orange
# 407                 Shobha Rao
# 408               Emily Giffin
# 409                Lisa Genova
# 410               Meg Wolitzer
# 411       Fatima Farheen Mirza
# 412               Jodi Picoult
# 413           Ottessa Moshfegh
# 414                Mira T. Lee
# 415             Richard Powers
# 416          Curtis Sittenfeld
# 417           Katherine Center
# 418        Meghan MacLean Weir
# 419             Rachel Kushner
#
#                                            description     format  \
# 0    An unspeakable crime. A confounding investigat...  Hardcover
# 1    Anna Fox lives alone—a recluse in her New York...  Hardcover
# 2    <i>“I seen a kid killed…He strangled it, up by...  Hardcover
# 3    When you read this book, you will make many as...  Hardcover
# 4                                                 THEN  Hardcover
# 5                      <i>The President Is Missing</i>  Hardcover
# 6    On a day that begins like any other, Hal recei...  Hardcover
# 7    Toby is a happy-go-lucky charmer who’s dodged ...  Hardcover
# 8    Five women reluctantly pick up their backpacks...  Hardcover
# 9    <b> <i>My name is Amber Reynolds. There are th...  Hardcover
# 10                      <b>The Rules of Blackheath</b>  Hardcover
# 11   <b>A shocking discovery on a honeymoon in para...  Hardcover
# 12   In 1986, Eddie and his friends are just kids o...  Hardcover
# 13   Bombay, 1921: Perveen Mistry, the daughter of ...  Hardcover
# 14   Lieutenant Eve Dallas puzzles over a bizarre s...  Hardcover
# 15   Finn and Layla are young, in love, and on vaca...  Hardcover
# 16   <b>A breakout suspense novel from the award-wi...  Hardcover
# 17   <b>In the new novel from the bestselling autho...  Hardcover
# 18   <b>A double life with a single purpose: reveng...  Hardcover
# 19   Isaiah Quintabe--IQ for short--has never been ...  Hardcover
# 20                                       Alaska, 1974.  Hardcover
# 21   Based on interviews that were conducted with H...  Paperback
# 22   If you knew the date of your death, how would ...  Hardcover
# 23   <i>My real name, no one remembers. The truth a...  Hardcover
# 24   <b>A novel about a young woman determined to m...  Hardcover
# 25   After the death of her beloved grandmother, a ...  Paperback
# 26   The story of two girls living eight hundred ye...  Hardcover
# 27   In 1940, eighteen-year old Juliet Armstrong is...  Hardcover
# 28   <b>A novel that tells a story set in the decad...  Hardcover
# 29                               <i>New York Times</i>  Hardcover
# ..                                                 ...        ...
# 390  <i>Some people collect stamps.<br/>Some people...  Hardcover
# 391                                Who is Baby Monkey?  Hardcover
# 392  When a young boy visits his grandfather, their...  Hardcover
# 393  <b>From <em>New York Times</em> bestseller and...  Hardcover
# 394  <b>From <em>New York Times</em> bestseller and...  Hardcover
# 395  National Book Award winner Jacqueline Woodson ...  Hardcover
# 396  In this modern fairy tale, a noble prince and ...  Hardcover
# 397  Caldecott and Printz Honor-winning illustrator...  Hardcover
# 398  From number one bestselling author Matt Haig c...  Hardcover
# 399  Luna’s best friend, Franklin, is a dragon. The...  Hardcover
# 400  <b>From the #1 New York Times bestselling auth...  Hardcover
# 401  Newlyweds Celestial and Roy are the embodiment...  Hardcover
# 402  After everything that the citizens of Beartown...  Hardcover
# 403  Could ten days at a health resort really chang...  Hardcover
# 404  <b>In his much-anticipated debut novel, Hank G...  Hardcover
# 405  The epic new novel from the internationally ac...  Hardcover
# 406  Fierce, angry, funny, heartbreaking—Tommy Oran...  Hardcover
# 407  A searing, electrifying debut novel set in Ind...  Hardcover
# 408  <b>In the riveting new novel from the #1 New Y...  Hardcover
# 409  <b>From neuroscientist and <i>New York Times</...  Hardcover
# 410  Greer Kadetsky is a shy college freshman when ...  Hardcover
# 411                              <i>A Place for Us</i>  Hardcover
# 412  The warm fall day starts like any other at the...  Hardcover
# 413  A shocking, hilarious and strangely tender nov...  Paperback
# 414  Two Chinese-American sisters—Miranda, the olde...  Hardcover
# 415  An Air Force loadmaster in the Vietnam War is ...  Hardcover
# 416  A suburban mother of two fantasizes about the ...  Hardcover
# 417  <b>From the author of <i>Happiness for Beginne...  Hardcover
# 418  <b>A debut novel of family, fame, and religion...  Hardcover
# 419  It’s 2003 and Romy Hall is at the start of two...  Hardcover
#
#              genre      month pages  \
# 0           Horror        May   561
# 1          Mystery    January   431
# 2          Mystery  September   650
# 3         Thriller    January   346
# 4          Mystery      April   359
# 5          Fiction       June   513
# 6          Mystery        May   368
# 7          Mystery    October   509
# 8          Mystery   February   326
# 9         Thriller      March   262
# 10         Mystery  September   438
# 11         Fiction       June   342
# 12         Mystery    January   280
# 13         Mystery    January   385
# 14         Mystery  September   385
# 15         Mystery       June   291
# 16         Mystery      March   336
# 17         Mystery       July   370
# 18        Thriller     August   258
# 19         Mystery    October   352
# 20         Fiction   February   440
# 21      Historical  September   272
# 22         Fiction    January   346
# 23      Historical    October   485
# 24         Fiction     August   384
# 25      Historical   February   361
# 26      Historical        May   361
# 27      Historical  September   352
# 28      Historical        May   285
# 29      Historical       July   384
# ..             ...        ...   ...
# 390      Childrens    January    40
# 391      Childrens   February   192
# 392      Childrens       June    40
# 393      Childrens      March    48
# 394      Childrens      March    48
# 395      Childrens     August    32
# 396      Childrens        May    40
# 397      Childrens      March    40
# 398         Poetry    October   119
# 399      Childrens  September    32
# 400        Fiction    January   390
# 401        Fiction   February   308
# 402        Fiction       June   448
# 403        Fiction   November   453
# 404        Fiction  September   343
# 405        Fiction    October   688
# 406        Fiction       June   294
# 407        Fiction      March   304
# 408        Fiction       June   400
# 409        Fiction      March   307
# 410        Fiction      April   454
# 411        Fiction       June   385
# 412        Fiction    October   352
# 413        Fiction       July   304
# 414        Fiction    January   368
# 415        Fiction      April   502
# 416  Short Stories      April   226
# 417        Fiction        May   320
# 418        Fiction       June   319
# 419        Fiction        May   338
#
#                                              publisher rating  \
# 0                                             Scribner   4.07
# 1                                       William Morrow   3.96
# 2                                     Mulholland Books   4.30
# 3                                   St. Martin's Press   3.85
# 4                                          Atria Books   4.09
# 5                  Little, Brown and Company and Knopf   3.87
# 6                                  Gallery/Scout Press   3.84
# 7                                               Viking   3.63
# 8    Flatiron Books                          (first...   3.87
# 9                                       Flatiron Books   3.86
# 10   Sourcebooks Landmark                          ...   4.03
# 11                                          Ballantine   3.66
# 12                          Crown Publishing Group (NY   3.73
# 13                                          Soho Press   3.94
# 14                                  St. Martin's Press   4.37
# 15   St. Martin's Press                          (f...   3.50
# 16                                       Berkley Books   4.08
# 17                                        Dutton Books   4.10
# 18                               Lake Union Publishing   4.09
# 19                                    Mulholland Books   3.94
# 20                                  St. Martin's Press   4.33
# 21   Harper Paperbacks                          (fi...   4.33
# 22                                  G.P. Putnam's Sons   3.73
# 23   Atria Books                          (first pu...   3.80
# 24                                  G.P. Putnam's Sons   4.53
# 25                                     Penguin/Berkley   4.01
# 26                                          Touchstone   3.89
# 27   Little, Brown and Company                     ...   3.60
# 28                              Knopf Publishing Group   3.73
# 29   William Morrow                          (first...   3.75
# ..                                                 ...    ...
# 390                                      Orchard Books   4.25
# 391                                   Scholastic Press   3.89
# 392                                    Disney-Hyperion   4.28
# 393  Dial Books                          (first pub...   4.48
# 394  Dial Books                          (first pub...   4.48
# 395                                Nancy Paulsen Books   4.55
# 396                                   Little Bee Books   4.40
# 397                                   Groundwood Books   3.87
# 398                                    Canongate Books   4.30
# 399                                    Thames & Hudson   4.29
# 400                                Pamela Dorman Books   4.19
# 401  Algonquin Books                          (firs...   4.01
# 402  Atria Books                          (first pu...   4.38
# 403  Flatiron Books                          (first...   3.58
# 404                                             Dutton   4.13
# 405  Knopf Publishing Group                        ...   3.93
# 406                                              Knopf   4.07
# 407                                     Flatiron Books   3.81
# 408                                   Ballantine Books   3.91
# 409                                        Scout Press   4.13
# 410                                    Riverhead Books   3.64
# 411                                    SJP for Hogarth   4.17
# 412                                   Ballantine Books   3.69
# 413  Jonathan Cape                          (first ...   3.76
# 414                                Pamela Dorman Books   3.95
# 415                             W. W. Norton & Company   4.25
# 416                                       Random House   3.78
# 417                                 St. Martin's Press   4.09
# 418                             Knopf Publishing Group   3.98
# 419                                           Scribner   3.53
#
#                                   title  year
# 0                          The Outsider  2018
# 1               The Woman in the Window  2018
# 2                          Lethal White  2018
# 3                   The Wife Between Us  2018
# 4                     Then She Was Gone  2018
# 5              The President Is Missing  2018
# 6            The Death of Mrs. Westaway  2018
# 7                         The Witch Elm  2018
# 8                       Force of Nature  2017
# 9                       Sometimes I Lie  2018
# 10   The 7½ Deaths of Evelyn Hardcastle  2018
# 11               Something in the Water  2018
# 12                        The Chalk Man  2018
# 13           The Widows of Malabar Hill  2018
# 14                    Leverage in Death  2018
# 15                        Bring Me Back  2018
# 16                     The Broken Girls  2018
# 17                 The Last Time I Lied  2018
# 18                             Jane Doe  2018
# 19                              Wrecked  2018
# 20                      The Great Alone  2018
# 21           The Tattooist of Auschwitz  2018
# 22                     The Immortalists  2018
# 23            The Clockmaker's Daughter  2018
# 24              Where the Crawdads Sing  2018
# 25                  Next Year in Havana  2018
# 26            The Map of Salt and Stars  2018
# 27                        Transcription  2018
# 28                             Warlight  2018
# 29                     The Summer Wives  2018
# ..                                  ...   ...
# 390                  The Word Collector  2018
# 391            Baby Monkey, Private Eye  2018
# 392                      Drawn Together  2018
# 393                          Islandborn  2018
# 394                          Islandborn  2018
# 395                   The Day You Begin  2018
# 396                     Prince & Knight  2018
# 397                       They Say Blue  2018
# 398                     The Truth Pixie  2018
# 399    Franklin and Luna Go to the Moon  2018
# 400                            Still Me  2018
# 401                An American Marriage  2018
# 402                      Us Against You  2017
# 403              Nine Perfect Strangers  2018
# 404      An Absolutely Remarkable Thing  2018
# 405                Killing Commendatore  2017
# 406                         There There  2018
# 407                 Girls Burn Brighter  2018
# 408                  All We Ever Wanted  2018
# 409                   Every Note Played  2018
# 410               The Female Persuasion  2018
# 411                      A Place for Us  2018
# 412                    A Spark of Light  2018
# 413      My Year of Rest and Relaxation  2018
# 414        Everything Here Is Beautiful  2018
# 415                       The Overstory  2018
# 416           You Think It, I'll Say It  2018
# 417                    How to Walk Away  2018
# 418                   The Book of Essie  2018
# 419                       The Mars Room  2018
#
# [420 rows x 10 columns]
